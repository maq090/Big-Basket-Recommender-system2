# %% [markdown]
# # <span style="color:blue"> <U/> Model and Feature Engineering</span>

# %%
#import all the necessary packages.
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings("ignore")
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import nltk
import seaborn as sns
from collections import Counter
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity  
from sklearn.metrics import pairwise_distances
from scipy.sparse import hstack

# %%
# loading preprocessed data
data=pd.read_csv(r'preprocessed_with_clusterlabel.csv',index_col=0) 
#index_col=0 to get rid of unnamed column
data.head(2)
# Out:
#                          product             category         sub_category  \
# 0  garlic oil vegetarian capsule       beauty_hygiene             haircare
# 1            water bottle orange  kitchen_garden_pets  storage_accessories
#
#             brand                 type  \
# 0  srisriayurveda        hairoil_serum
# 1      mastercook  water_fridgebottles
#
#                                          description  sale_price  discount_%  \
# 0  this product contains garlic oil that known he...       220.0         0.0
# 1  each product microwave safe refrigerator safe ...       180.0         0.0
#
#    negative  neutral  positive  compound  cluster_label
# 0     0.046    0.673     0.281    0.8271              0
# 1     0.000    0.696     0.304    0.9432              7

# %%
data.shape
# Out:
# (27164, 13)

# %%
data.columns
# Out:
# Index(['product', 'category', 'sub_category', 'brand', 'type', 'description',
#        'sale_price', 'discount_%', 'negative', 'neutral', 'positive',
#        'compound', 'cluster_label'],
#       dtype='object')

# %% [markdown]
# ## <span style=color:red> Model-1</span>
#
# ### `Bag of words` for Preprocessed Product,`One Hot encoding` for categorical features(category,sub_category,brand,type)

# %%
# Bag of words for product feature
vectorizer=CountVectorizer()
product_bow=vectorizer.fit_transform(data['product'].values)

print("After vectorization")
print('The shape of product feature vector',product_bow.shape)
# Out:
# After vectorization
# The shape of product feature vector (27164, 8687)

# %%
# one hot encoding for category feature
ohe=CountVectorizer()
category_ohe=ohe.fit_transform(data['category'].values)

print("After vectorization")
print('The shape of category ohe vector',category_ohe.shape)
# Out:
# After vectorization
# The shape of category ohe vector (27164, 11)

# %%
# one hot encoding for sub_category feature
ohe=CountVectorizer()
sub_category_ohe=ohe.fit_transform(data['sub_category'].values)

print("After vectorization")
print('The shape of sub_category ohe vector',sub_category_ohe.shape)
# Out:
# After vectorization
# The shape of sub_category ohe vector (27164, 90)

# %%
# one hot encoding for sub_category feature
brandohe=CountVectorizer()
brand_ohe=brandohe.fit_transform(data['brand'].values)

print("After vectorization")
print('The shape of brand ohe vector',brand_ohe.shape)
# Out:
# After vectorization
# The shape of brand ohe vector (27164, 2294)

# %%
# one hot encoding for sub_category feature
ohe=CountVectorizer()
type_ohe=ohe.fit_transform(data['type'].values)

print("After vectorization")
print('The shape of type ohe vector',type_ohe.shape)
# Out:
# After vectorization
# The shape of type ohe vector (27164, 433)

# %%
# concatenating all feature vectors and other numerical value columns(,sale_price,'negative', 'neutral', 'positive','compound', 'cluster_label')
from scipy.sparse import hstack
X_bow = hstack ((product_bow,category_ohe,sub_category_ohe,brand_ohe,type_ohe,data['sale_price'].values.reshape(-1,1), \
             data['negative'].values.reshape(-1,1),data['neutral'].values.reshape(-1,1),data['positive'].values.reshape(-1,1), \
             data['compound'].values.reshape(-1,1),data['cluster_label'].values.reshape(-1,1))).tocsr()

# %%
print('Shape of BOW feature vector:',X_bow.shape)
# Out:
# Shape of BOW feature vector: (27164, 11521)

# %%
# Model on bag of words for product feature

def bag_of_words_product(prod_index,num_results):

    # prod_index: product index in the given data
    # num_results: number of similar products to show
    
    # the metric we used here is cosine, the coside distance is mesured as K(X, Y) = <X, Y> / (||X||*||Y||)
    cosine_sim=cosine_similarity(X_bow,X_bow[prod_index])
    
    # np.argsort will return indices of the nearest products 
    indices = np.argsort(cosine_sim.flatten())[-num_results:-1]
    # -1 given to exclude the searched product itself from showing in recommendations as cosinine similarity will be 1 for same product
    # flipping the indices so that the product with more similarity is shown first
    # argsort will do sorting of indices from smallest to largest value
    indices=np.flip(indices) # to get sorting in descending order
    
    #psimilarity will store the similarity 
    psimilarity  = np.sort(cosine_sim.flatten())[-num_results:-1]
    psimilarity = np.flip(psimilarity)
    
    print('The searched product is:\n',prod_index,":",data['product'].loc[prod_index])
    ##https://appdividend.com/2022/07/27/how-to-print-bold-python-text/
    print('\nTop '+str(num_results-1)+' Similar products for "'+'\033[1m'+data['product'].loc[prod_index]+'\033[0m' +'" are:')
    print("="*70,'\n')
    
    for i in range (0,len(indices)):
        print(indices[i],":",data['product'].loc[indices[i]])
        print('Cosine similarity:',np.round(psimilarity[i],6))
        print("-"*50,'\n')
    
    return data.loc[np.append([prod_index],[indices])] # appending prod_index so as we get query product in dataframe

#https://numpy.org/doc/stable/reference/generated/numpy.append.html

# %%
bag_of_words_product(57,11) # without adding discount_% 
# rankimg of similar recommendations is based on cosine similarity only
# Out:
# The searched product is:
#  57 : argan liquid gold hair spa
#
# Top 10 Similar products for "argan liquid gold hair spa" are:
# ======================================================================
#
# 15854 : cream anti hair loss
# Cosine similarity: 0.999901
# --------------------------------------------------
#
# 18644 : premium henna hair treatment
# Cosine similarity: 0.999897
# --------------------------------------------------
#
# 3738 : apple cider vinegar organic argan oil hair shampoo argan hair conditioner
# Cosine similarity: 0.999896
# --------------------------------------------------
#
# 10754 : argan hair cream
# Cosine similarity: 0.999896
# --------------------------------------------------
#
# 17996 : ultimate hair repair shampoo moroccan argan hair conditioner
# Cosine similarity: 0.999894
# --------------------------------------------------
#
# 20841 : ultra nourishing hair shampoo moroccan argan hair conditioner
# Cosine similarity: 0.999894
# --------------------------------------------------
#
# 23782 : gliss hair repair total repair anti hair breakage treatment
# Cosine similarity: 0.999892
# --------------------------------------------------
#
# 21884 : gliss hair repair ultimate oil elixir structure build treatment
# Cosine similarity: 0.99989
# --------------------------------------------------
#
# 12150 : argan oil conditioner
# Cosine similarity: 0.99989
# --------------------------------------------------
#
# 21762 : gliss hair repair intense therapy bond repair mask
# Cosine similarity: 0.999889
# --------------------------------------------------
#                                                  product        category  \
# 57                            argan liquid gold hair spa  beauty_hygiene
# 15854                               cream anti hair loss  beauty_hygiene
# 18644                       premium henna hair treatment  beauty_hygiene
# 3738   apple cider vinegar organic argan oil hair sha...  beauty_hygiene
# 10754                                   argan hair cream  beauty_hygiene
# 17996  ultimate hair repair shampoo moroccan argan ha...  beauty_hygiene
# 20841  ultra nourishing hair shampoo moroccan argan h...  beauty_hygiene
# 23782  gliss hair repair total repair anti hair break...  beauty_hygiene
# 21884  gliss hair repair ultimate oil elixir structur...  beauty_hygiene
# 12150                              argan oil conditioner  beauty_hygiene
# 21762  gliss hair repair intense therapy bond repair ...  beauty_hygiene
#
#       sub_category             brand                 type  \
# 57        haircare    aromatreasures  hair_scalptreatment
# 15854     haircare  himalayawellness  hair_scalptreatment
# 18644     haircare            madilu  hair_scalptreatment
# 3738      haircare        stbotanica  shampoo_conditioner
# 10754     haircare            inatur  hair_scalptreatment
# 17996     haircare        stbotanica  shampoo_conditioner
# 20841     haircare        stbotanica  shampoo_conditioner
# 23782     haircare       schwarzkopf  hair_scalptreatment
# 21884     haircare       schwarzkopf  hair_scalptreatment
# 12150     haircare          biotique  shampoo_conditioner
# 21762     haircare       schwarzkopf  hair_scalptreatment
#
#                                              description  sale_price  \
# 57     our beautifully crafted hair spa collection pr...      199.50
# 15854  himalaya anti hair loss cream promotes hair gr...      243.75
# 18644  used treat hair fall hair growth early greying...      225.00
# 3738   apple cider vinegar argan shampoo gentle and n...      898.00
# 10754  inatur moroccan argan oil hair cream contains ...      440.00
# 17996  stbotanica moroccan argan oil conditioner affo...      898.00
# 20841  ultra nourishing shampoo proven lock moisture ...      898.00
# 23782  liquid keratin reconstructs the hair and renew...      775.00
# 21884  schwarzkopf gliss hair repair with liquid kera...      775.00
# 12150  biotique argan oil conditioner made from botan...      247.50
# 21762  gliss hair repair intense therapy bond repair ...      775.00
#
#        discount_%  negative  neutral  positive  compound  cluster_label
# 57            5.0     0.054    0.712     0.233    0.9886              0
# 15854        25.0     0.068    0.685     0.248    0.9468              0
# 18644         0.0     0.000    0.728     0.272    0.9371              0
# 3738          0.0     0.004    0.753     0.242    0.9948              1
# 10754        20.0     0.000    0.838     0.162    0.7964              3
# 17996         0.0     0.065    0.687     0.249    0.9945              1
# 20841         0.0     0.034    0.742     0.225    0.9260              1
# 23782         0.0     0.102    0.735     0.163    0.6486              1
# 21884         0.0     0.039    0.766     0.195    0.9169              1
# 12150        25.0     0.039    0.718     0.243    0.9246              0
# 21762         0.0     0.038    0.768     0.194    0.9042              1

# %% [markdown]
# ### Taking discount_% for ranking the similar items along with similarity

# %%
# taking discount_% for ranking the similar items
#https://www.geeksforgeeks.org/sort-rows-or-columns-in-pandas-dataframe-based-on-values/
def bag_of_words_product_with_discount(prod_index,num_results):

    # prod_index: product index in the given data
    # num_results: number of similar products to show
    
    # the metric we used here is cosine, the coside distance is mesured as K(X, Y) = <X, Y> / (||X||*||Y||)
    cosine_sim=cosine_similarity(X_bow,X_bow[prod_index])
    
    # np.argsort will return indices of the nearest products 
    indices = np.argsort(cosine_sim.flatten())[-num_results:-1]
    # -1 given to exclude the searched product itself from showing in recommendations as cosinine similarity will be 1 for same product
    # flipping the indices so that the product with more similarity is shown first
    # argsort will do sorting of indices from smallest to largest value
    
    indices=np.flip(indices)
    #psimilarity will store the similarity 
    psimilarity  = np.sort(cosine_sim.flatten())[-num_results:-1]
    psimilarity = np.flip(psimilarity)
    
    print('The searched\Queried product is:\n',prod_index,":",data['product'].loc[prod_index])
    print('\nTop '+str(num_results-1)+' Similar products for "'+'\033[1m'+data['product'].loc[prod_index]+'\033[0m' +'" are:')
    print("="*70,'\n')
    
    df=data[['product','discount_%']].loc[indices]
    df['discount_%']=df['discount_%']*0.5/100 # multiplied by 0.5 to give half weightage to discount % and divided by 100 to convert 
    # percentage to decimal
    df['similarity']=psimilarity.tolist() # adding similarity scores as s new column to df
    
    df['rank_score']= df['discount_%']+df['similarity'] # creating rank score by adding similarity and discount
    
    df=df.sort_values(by='rank_score',ascending=False)
    
    lst=[] # list to store indices after sorting
    for ind in df.index:
        lst.append(ind)
        print(ind,":",df['product'][ind])
        print('Cosine Similarity with queried product is :',np.round(df['similarity'][ind],6))
        print('Discount %: ',np.round(df['discount_%'][ind]/0.5*100,4)) # restoring discount to original scale 
        print('-'*50,'\n')
    return data.loc[np.append([prod_index],lst)] # appending prod_index so as we get query product in dataframe

# %%
bow_57=bag_of_words_product_with_discount(57,11)
bow_57
# Out:
# The searched\Queried product is:
#  57 : argan liquid gold hair spa
#
# Top 10 Similar products for "argan liquid gold hair spa" are:
# ======================================================================
#
# 15854 : cream anti hair loss
# Cosine Similarity with queried product is : 0.999901
# Discount %:  25.0
# --------------------------------------------------
#
# 12150 : argan oil conditioner
# Cosine Similarity with queried product is : 0.99989
# Discount %:  25.0
# --------------------------------------------------
#
# 10754 : argan hair cream
# Cosine Similarity with queried product is : 0.999896
# Discount %:  20.0
# --------------------------------------------------
#
# 18644 : premium henna hair treatment
# Cosine Similarity with queried product is : 0.999897
# Discount %:  0.0
# --------------------------------------------------
#
# 3738 : apple cider vinegar organic argan oil hair shampoo argan hair conditioner
# Cosine Similarity with queried product is : 0.999896
# Discount %:  0.0
# --------------------------------------------------
#
# 17996 : ultimate hair repair shampoo moroccan argan hair conditioner
# Cosine Similarity with queried product is : 0.999894
# Discount %:  0.0
# --------------------------------------------------
#
# 20841 : ultra nourishing hair shampoo moroccan argan hair conditioner
# Cosine Similarity with queried product is : 0.999894
# Discount %:  0.0
# --------------------------------------------------
#
# 23782 : gliss hair repair total repair anti hair breakage treatment
# Cosine Similarity with queried product is : 0.999892
# Discount %:  0.0
# --------------------------------------------------
#
# 21884 : gliss hair repair ultimate oil elixir structure build treatment
# Cosine Similarity with queried product is : 0.99989
# Discount %:  0.0
# --------------------------------------------------
#
# 21762 : gliss hair repair intense therapy bond repair mask
# Cosine Similarity with queried product is : 0.999889
# Discount %:  0.0
# --------------------------------------------------
#                                                  product        category  \
# 57                            argan liquid gold hair spa  beauty_hygiene
# 15854                               cream anti hair loss  beauty_hygiene
# 12150                              argan oil conditioner  beauty_hygiene
# 10754                                   argan hair cream  beauty_hygiene
# 18644                       premium henna hair treatment  beauty_hygiene
# 3738   apple cider vinegar organic argan oil hair sha...  beauty_hygiene
# 17996  ultimate hair repair shampoo moroccan argan ha...  beauty_hygiene
# 20841  ultra nourishing hair shampoo moroccan argan h...  beauty_hygiene
# 23782  gliss hair repair total repair anti hair break...  beauty_hygiene
# 21884  gliss hair repair ultimate oil elixir structur...  beauty_hygiene
# 21762  gliss hair repair intense therapy bond repair ...  beauty_hygiene
#
#       sub_category             brand                 type  \
# 57        haircare    aromatreasures  hair_scalptreatment
# 15854     haircare  himalayawellness  hair_scalptreatment
# 12150     haircare          biotique  shampoo_conditioner
# 10754     haircare            inatur  hair_scalptreatment
# 18644     haircare            madilu  hair_scalptreatment
# 3738      haircare        stbotanica  shampoo_conditioner
# 17996     haircare        stbotanica  shampoo_conditioner
# 20841     haircare        stbotanica  shampoo_conditioner
# 23782     haircare       schwarzkopf  hair_scalptreatment
# 21884     haircare       schwarzkopf  hair_scalptreatment
# 21762     haircare       schwarzkopf  hair_scalptreatment
#
#                                              description  sale_price  \
# 57     our beautifully crafted hair spa collection pr...      199.50
# 15854  himalaya anti hair loss cream promotes hair gr...      243.75
# 12150  biotique argan oil conditioner made from botan...      247.50
# 10754  inatur moroccan argan oil hair cream contains ...      440.00
# 18644  used treat hair fall hair growth early greying...      225.00
# 3738   apple cider vinegar argan shampoo gentle and n...      898.00
# 17996  stbotanica moroccan argan oil conditioner affo...      898.00
# 20841  ultra nourishing shampoo proven lock moisture ...      898.00
# 23782  liquid keratin reconstructs the hair and renew...      775.00
# 21884  schwarzkopf gliss hair repair with liquid kera...      775.00
# 21762  gliss hair repair intense therapy bond repair ...      775.00
#
#        discount_%  negative  neutral  positive  compound  cluster_label
# 57            5.0     0.054    0.712     0.233    0.9886              0
# 15854        25.0     0.068    0.685     0.248    0.9468              0
# 12150        25.0     0.039    0.718     0.243    0.9246              0
# 10754        20.0     0.000    0.838     0.162    0.7964              3
# 18644         0.0     0.000    0.728     0.272    0.9371              0
# 3738          0.0     0.004    0.753     0.242    0.9948              1
# 17996         0.0     0.065    0.687     0.249    0.9945              1
# 20841         0.0     0.034    0.742     0.225    0.9260              1
# 23782         0.0     0.102    0.735     0.163    0.6486              1
# 21884         0.0     0.039    0.766     0.195    0.9169              1
# 21762         0.0     0.038    0.768     0.194    0.9042              1

# %%
bag_of_words_product_with_discount(18623,11)
# Out:
# The searched\Queried product is:
#  18623 : cookies italian biscotti
#
# Top 10 Similar products for "cookies italian biscotti" are:
# ======================================================================
#
# 16664 : cookies almond roasted
# Cosine Similarity with queried product is : 0.999902
# Discount %:  20.0
# --------------------------------------------------
#
# 3853 : cookies butter pista
# Cosine Similarity with queried product is : 0.999924
# Discount %:  10.0
# --------------------------------------------------
#
# 15398 : artisanal cookies seasons greetings
# Cosine Similarity with queried product is : 0.999877
# Discount %:  10.0
# --------------------------------------------------
#
# 26398 : peanut butter cookies
# Cosine Similarity with queried product is : 0.999891
# Discount %:  0.0
# --------------------------------------------------
#
# 22473 : cookies oats
# Cosine Similarity with queried product is : 0.999889
# Discount %:  0.0
# --------------------------------------------------
#
# 10682 : cookies kesar supreme
# Cosine Similarity with queried product is : 0.999885
# Discount %:  0.0
# --------------------------------------------------
#
# 4404 : cookies assorted
# Cosine Similarity with queried product is : 0.99986
# Discount %:  0.0
# --------------------------------------------------
#
# 15231 : dark chocolate cookies
# Cosine Similarity with queried product is : 0.999854
# Discount %:  0.0
# --------------------------------------------------
#
# 15267 : cashew cookies
# Cosine Similarity with queried product is : 0.999846
# Discount %:  0.0
# --------------------------------------------------
#
# 17415 : whole wheat cookies choco chip
# Cosine Similarity with queried product is : 0.999845
# Discount %:  0.0
# --------------------------------------------------
#                                    product            category  \
# 18623             cookies italian biscotti  bakery_cakes_dairy
# 16664               cookies almond roasted  bakery_cakes_dairy
# 3853                  cookies butter pista  bakery_cakes_dairy
# 15398  artisanal cookies seasons greetings  bakery_cakes_dairy
# 26398                peanut butter cookies  bakery_cakes_dairy
# 22473                         cookies oats  bakery_cakes_dairy
# 10682                cookies kesar supreme  bakery_cakes_dairy
# 4404                      cookies assorted  bakery_cakes_dairy
# 15231               dark chocolate cookies  bakery_cakes_dairy
# 15267                       cashew cookies  bakery_cakes_dairy
# 17415       whole wheat cookies choco chip  bakery_cakes_dairy
#
#              sub_category             brand                    type  \
# 18623  cookies_rusk_khari  lovelybakestudio  bakerybiscuits_cookies
# 16664  cookies_rusk_khari  lovelybakestudio  bakerybiscuits_cookies
# 3853   cookies_rusk_khari  lovelybakestudio  bakerybiscuits_cookies
# 15398  cookies_rusk_khari         cookieman  bakerybiscuits_cookies
# 26398  cookies_rusk_khari    thebakersdozen  bakerybiscuits_cookies
# 22473  cookies_rusk_khari          bhealthy  bakerybiscuits_cookies
# 10682  cookies_rusk_khari         momkhatai  bakerybiscuits_cookies
# 4404   cookies_rusk_khari         momkhatai  bakerybiscuits_cookies
# 15231  cookies_rusk_khari    thebakersdozen          premiumcookies
# 15267  cookies_rusk_khari    thebakersdozen          premiumcookies
# 17415  cookies_rusk_khari          bhealthy  bakerybiscuits_cookies
#
#                                              description  sale_price  \
# 18623  eggless premium quality almonds are twice bake...       166.5
# 16664  eggless premium almonds and goodness butter co...       148.0
# 3853   eggless crunchy buttery tasteful baked perfect...       166.5
# 15398  cookie man presents delightful pack artisanal ...       175.5
# 26398  enjoy the baker dozen healthy peanut butter co...       170.0
# 22473  power the with wholesome whole wheat oat cooke...       159.0
# 10682  momkhatai kesar supreme are handmade cookies w...       160.0
# 4404   momkhatai assorted cookies contain four delici...       140.0
# 15231  crunchy butter cookies with loads dark chocola...       170.0
# 15267  crunchy butter cookies with cashews chunks the...       150.0
# 17415  whole wheat cookie filled with choco chips and...       159.0
#
#        discount_%  negative  neutral  positive  compound  cluster_label
# 18623        10.0      0.00    0.845     0.155    0.8834              7
# 16664        20.0      0.00    0.714     0.286    0.9847              7
# 3853         10.0      0.11    0.649     0.240    0.4588              7
# 15398        10.0      0.00    0.662     0.338    0.9911              7
# 26398         0.0      0.00    0.592     0.408    0.9816              7
# 22473         0.0      0.00    1.000     0.000    0.0000              7
# 10682         0.0      0.00    0.684     0.316    0.9451              7
# 4404          0.0      0.00    0.735     0.265    0.9371              7
# 15231         0.0      0.00    0.895     0.105    0.4019              7
# 15267         0.0      0.00    0.891     0.109    0.4019              7
# 17415         0.0      0.00    0.717     0.283    0.7845              7

# %% [markdown]
# ### Observatios:
# - Even though we searched for cookies its showing similar items milkshake mix
# - will see with other featurization techniques

# %% [markdown]
# ## <span style=color:red>Model-2
# ### Tf-Idf for Product title

# %%
tfidf_vectorizer = TfidfVectorizer()
tfidf_product = tfidf_vectorizer.fit_transform(data['product'])

print('shape of product title after TF-IDF featurisation:',tfidf_product.shape)
# Out:
# shape of product title after TF-IDF featurisation: (27164, 8687)

# %%
# concatenating all feature vectors and other numerical value columns(,sale_price,'negative', 'neutral', 'positive','compound', 'cluster_label')

X_tfidf = hstack ((tfidf_product,category_ohe,sub_category_ohe,brand_ohe,type_ohe,data['sale_price'].values.reshape(-1,1), \
             data['negative'].values.reshape(-1,1),data['neutral'].values.reshape(-1,1),data['positive'].values.reshape(-1,1), \
             data['compound'].values.reshape(-1,1),data['cluster_label'].values.reshape(-1,1))).tocsr()

# %%
print('Shape of TF-IDF feature vector:',X_tfidf.shape)
# Out:
# Shape of TF-IDF feature vector: (27164, 11521)

# %%
def tfidf_product(prod_index,num_results):

    # prod_index: product index in the given data
    # num_results: number of similar products to show
    
    # the metric we used here is cosine, the coside distance is mesured as K(X, Y) = <X, Y> / (||X||*||Y||)
    cosine_sim=cosine_similarity(X_tfidf,X_tfidf[prod_index])
    
    # np.argsort will return indices of the nearest products 
    indices = np.argsort(cosine_sim.flatten())[-num_results:-1]
    # -1 given to exclude the searched product itself from showing in recommendations as cosinine similarity will be 1 for same product
    # flipping the indices so that the product with more similarity is shown first
    # argsort will do sorting of indices from smallest to largest value
    
    indices=np.flip(indices)
    #psimilarity will store the similarity 
    psimilarity  = np.sort(cosine_sim.flatten())[-num_results:-1]
    psimilarity = np.flip(psimilarity)
    
    print('The searched\Queried product is:\n',prod_index,":\n",data.loc[prod_index])
    print('\nTop '+str(num_results-1)+' Similar products for "'+'\033[1m'+data['product'].loc[prod_index]+'\033[0m' +'" are:')
    print("="*70,'\n')
    
    df=data[['product','discount_%']].loc[indices]
    df['discount_%']=df['discount_%']*0.5/100 # multiplied by 0.5 to give half weightage to discount % and divided by 100 to convert 
    # percentage to decimal
    df['similarity']=psimilarity.tolist() # adding similarity scores as s new column to df
    
    df['rank_score']= df['discount_%']+df['similarity'] # creating rank score by adding similarity and discount
    
    df=df.sort_values(by='rank_score',ascending=False)
    
    lst=[] # list to store indices after sorting
    for ind in df.index:
        lst.append(ind)
        print(ind,":",df['product'][ind])
        print('Cosine Similarity with queried product is :',np.round(df['similarity'][ind],6))
        print('Discount %: ',np.round(df['discount_%'][ind]/0.5*100,4)) # restoring discount to original scale 
        print('-'*50,'\n')
        
    return data.loc[np.append([prod_index],lst)] # appending prod_index so as we get query product in dataframe

# %%
tfidf_57=tfidf_product(57,11)
tfidf_57
# Out:
# The searched\Queried product is:
#  57 :
#  product                                 argan liquid gold hair spa
# category                                            beauty_hygiene
# sub_category                                              haircare
# brand                                               aromatreasures
# type                                           hair_scalptreatment
# description      our beautifully crafted hair spa collection pr...
# sale_price                                                   199.5
# discount_%                                                       5
# negative                                                     0.054
# neutral                                                      0.712
# positive                                                     0.233
# compound                                                    0.9886
# cluster_label                                                    0
# Name: 57, dtype: object
#
# Top 10 Similar products for "argan liquid gold hair spa" are:
# ======================================================================
#
# 15854 : cream anti hair loss
# Cosine Similarity with queried product is : 0.999959
# Discount %:  25.0
# --------------------------------------------------
#
# 12150 : argan oil conditioner
# Cosine Similarity with queried product is : 0.999943
# Discount %:  25.0
# --------------------------------------------------
#
# 26263 : avocado nourish mask for fragile hair
# Cosine Similarity with queried product is : 0.999952
# Discount %:  20.0
# --------------------------------------------------
#
# 21421 : argan oil shampoo
# Cosine Similarity with queried product is : 0.999942
# Discount %:  20.0
# --------------------------------------------------
#
# 5979 : hibiscus shampoo for dry hair
# Cosine Similarity with queried product is : 0.999951
# Discount %:  15.0
# --------------------------------------------------
#
# 12993 : tea tree shampoo for dandruff
# Cosine Similarity with queried product is : 0.99995
# Discount %:  10.0
# --------------------------------------------------
#
# 8976 : honey moisture mask for dry damaged hair
# Cosine Similarity with queried product is : 0.999958
# Discount %:  0.0
# --------------------------------------------------
#
# 18644 : premium henna hair treatment
# Cosine Similarity with queried product is : 0.999957
# Discount %:  0.0
# --------------------------------------------------
#
# 21884 : gliss hair repair ultimate oil elixir structure build treatment
# Cosine Similarity with queried product is : 0.999941
# Discount %:  0.0
# --------------------------------------------------
#
# 21762 : gliss hair repair intense therapy bond repair mask
# Cosine Similarity with queried product is : 0.999941
# Discount %:  0.0
# --------------------------------------------------
#                                                  product        category  \
# 57                            argan liquid gold hair spa  beauty_hygiene
# 15854                               cream anti hair loss  beauty_hygiene
# 12150                              argan oil conditioner  beauty_hygiene
# 26263              avocado nourish mask for fragile hair  beauty_hygiene
# 21421                                  argan oil shampoo  beauty_hygiene
# 5979                       hibiscus shampoo for dry hair  beauty_hygiene
# 12993                      tea tree shampoo for dandruff  beauty_hygiene
# 8976            honey moisture mask for dry damaged hair  beauty_hygiene
# 18644                       premium henna hair treatment  beauty_hygiene
# 21884  gliss hair repair ultimate oil elixir structur...  beauty_hygiene
# 21762  gliss hair repair intense therapy bond repair ...  beauty_hygiene
#
#       sub_category               brand                 type  \
# 57        haircare      aromatreasures  hair_scalptreatment
# 15854     haircare    himalayawellness  hair_scalptreatment
# 12150     haircare            biotique  shampoo_conditioner
# 26263     haircare  godrejprofessional  hair_scalptreatment
# 21421     haircare              inatur  shampoo_conditioner
# 5979      haircare      aromatreasures  shampoo_conditioner
# 12993     haircare      aromatreasures  shampoo_conditioner
# 8976      haircare  godrejprofessional  hair_scalptreatment
# 18644     haircare              madilu  hair_scalptreatment
# 21884     haircare         schwarzkopf  hair_scalptreatment
# 21762     haircare         schwarzkopf  hair_scalptreatment
#
#                                              description  sale_price  \
# 57     our beautifully crafted hair spa collection pr...      199.50
# 15854  himalaya anti hair loss cream promotes hair gr...      243.75
# 12150  biotique argan oil conditioner made from botan...      247.50
# 26263  with frequent exposure pollution sun and styli...      200.00
# 21421  argan oil nutri hydrant shampoo enriched with ...      240.00
# 5979   rich formula with natural ingredients which pe...      191.25
# 12993  thanks its balanced formula which purifies the...      202.50
# 8976   godrej professional honey moisture mask infuse...      250.00
# 18644  used treat hair fall hair growth early greying...      225.00
# 21884  schwarzkopf gliss hair repair with liquid kera...      775.00
# 21762  gliss hair repair intense therapy bond repair ...      775.00
#
#        discount_%  negative  neutral  positive  compound  cluster_label
# 57            5.0     0.054    0.712     0.233    0.9886              0
# 15854        25.0     0.068    0.685     0.248    0.9468              0
# 12150        25.0     0.039    0.718     0.243    0.9246              0
# 26263        20.0     0.028    0.745     0.226    0.9694              0
# 21421        20.0     0.023    0.647     0.330    0.9785              0
# 5979         15.0     0.000    0.673     0.327    0.9657              0
# 12993        10.0     0.000    0.830     0.170    0.7650              0
# 8976          0.0     0.042    0.824     0.133    0.8779              0
# 18644         0.0     0.000    0.728     0.272    0.9371              0
# 21884         0.0     0.039    0.766     0.195    0.9169              1
# 21762         0.0     0.038    0.768     0.194    0.9042              1

# %% [markdown]
# ### Observations:
#
# - We can see that for product index:57 the top 10 similar products using TF-IDF  product featurization are different and much better than those of Bag of Words
# - Only 3 products are common in both approches

# %% [markdown]
# ## <span style=color:red>Model-3
#
# ### TF-IDF weighted Word2Vec for Product title feature

# %%
# using pre trained word2vec from glove vectors
#https://nlp.stanford.edu/projects/glove/
import pickle
with open('glove_vectors', 'rb') as f:
    model = pickle.load(f)
    glove_words =  set(model.keys())

# %%
# we are converting a dictionary with word as a key, and the idf as a value
dictionary = dict(zip(tfidf_vectorizer.get_feature_names(), list(tfidf_vectorizer.idf_)))
tfidf_words = set(tfidf_vectorizer.get_feature_names())

# %% [markdown]
# ### tfidf_W2V vectorization of product feature

# %%
#vectorizing train  data using tfidf-W2v
# average Word2Vec
# compute tfidf word2vec for each product.
from tqdm import tqdm
product_tfidf_w2v_vectors = []; # the avg-w2v for each product is stored in this list
for product in tqdm(data['product']): # for each product title
    vector = np.zeros(300) # as word vectors are of zero length
    tf_idf_weight =0; # num of words with a valid vector in the product
    for word in product.split(): # for each word in product title
        if (word in glove_words) and (word in tfidf_words):
            vec = model[word] # getting the vector for each word
            # here we are multiplying idf value(dictionary[word]) and the tf value((product.count(word)/len(product.split())))
            tf_idf = dictionary[word]*(product.count(word)/len(product.split())) # getting the tfidf value for each word
            vector += (vec * tf_idf) # calculating tfidf weighted w2v
            tf_idf_weight += tf_idf
    if tf_idf_weight != 0:
        vector /= tf_idf_weight
    product_tfidf_w2v_vectors.append(vector)
# Out:
# 100%|█████████████████████████████████| 27164/27164 [00:01<00:00, 15309.58it/s]

# %%
print(len(product_tfidf_w2v_vectors))
print(len(product_tfidf_w2v_vectors[0]))
# Out:
# 27164
# 300

# %%
# concatenating all feature vectors and other numerical value columns(,sale_price,'negative', 'neutral', 'positive','compound', 'cluster_label')

X_tfidf_w2v = hstack ((product_tfidf_w2v_vectors,category_ohe,sub_category_ohe,brand_ohe,type_ohe,data['sale_price'].values.reshape(-1,1), \
             data['negative'].values.reshape(-1,1),data['neutral'].values.reshape(-1,1),data['positive'].values.reshape(-1,1), \
             data['compound'].values.reshape(-1,1),data['cluster_label'].values.reshape(-1,1))).tocsr()

# %%
def tfidf_w2v_product(prod_index,num_results):

    # prod_index: product index in the given data
    # num_results: number of similar products to show
    
    # the metric we used here is cosine, the coside distance is mesured as K(X, Y) = <X, Y> / (||X||*||Y||)
    cosine_sim=cosine_similarity(X_tfidf_w2v,X_tfidf_w2v[prod_index])
    
    # np.argsort will return indices of the nearest products 
    indices = np.argsort(cosine_sim.flatten())[-num_results:-1]
    # -1 given to exclude the searched product itself from showing in recommendations as cosinine similarity will be 1 for same product
    # flipping the indices so that the product with more similarity is shown first
    # argsort will do sorting of indices from smallest to largest value
    indices=np.flip(indices)
    #psimilarity will store the similarity 
    psimilarity  = np.sort(cosine_sim.flatten())[-num_results:-1]
    psimilarity = np.flip(psimilarity)
    
    print('The searched/Queried product is:\n',prod_index,":",data['product'].loc[prod_index])
    print('\nTop '+str(num_results-1)+' Similar products for "'+'\033[1m'+data['product'].loc[prod_index]+'\033[0m' +'" are:')
    print("="*70,'\n')
    
    df=data[['product','discount_%']].loc[indices]
    df['discount_%']=df['discount_%']*0.5/100 # multiplied by 0.5 to give half weightage to discount % and divided by 100 to convert 
    # percentage to decimal
    df['similarity']=psimilarity.tolist() # adding similarity scores as s new column to df
    
    df['rank_score']= df['discount_%']+df['similarity'] # creating rank score by adding similarity and discount
    
    df=df.sort_values(by='rank_score',ascending=False)
    
    lst=[] # list to store indices after sorting
    for ind in df.index:
        lst.append(ind)
        print(ind,":",df['product'][ind])
        print('Cosine Similarity with queried product is :',np.round(df['similarity'][ind],6))
        print('Discount %: ',np.round(df['discount_%'][ind]/0.5*100,4)) # restoring discount to original scale 
        print('-'*50,'\n')
        
    return data.loc[np.append([prod_index],lst)] # appending prod_index so as we get query product in dataframe

# %%
tfidf_w2v_57=tfidf_w2v_product(57,11)
tfidf_w2v_57
# Out:
# The searched/Queried product is:
#  57 : argan liquid gold hair spa
#
# Top 10 Similar products for "argan liquid gold hair spa" are:
# ======================================================================
#
# 5979 : hibiscus shampoo for dry hair
# Cosine Similarity with queried product is : 0.999802
# Discount %:  15.0
# --------------------------------------------------
#
# 18671 : hair oil for strong long thick hair
# Cosine Similarity with queried product is : 0.999792
# Discount %:  15.0
# --------------------------------------------------
#
# 17753 : advansed gold coconut hair oil
# Cosine Similarity with queried product is : 0.999803
# Discount %:  12.0
# --------------------------------------------------
#
# 16392 : garnier hair color shade natural black loreal paris shampoo
# Cosine Similarity with queried product is : 0.999797
# Discount %:  10.8434
# --------------------------------------------------
#
# 13487 : royal gold facial kit for dry skin single time use
# Cosine Similarity with queried product is : 0.999814
# Discount %:  10.0
# --------------------------------------------------
#
# 24747 : royal gold facial kit for oily skin single time use
# Cosine Similarity with queried product is : 0.99981
# Discount %:  10.0
# --------------------------------------------------
#
# 10565 : royal gold facial kit for oily skin single time use
# Cosine Similarity with queried product is : 0.99981
# Discount %:  10.0
# --------------------------------------------------
#
# 21158 : herbal green tea aloevera hair conditioner sls paraben free
# Cosine Similarity with queried product is : 0.999816
# Discount %:  0.0
# --------------------------------------------------
#
# 15707 : all natural probiotics shampoo bar for oily hair
# Cosine Similarity with queried product is : 0.999809
# Discount %:  0.0
# --------------------------------------------------
#
# 18644 : premium henna hair treatment
# Cosine Similarity with queried product is : 0.999802
# Discount %:  0.0
# --------------------------------------------------
#                                                  product        category  \
# 57                            argan liquid gold hair spa  beauty_hygiene
# 5979                       hibiscus shampoo for dry hair  beauty_hygiene
# 18671                hair oil for strong long thick hair  beauty_hygiene
# 17753                     advansed gold coconut hair oil  beauty_hygiene
# 16392  garnier hair color shade natural black loreal ...  beauty_hygiene
# 13487  royal gold facial kit for dry skin single time...  beauty_hygiene
# 24747  royal gold facial kit for oily skin single tim...  beauty_hygiene
# 10565  royal gold facial kit for oily skin single tim...  beauty_hygiene
# 21158  herbal green tea aloevera hair conditioner sls...  beauty_hygiene
# 15707   all natural probiotics shampoo bar for oily hair  beauty_hygiene
# 18644                       premium henna hair treatment  beauty_hygiene
#
#       sub_category           brand                 type  \
# 57        haircare  aromatreasures  hair_scalptreatment
# 5979      haircare  aromatreasures  shampoo_conditioner
# 18671     haircare       daburamla        hairoil_serum
# 17753     haircare       parachute        hairoil_serum
# 16392     haircare         bbcombo            haircolor
# 13487     skincare  aromatreasures             facecare
# 24747     skincare  aromatreasures             facecare
# 10565     skincare  aromatreasures             facecare
# 21158     haircare    khadinatural  shampoo_conditioner
# 15707     haircare        golisoda  shampoo_conditioner
# 18644     haircare          madilu  hair_scalptreatment
#
#                                              description  sale_price  \
# 57     our beautifully crafted hair spa collection pr...      199.50
# 5979   rich formula with natural ingredients which pe...      191.25
# 18671  dabur amla hair oil infuses your hair with str...      233.75
# 17753  your hair reflection who you are your identity...      189.20
# 16392  garnier color naturals shade natural black gar...      222.00
# 13487  enriched with the goodness gold leaf this trea...      243.00
# 24747  enriched with the goodness gold leaf this trea...      243.00
# 10565  enriched with the goodness gold leaf this trea...      243.00
# 21158  this green tea aloe vera conditioner nourishes...      250.00
# 15707  the shampoo bar contains brahmi powder which t...      250.00
# 18644  used treat hair fall hair growth early greying...      225.00
#
#        discount_%  negative  neutral  positive  compound  cluster_label
# 57       5.000000     0.054    0.712     0.233    0.9886              0
# 5979    15.000000     0.000    0.673     0.327    0.9657              0
# 18671   15.000000     0.000    0.699     0.301    0.9753              0
# 17753   12.000000     0.043    0.623     0.334    0.9937              0
# 16392   10.843373     0.018    0.693     0.289    0.9971              0
# 13487   10.000000     0.031    0.714     0.255    0.9501              0
# 24747   10.000000     0.031    0.714     0.255    0.9501              0
# 10565   10.000000     0.031    0.714     0.255    0.9501              0
# 21158    0.000000     0.101    0.595     0.304    0.8720              0
# 15707    0.000000     0.037    0.733     0.230    0.9705              0
# 18644    0.000000     0.000    0.728     0.272    0.9371              0

# %%
tfidf_w2v_product(18623,11)
# Out:
# The searched/Queried product is:
#  18623 : cookies italian biscotti
#
# Top 10 Similar products for "cookies italian biscotti" are:
# ======================================================================
#
# 3031 : organic foxtail millet italian thinai rice
# Cosine Similarity with queried product is : 0.99952
# Discount %:  30.5019
# --------------------------------------------------
#
# 6982 : organic foxtail millet italian thinai rice
# Cosine Similarity with queried product is : 0.99952
# Discount %:  30.5019
# --------------------------------------------------
#
# 14094 : fresho signature plain bread stick happy chef pasta sauce arrabiata
# Cosine Similarity with queried product is : 0.999608
# Discount %:  17.0561
# --------------------------------------------------
#
# 13810 : fresho signature plain bread stick happy chef pasta sauce arrabiata
# Cosine Similarity with queried product is : 0.999574
# Discount %:  17.0561
# --------------------------------------------------
#
# 6198 : assorted cookies fruit nut choc chip
# Cosine Similarity with queried product is : 0.999537
# Discount %:  15.0
# --------------------------------------------------
#
# 3853 : cookies butter pista
# Cosine Similarity with queried product is : 0.999553
# Discount %:  10.0
# --------------------------------------------------
#
# 17415 : whole wheat cookies choco chip
# Cosine Similarity with queried product is : 0.999566
# Discount %:  0.0
# --------------------------------------------------
#
# 15231 : dark chocolate cookies
# Cosine Similarity with queried product is : 0.999547
# Discount %:  0.0
# --------------------------------------------------
#
# 15845 : artisanal cookies
# Cosine Similarity with queried product is : 0.999525
# Discount %:  0.0
# --------------------------------------------------
#
# 4322 : quadratini wafer cookies chocolate
# Cosine Similarity with queried product is : 0.999508
# Discount %:  0.0
# --------------------------------------------------
#                                                  product  \
# 18623                           cookies italian biscotti
# 3031          organic foxtail millet italian thinai rice
# 6982          organic foxtail millet italian thinai rice
# 14094  fresho signature plain bread stick happy chef ...
# 13810  fresho signature plain bread stick happy chef ...
# 6198                assorted cookies fruit nut choc chip
# 3853                                cookies butter pista
# 17415                     whole wheat cookies choco chip
# 15231                             dark chocolate cookies
# 15845                                  artisanal cookies
# 4322                  quadratini wafer cookies chocolate
#
#                     category         sub_category             brand  \
# 18623     bakery_cakes_dairy   cookies_rusk_khari  lovelybakestudio
# 3031   foodgrains_oil_masala       organicstaples           bbroyal
# 6982   foodgrains_oil_masala          dals_pulses           bbroyal
# 14094     bakery_cakes_dairy   cookies_rusk_khari           bbcombo
# 13810     bakery_cakes_dairy         bakerysnacks           bbcombo
# 6198      bakery_cakes_dairy   cookies_rusk_khari         cookieman
# 3853      bakery_cakes_dairy   cookies_rusk_khari  lovelybakestudio
# 17415     bakery_cakes_dairy   cookies_rusk_khari          bhealthy
# 15231     bakery_cakes_dairy   cookies_rusk_khari    thebakersdozen
# 15845     bakery_cakes_dairy   cookies_rusk_khari         cookieman
# 4322       gourmet_worldfood  chocolates_biscuits           loacker
#
#                          type  \
# 18623  bakerybiscuits_cookies
# 3031     organicmillet_flours
# 6982     organicmillet_flours
# 14094  bakerybiscuits_cookies
# 13810  bakerybiscuits_cookies
# 6198   bakerybiscuits_cookies
# 3853   bakerybiscuits_cookies
# 17415  bakerybiscuits_cookies
# 15231          premiumcookies
# 15845  bakerybiscuits_cookies
# 4322   cookies_biscotti_wafer
#
#                                              description  sale_price  \
# 18623  eggless premium quality almonds are twice bake...      166.50
# 3031   foxtail italian millet one those forgotten gra...      180.00
# 6982   foxtail italian millet one those forgotten gra...      180.00
# 14094  cherish the heavenly taste these incredibly de...      177.50
# 13810  cherish the heavenly taste these incredibly de...      177.50
# 6198   cookie man presents delightful pack assorted a...      165.75
# 3853   eggless crunchy buttery tasteful baked perfect...      166.50
# 17415  whole wheat cookie filled with choco chips and...      159.00
# 15231  crunchy butter cookies with loads dark chocola...      170.00
# 15845  cookie man presents delightful pack artisanal ...      370.00
# 4322   loacker chocolates are made using unique recip...      349.00
#
#        discount_%  negative  neutral  positive  compound  cluster_label
# 18623   10.000000     0.000    0.845     0.155    0.8834              7
# 3031    30.501931     0.060    0.852     0.088    0.2822              7
# 6982    30.501931     0.060    0.852     0.088    0.2822              7
# 14094   17.056075     0.036    0.503     0.461    0.9371              7
# 13810   17.056075     0.036    0.503     0.461    0.9371              7
# 6198    15.000000     0.000    0.712     0.288    0.9886              7
# 3853    10.000000     0.110    0.649     0.240    0.4588              7
# 17415    0.000000     0.000    0.717     0.283    0.7845              7
# 15231    0.000000     0.000    0.895     0.105    0.4019              7
# 15845    0.000000     0.000    0.653     0.347    0.9732             11
# 4322     0.000000     0.023    0.742     0.234    0.8957             11

# %% [markdown]
# ### Observations:
#
# - TF-IDF Word2Vec is recommending similar items which are more relavant to search query than BOW
# - Overall TF-IDF Word2Vec will be better solution

# %% [markdown]
# ### Summary of all three featurizations techniques for Product title

# %%
#Summary of all three featurizations techniques for Product title for product index 57
#https://pandas.pydata.org/docs/user_guide/style.html
#https://stackoverflow.com/questions/59535426/can-you-change-the-caption-font-size-using-pandas-styling
#https://datascientyst.com/set-caption-customize-font-size-color-in-pandas-dataframe/
prod_index=57
d=pd.DataFrame({'BOW':bow_57['product'].values[1:],'TF-IDF':tfidf_57['product'].values[1:],'TF-IDF_W2V':tfidf_w2v_57['product'].values[1:]})
# setting caption(title) to dataframe
d.style.set_caption('Similar products for : '+'" '+data['product'].loc[prod_index]+'"').set_table_styles([{'selector':'caption',
                                                                                         'props':[('color','black'),
                                                                                                  ('font-weight', 'bold'),
                                                                                                  ('text-align','left'),
                                                                                                 ('font-size', '16px')]}])
# Out:
# <style  type="text/css" >
#     #T_4db9a7fb_2ad4_11ed_90b5_d4bed961474d caption {
#           color: black;
#           font-weight: bold;
#           text-align: left;
#           font-size: 16px;
#     }</style><table id="T_4db9a7fb_2ad4_11ed_90b5_d4bed961474d" ><caption>Similar products for : " argan liquid gold hair spa"</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >BOW</th>        <th class="col_heading level0 col1" >TF-IDF</th>        <th class="col_heading level0 col2" >TF-IDF_W2V</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_4db9a7fb_2ad4_11ed_90b5_d4bed961474dlevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_4db9a7fb_2ad4_11ed_90b5_d4bed961474drow0_col0" class="data row0 col0" >cream anti hair loss</td>
#                         <td id="T_4db9a7fb_2ad4_11ed_90b5_d4bed961474drow0_col1" class="data row0 col1" >cream anti hair loss</td>
#                         <td id="T_4db9a7fb_2ad4_11ed_90b5_d4bed961474drow0_col2" class="data row0 col2" >hibiscus shampoo for dry hair</td>
#             </tr>
#             <tr>
#                         <th id="T_4db9a7fb_2ad4_11ed_90b5_d4bed961474dlevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_4db9a7fb_2ad4_11ed_90b5_d4bed961474drow1_col0" class="data row1 col0" >argan oil conditioner</td>
#                         <td id="T_4db9a7fb_2ad4_11ed_90b5_d4bed961474drow1_col1" class="data row1 col1" >argan oil conditioner</td>
#                         <td id="T_4db9a7fb_2ad4_11ed_90b5_d4bed961474drow1_col2" class="data row1 col2" >hair oil for strong long thick hair</td>
#             </tr>
#             <tr>
#                         <th id="T_4db9a7fb_2ad4_11ed_90b5_d4bed961474dlevel0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_4db9a7fb_2ad4_11ed_90b5_d4bed961474drow2_col0" class="data row2 col0" >argan hair cream</td>
#                         <td id="T_4db9a7fb_2ad4_11ed_90b5_d4bed961474drow2_col1" class="data row2 col1" >avocado nourish mask for fragile hair</td>
#                         <td id="T_4db9a7fb_2ad4_11ed_90b5_d4bed961474drow2_col2" class="data row2 col2" >advansed gold coconut hair oil</td>
#             </tr>
#             <tr>
#                         <th id="T_4db9a7fb_2ad4_11ed_90b5_d4bed961474dlevel0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_4db9a7fb_2ad4_11ed_90b5_d4bed961474drow3_col0" class="data row3 col0" >premium henna hair treatment</td>
#                         <td id="T_4db9a7fb_2ad4_11ed_90b5_d4bed961474drow3_col1" class="data row3 col1" >argan oil shampoo</td>
#                         <td id="T_4db9a7fb_2ad4_11ed_90b5_d4bed961474drow3_col2" class="data row3 col2" >garnier hair color shade natural black loreal paris shampoo</td>
#             </tr>
#             <tr>
#                         <th id="T_4db9a7fb_2ad4_11ed_90b5_d4bed961474dlevel0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_4db9a7fb_2ad4_11ed_90b5_d4bed961474drow4_col0" class="data row4 col0" >apple cider vinegar organic argan oil hair shampoo argan hair conditioner</td>
#                         <td id="T_4db9a7fb_2ad4_11ed_90b5_d4bed961474drow4_col1" class="data row4 col1" >hibiscus shampoo for dry hair</td>
#                         <td id="T_4db9a7fb_2ad4_11ed_90b5_d4bed961474drow4_col2" class="data row4 col2" >royal gold facial kit for dry skin single time use</td>
#             </tr>
#             <tr>
#                         <th id="T_4db9a7fb_2ad4_11ed_90b5_d4bed961474dlevel0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_4db9a7fb_2ad4_11ed_90b5_d4bed961474drow5_col0" class="data row5 col0" >ultimate hair repair shampoo moroccan argan hair conditioner</td>
#                         <td id="T_4db9a7fb_2ad4_11ed_90b5_d4bed961474drow5_col1" class="data row5 col1" >tea tree shampoo for dandruff</td>
#                         <td id="T_4db9a7fb_2ad4_11ed_90b5_d4bed961474drow5_col2" class="data row5 col2" >royal gold facial kit for oily skin single time use</td>
#             </tr>
#             <tr>
#                         <th id="T_4db9a7fb_2ad4_11ed_90b5_d4bed961474dlevel0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_4db9a7fb_2ad4_11ed_90b5_d4bed961474drow6_col0" class="data row6 col0" >ultra nourishing hair shampoo moroccan argan hair conditioner</td>
#                         <td id="T_4db9a7fb_2ad4_11ed_90b5_d4bed961474drow6_col1" class="data row6 col1" >honey moisture mask for dry damaged hair</td>
#                         <td id="T_4db9a7fb_2ad4_11ed_90b5_d4bed961474drow6_col2" class="data row6 col2" >royal gold facial kit for oily skin single time use</td>
#             </tr>
#             <tr>
#                         <th id="T_4db9a7fb_2ad4_11ed_90b5_d4bed961474dlevel0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_4db9a7fb_2ad4_11ed_90b5_d4bed961474drow7_col0" class="data row7 col0" >gliss hair repair total repair anti hair breakage treatment</td>
#                         <td id="T_4db9a7fb_2ad4_11ed_90b5_d4bed961474drow7_col1" class="data row7 col1" >premium henna hair treatment</td>
#                         <td id="T_4db9a7fb_2ad4_11ed_90b5_d4bed961474drow7_col2" class="data row7 col2" >herbal green tea aloevera hair conditioner sls paraben free</td>
#             </tr>
#             <tr>
#                         <th id="T_4db9a7fb_2ad4_11ed_90b5_d4bed961474dlevel0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_4db9a7fb_2ad4_11ed_90b5_d4bed961474drow8_col0" class="data row8 col0" >gliss hair repair ultimate oil elixir structure build treatment</td>
#                         <td id="T_4db9a7fb_2ad4_11ed_90b5_d4bed961474drow8_col1" class="data row8 col1" >gliss hair repair ultimate oil elixir structure build treatment</td>
#                         <td id="T_4db9a7fb_2ad4_11ed_90b5_d4bed961474drow8_col2" class="data row8 col2" >all natural probiotics shampoo bar for oily hair</td>
#             </tr>
#             <tr>
#                         <th id="T_4db9a7fb_2ad4_11ed_90b5_d4bed961474dlevel0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_4db9a7fb_2ad4_11ed_90b5_d4bed961474drow9_col0" class="data row9 col0" >gliss hair repair intense therapy bond repair mask</td>
#                         <td id="T_4db9a7fb_2ad4_11ed_90b5_d4bed961474drow9_col1" class="data row9 col1" >gliss hair repair intense therapy bond repair mask</td>
#                         <td id="T_4db9a7fb_2ad4_11ed_90b5_d4bed961474drow9_col2" class="data row9 col2" >premium henna hair treatment</td>
#             </tr>
#     </tbody></table>

# %%
#https://pypi.org/project/prettytable/
from prettytable import PrettyTable

table=PrettyTable()

# adding title to table
table.title='Similar Products for: '+ tfidf_57['product'].values[0]
#adding columns to pretty table
table.add_column("TF-IDF",tfidf_57['product'].values[1:]) # indexing from [1:] first to end as 0th index has searched product
table.add_column("TF-IDF_W2V",tfidf_w2v_57['product'].values[1:])

table.align="l"
table._max_width = {"TF-IDF" :61, "TF-IDF_W2V" :64} # define width of columns
#https://stackoverflow.com/questions/59823203/how-can-i-define-the-width-of-a-column-prettytable-python

print(table)
# Out:
# +-----------------------------------------------------------------------------------------------------------------------------+
# |                                       Similar Products for: argan liquid gold hair spa                                      |
# +---------------------------------------------------------------+-------------------------------------------------------------+
# | TF-IDF                                                        | TF-IDF_W2V                                                  |
# +---------------------------------------------------------------+-------------------------------------------------------------+
# | cream anti hair loss                                          | hibiscus shampoo for dry hair                               |
# | argan oil conditioner                                         | hair oil for strong long thick hair                         |
# | avocado nourish mask for fragile hair                         | advansed gold coconut hair oil                              |
# | argan oil shampoo                                             | garnier hair color shade natural black loreal paris shampoo |
# | hibiscus shampoo for dry hair                                 | royal gold facial kit for dry skin single time use          |
# | tea tree shampoo for dandruff                                 | royal gold facial kit for oily skin single time use         |
# | honey moisture mask for dry damaged hair                      | royal gold facial kit for oily skin single time use         |
# | premium henna hair treatment                                  | herbal green tea aloevera hair conditioner sls paraben free |
# | gliss hair repair ultimate oil elixir structure build         | all natural probiotics shampoo bar for oily hair            |
# | treatment                                                     |                                                             |
# | gliss hair repair intense therapy bond repair mask            | premium henna hair treatment                                |
# +---------------------------------------------------------------+-------------------------------------------------------------+

# %% [markdown]
# - <span style='color:red'>**Randomly checking for other products**

# %%
# checking for prod_index 18623 , top 10 similar items
bow_18623=bag_of_words_product_with_discount(18623,11)
tfidf_18623=tfidf_product(18623,11)
tfidf_w2v_18623=tfidf_w2v_product(18623,11)
# Out:
# The searched\Queried product is:
#  18623 : cookies italian biscotti
#
# Top 10 Similar products for "cookies italian biscotti" are:
# ======================================================================
#
# 16664 : cookies almond roasted
# Cosine Similarity with queried product is : 0.999902
# Discount %:  20.0
# --------------------------------------------------
#
# 3853 : cookies butter pista
# Cosine Similarity with queried product is : 0.999924
# Discount %:  10.0
# --------------------------------------------------
#
# 15398 : artisanal cookies seasons greetings
# Cosine Similarity with queried product is : 0.999877
# Discount %:  10.0
# --------------------------------------------------
#
# 26398 : peanut butter cookies
# Cosine Similarity with queried product is : 0.999891
# Discount %:  0.0
# --------------------------------------------------
#
# 22473 : cookies oats
# Cosine Similarity with queried product is : 0.999889
# Discount %:  0.0
# --------------------------------------------------
#
# 10682 : cookies kesar supreme
# Cosine Similarity with queried product is : 0.999885
# Discount %:  0.0
# --------------------------------------------------
#
# 4404 : cookies assorted
# Cosine Similarity with queried product is : 0.99986
# Discount %:  0.0
# --------------------------------------------------
#
# 15231 : dark chocolate cookies
# Cosine Similarity with queried product is : 0.999854
# Discount %:  0.0
# --------------------------------------------------
#
# 15267 : cashew cookies
# Cosine Similarity with queried product is : 0.999846
# Discount %:  0.0
# --------------------------------------------------
#
# 17415 : whole wheat cookies choco chip
# Cosine Similarity with queried product is : 0.999845
# Discount %:  0.0
# --------------------------------------------------
#
# The searched\Queried product is:
#  18623 :
#  product                                   cookies italian biscotti
# category                                        bakery_cakes_dairy
# sub_category                                    cookies_rusk_khari
# brand                                             lovelybakestudio
# type                                        bakerybiscuits_cookies
# description      eggless premium quality almonds are twice bake...
# sale_price                                                   166.5
# discount_%                                                      10
# negative                                                         0
# neutral                                                      0.845
# positive                                                     0.155
# compound                                                    0.8834
# cluster_label                                                    7
# Name: 18623, dtype: object
#
# Top 10 Similar products for "cookies italian biscotti" are:
# ======================================================================
#
# 21724 : cookies honey corn flakes
# Cosine Similarity with queried product is : 0.999912
# Discount %:  40.1606
# --------------------------------------------------
#
# 16664 : cookies almond roasted
# Cosine Similarity with queried product is : 0.999954
# Discount %:  20.0
# --------------------------------------------------
#
# 14094 : fresho signature plain bread stick happy chef pasta sauce arrabiata
# Cosine Similarity with queried product is : 0.999925
# Discount %:  17.0561
# --------------------------------------------------
#
# 6198 : assorted cookies fruit nut choc chip
# Cosine Similarity with queried product is : 0.999932
# Discount %:  15.0
# --------------------------------------------------
#
# 3853 : cookies butter pista
# Cosine Similarity with queried product is : 0.999968
# Discount %:  10.0
# --------------------------------------------------
#
# 15398 : artisanal cookies seasons greetings
# Cosine Similarity with queried product is : 0.999933
# Discount %:  10.0
# --------------------------------------------------
#
# 26398 : peanut butter cookies
# Cosine Similarity with queried product is : 0.999936
# Discount %:  0.0
# --------------------------------------------------
#
# 10682 : cookies kesar supreme
# Cosine Similarity with queried product is : 0.99993
# Discount %:  0.0
# --------------------------------------------------
#
# 17415 : whole wheat cookies choco chip
# Cosine Similarity with queried product is : 0.999929
# Discount %:  0.0
# --------------------------------------------------
#
# 22473 : cookies oats
# Cosine Similarity with queried product is : 0.999919
# Discount %:  0.0
# --------------------------------------------------
#
# The searched/Queried product is:
#  18623 : cookies italian biscotti
#
# Top 10 Similar products for "cookies italian biscotti" are:
# ======================================================================
#
# 3031 : organic foxtail millet italian thinai rice
# Cosine Similarity with queried product is : 0.99952
# Discount %:  30.5019
# --------------------------------------------------
#
# 6982 : organic foxtail millet italian thinai rice
# Cosine Similarity with queried product is : 0.99952
# Discount %:  30.5019
# --------------------------------------------------
#
# 14094 : fresho signature plain bread stick happy chef pasta sauce arrabiata
# Cosine Similarity with queried product is : 0.999608
# Discount %:  17.0561
# --------------------------------------------------
#
# 13810 : fresho signature plain bread stick happy chef pasta sauce arrabiata
# Cosine Similarity with queried product is : 0.999574
# Discount %:  17.0561
# --------------------------------------------------
#
# 6198 : assorted cookies fruit nut choc chip
# Cosine Similarity with queried product is : 0.999537
# Discount %:  15.0
# --------------------------------------------------
#
# 3853 : cookies butter pista
# Cosine Similarity with queried product is : 0.999553
# Discount %:  10.0
# --------------------------------------------------
#
# 17415 : whole wheat cookies choco chip
# Cosine Similarity with queried product is : 0.999566
# Discount %:  0.0
# --------------------------------------------------
#
# 15231 : dark chocolate cookies
# Cosine Similarity with queried product is : 0.999547
# Discount %:  0.0
# --------------------------------------------------
#
# 15845 : artisanal cookies
# Cosine Similarity with queried product is : 0.999525
# Discount %:  0.0
# --------------------------------------------------
#
# 4322 : quadratini wafer cookies chocolate
# Cosine Similarity with queried product is : 0.999508
# Discount %:  0.0
# --------------------------------------------------

# %%
#Summarizing the results of all 3 methods
prod_index=18623
d=pd.DataFrame({'BOW':bow_18623['product'].values[1:],'TF-IDF':tfidf_18623['product'].values[1:], \
                'TF-IDF_W2V':tfidf_w2v_18623['product'].values[1:]})
# setting caption(title) to dataframe
d.style.set_caption('Similar products for : '+'" '+data['product'].loc[prod_index]+'"').set_table_styles([{'selector':'caption',
                                                                                         'props':[('color','black'),
                                                                                                  ('font-weight', 'bold'),
                                                                                                  ('text-align','left'),
                                                                                                 ('font-size', '16px')]}])
# Out:
# <style  type="text/css" >
#     #T_a630fe90_2ae2_11ed_a2b1_d4bed961474d caption {
#           color: black;
#           font-weight: bold;
#           text-align: left;
#           font-size: 16px;
#     }</style><table id="T_a630fe90_2ae2_11ed_a2b1_d4bed961474d" ><caption>Similar products for : " cookies italian biscotti"</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >BOW</th>        <th class="col_heading level0 col1" >TF-IDF</th>        <th class="col_heading level0 col2" >TF-IDF_W2V</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_a630fe90_2ae2_11ed_a2b1_d4bed961474dlevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_a630fe90_2ae2_11ed_a2b1_d4bed961474drow0_col0" class="data row0 col0" >cookies almond roasted</td>
#                         <td id="T_a630fe90_2ae2_11ed_a2b1_d4bed961474drow0_col1" class="data row0 col1" >cookies honey corn flakes</td>
#                         <td id="T_a630fe90_2ae2_11ed_a2b1_d4bed961474drow0_col2" class="data row0 col2" >organic foxtail millet italian thinai rice</td>
#             </tr>
#             <tr>
#                         <th id="T_a630fe90_2ae2_11ed_a2b1_d4bed961474dlevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_a630fe90_2ae2_11ed_a2b1_d4bed961474drow1_col0" class="data row1 col0" >cookies butter pista</td>
#                         <td id="T_a630fe90_2ae2_11ed_a2b1_d4bed961474drow1_col1" class="data row1 col1" >cookies almond roasted</td>
#                         <td id="T_a630fe90_2ae2_11ed_a2b1_d4bed961474drow1_col2" class="data row1 col2" >organic foxtail millet italian thinai rice</td>
#             </tr>
#             <tr>
#                         <th id="T_a630fe90_2ae2_11ed_a2b1_d4bed961474dlevel0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_a630fe90_2ae2_11ed_a2b1_d4bed961474drow2_col0" class="data row2 col0" >artisanal cookies seasons greetings</td>
#                         <td id="T_a630fe90_2ae2_11ed_a2b1_d4bed961474drow2_col1" class="data row2 col1" >fresho signature plain bread stick happy chef pasta sauce arrabiata</td>
#                         <td id="T_a630fe90_2ae2_11ed_a2b1_d4bed961474drow2_col2" class="data row2 col2" >fresho signature plain bread stick happy chef pasta sauce arrabiata</td>
#             </tr>
#             <tr>
#                         <th id="T_a630fe90_2ae2_11ed_a2b1_d4bed961474dlevel0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_a630fe90_2ae2_11ed_a2b1_d4bed961474drow3_col0" class="data row3 col0" >peanut butter cookies</td>
#                         <td id="T_a630fe90_2ae2_11ed_a2b1_d4bed961474drow3_col1" class="data row3 col1" >assorted cookies fruit nut choc chip</td>
#                         <td id="T_a630fe90_2ae2_11ed_a2b1_d4bed961474drow3_col2" class="data row3 col2" >fresho signature plain bread stick happy chef pasta sauce arrabiata</td>
#             </tr>
#             <tr>
#                         <th id="T_a630fe90_2ae2_11ed_a2b1_d4bed961474dlevel0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_a630fe90_2ae2_11ed_a2b1_d4bed961474drow4_col0" class="data row4 col0" >cookies oats</td>
#                         <td id="T_a630fe90_2ae2_11ed_a2b1_d4bed961474drow4_col1" class="data row4 col1" >cookies butter pista</td>
#                         <td id="T_a630fe90_2ae2_11ed_a2b1_d4bed961474drow4_col2" class="data row4 col2" >assorted cookies fruit nut choc chip</td>
#             </tr>
#             <tr>
#                         <th id="T_a630fe90_2ae2_11ed_a2b1_d4bed961474dlevel0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_a630fe90_2ae2_11ed_a2b1_d4bed961474drow5_col0" class="data row5 col0" >cookies kesar supreme</td>
#                         <td id="T_a630fe90_2ae2_11ed_a2b1_d4bed961474drow5_col1" class="data row5 col1" >artisanal cookies seasons greetings</td>
#                         <td id="T_a630fe90_2ae2_11ed_a2b1_d4bed961474drow5_col2" class="data row5 col2" >cookies butter pista</td>
#             </tr>
#             <tr>
#                         <th id="T_a630fe90_2ae2_11ed_a2b1_d4bed961474dlevel0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_a630fe90_2ae2_11ed_a2b1_d4bed961474drow6_col0" class="data row6 col0" >cookies assorted</td>
#                         <td id="T_a630fe90_2ae2_11ed_a2b1_d4bed961474drow6_col1" class="data row6 col1" >peanut butter cookies</td>
#                         <td id="T_a630fe90_2ae2_11ed_a2b1_d4bed961474drow6_col2" class="data row6 col2" >whole wheat cookies choco chip</td>
#             </tr>
#             <tr>
#                         <th id="T_a630fe90_2ae2_11ed_a2b1_d4bed961474dlevel0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_a630fe90_2ae2_11ed_a2b1_d4bed961474drow7_col0" class="data row7 col0" >dark chocolate cookies</td>
#                         <td id="T_a630fe90_2ae2_11ed_a2b1_d4bed961474drow7_col1" class="data row7 col1" >cookies kesar supreme</td>
#                         <td id="T_a630fe90_2ae2_11ed_a2b1_d4bed961474drow7_col2" class="data row7 col2" >dark chocolate cookies</td>
#             </tr>
#             <tr>
#                         <th id="T_a630fe90_2ae2_11ed_a2b1_d4bed961474dlevel0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_a630fe90_2ae2_11ed_a2b1_d4bed961474drow8_col0" class="data row8 col0" >cashew cookies</td>
#                         <td id="T_a630fe90_2ae2_11ed_a2b1_d4bed961474drow8_col1" class="data row8 col1" >whole wheat cookies choco chip</td>
#                         <td id="T_a630fe90_2ae2_11ed_a2b1_d4bed961474drow8_col2" class="data row8 col2" >artisanal cookies</td>
#             </tr>
#             <tr>
#                         <th id="T_a630fe90_2ae2_11ed_a2b1_d4bed961474dlevel0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_a630fe90_2ae2_11ed_a2b1_d4bed961474drow9_col0" class="data row9 col0" >whole wheat cookies choco chip</td>
#                         <td id="T_a630fe90_2ae2_11ed_a2b1_d4bed961474drow9_col1" class="data row9 col1" >cookies oats</td>
#                         <td id="T_a630fe90_2ae2_11ed_a2b1_d4bed961474drow9_col2" class="data row9 col2" >quadratini wafer cookies chocolate</td>
#             </tr>
#     </tbody></table>

# %%
# checking for prod_index 22349 , top 10 similar items
bow_22349=bag_of_words_product_with_discount(22349,11)
tfidf_22349=tfidf_product(22349,11)
tfidf_w2v_22349=tfidf_w2v_product(22349,11)
# Out:
# The searched\Queried product is:
#  22349 : keratin smooth conditioner
#
# Top 10 Similar products for "keratin smooth conditioner" are:
# ======================================================================
#
# 14101 : nourish replenish conditioner
# Cosine Similarity with queried product is : 0.999926
# Discount %:  25.0
# --------------------------------------------------
#
# 20866 : climate protection conditioner
# Cosine Similarity with queried product is : 0.9999
# Discount %:  25.0
# --------------------------------------------------
#
# 64 : aqua halo rejuvenating conditioner
# Cosine Similarity with queried product is : 0.999873
# Discount %:  25.0
# --------------------------------------------------
#
# 26061 : hair fall defense conditioner
# Cosine Similarity with queried product is : 0.99987
# Discount %:  22.8663
# --------------------------------------------------
#
# 924 : oil nourish conditioner
# Cosine Similarity with queried product is : 0.999884
# Discount %:  20.1005
# --------------------------------------------------
#
# 15459 : color protect conditioner
# Cosine Similarity with queried product is : 0.999884
# Discount %:  20.0
# --------------------------------------------------
#
# 11821 : aloe hair conditioner
# Cosine Similarity with queried product is : 0.999893
# Discount %:  0.0
# --------------------------------------------------
#
# 417 : conditioner hair repair
# Cosine Similarity with queried product is : 0.999886
# Discount %:  0.0
# --------------------------------------------------
#
# 15535 : satreetha shampoo
# Cosine Similarity with queried product is : 0.999873
# Discount %:  0.0
# --------------------------------------------------
#
# 15427 : conditioning shampoo
# Cosine Similarity with queried product is : 0.999873
# Discount %:  0.0
# --------------------------------------------------
#
# The searched\Queried product is:
#  22349 :
#  product                                 keratin smooth conditioner
# category                                            beauty_hygiene
# sub_category                                              haircare
# brand                                                     tresemme
# type                                           shampoo_conditioner
# description      deep condition your hair and protect them from...
# sale_price                                                     165
# discount_%                                                      25
# negative                                                     0.036
# neutral                                                      0.801
# positive                                                     0.163
# compound                                                    0.9794
# cluster_label                                                    7
# Name: 22349, dtype: object
#
# Top 10 Similar products for "keratin smooth conditioner" are:
# ======================================================================
#
# 14101 : nourish replenish conditioner
# Cosine Similarity with queried product is : 0.999971
# Discount %:  25.0
# --------------------------------------------------
#
# 20866 : climate protection conditioner
# Cosine Similarity with queried product is : 0.999951
# Discount %:  25.0
# --------------------------------------------------
#
# 64 : aqua halo rejuvenating conditioner
# Cosine Similarity with queried product is : 0.999933
# Discount %:  25.0
# --------------------------------------------------
#
# 26061 : hair fall defense conditioner
# Cosine Similarity with queried product is : 0.999946
# Discount %:  22.8663
# --------------------------------------------------
#
# 924 : oil nourish conditioner
# Cosine Similarity with queried product is : 0.999933
# Discount %:  20.1005
# --------------------------------------------------
#
# 15459 : color protect conditioner
# Cosine Similarity with queried product is : 0.999933
# Discount %:  20.0
# --------------------------------------------------
#
# 1568 : herbal orange lemongrass hair conditioner
# Cosine Similarity with queried product is : 0.999933
# Discount %:  5.0
# --------------------------------------------------
#
# 11821 : aloe hair conditioner
# Cosine Similarity with queried product is : 0.999938
# Discount %:  0.0
# --------------------------------------------------
#
# 417 : conditioner hair repair
# Cosine Similarity with queried product is : 0.999934
# Discount %:  0.0
# --------------------------------------------------
#
# 19337 : fructis long strong strengthening conditioner
# Cosine Similarity with queried product is : 0.999933
# Discount %:  0.0
# --------------------------------------------------
#
# The searched/Queried product is:
#  22349 : keratin smooth conditioner
#
# Top 10 Similar products for "keratin smooth conditioner" are:
# ======================================================================
#
# 924 : oil nourish conditioner
# Cosine Similarity with queried product is : 0.999589
# Discount %:  20.1005
# --------------------------------------------------
#
# 15459 : color protect conditioner
# Cosine Similarity with queried product is : 0.999606
# Discount %:  20.0
# --------------------------------------------------
#
# 5700 : advanced hair fall control conditioner
# Cosine Similarity with queried product is : 0.999583
# Discount %:  17.0
# --------------------------------------------------
#
# 1568 : herbal orange lemongrass hair conditioner
# Cosine Similarity with queried product is : 0.99967
# Discount %:  5.0
# --------------------------------------------------
#
# 18814 : silky smooth care shampoo conditioner
# Cosine Similarity with queried product is : 0.999837
# Discount %:  0.0
# --------------------------------------------------
#
# 11821 : aloe hair conditioner
# Cosine Similarity with queried product is : 0.99965
# Discount %:  0.0
# --------------------------------------------------
#
# 16553 : keratin smooth conditioner
# Cosine Similarity with queried product is : 0.999649
# Discount %:  0.0
# --------------------------------------------------
#
# 9386 : conditioner lusciously thick long nourishing
# Cosine Similarity with queried product is : 0.999632
# Discount %:  0.0
# --------------------------------------------------
#
# 25728 : hair conditioner green tea with aloevera
# Cosine Similarity with queried product is : 0.999625
# Discount %:  0.0
# --------------------------------------------------
#
# 19337 : fructis long strong strengthening conditioner
# Cosine Similarity with queried product is : 0.999583
# Discount %:  0.0
# --------------------------------------------------

# %%
#Summarizing the results of all 3 methods
prod_index=22349
d=pd.DataFrame({'BOW':bow_22349['product'].values[1:],'TF-IDF':tfidf_22349['product'].values[1:], \
                'TF-IDF_W2V':tfidf_w2v_22349['product'].values[1:]})
# setting caption(title) to dataframe
d.style.set_caption('Similar products for : '+'" '+data['product'].loc[prod_index]+'"').set_table_styles([{'selector':'caption',
                                                                                         'props':[('color','black'),
                                                                                                  ('font-weight', 'bold'),
                                                                                                  ('text-align','left'),
                                                                                                 ('font-size', '16px')]}])
# Out:
# <style  type="text/css" >
#     #T_0dfb6591_2ae3_11ed_83dd_d4bed961474d caption {
#           color: black;
#           font-weight: bold;
#           text-align: left;
#           font-size: 16px;
#     }</style><table id="T_0dfb6591_2ae3_11ed_83dd_d4bed961474d" ><caption>Similar products for : " keratin smooth conditioner"</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >BOW</th>        <th class="col_heading level0 col1" >TF-IDF</th>        <th class="col_heading level0 col2" >TF-IDF_W2V</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_0dfb6591_2ae3_11ed_83dd_d4bed961474dlevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_0dfb6591_2ae3_11ed_83dd_d4bed961474drow0_col0" class="data row0 col0" >nourish replenish conditioner</td>
#                         <td id="T_0dfb6591_2ae3_11ed_83dd_d4bed961474drow0_col1" class="data row0 col1" >nourish replenish conditioner</td>
#                         <td id="T_0dfb6591_2ae3_11ed_83dd_d4bed961474drow0_col2" class="data row0 col2" >oil nourish conditioner</td>
#             </tr>
#             <tr>
#                         <th id="T_0dfb6591_2ae3_11ed_83dd_d4bed961474dlevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_0dfb6591_2ae3_11ed_83dd_d4bed961474drow1_col0" class="data row1 col0" >climate protection conditioner</td>
#                         <td id="T_0dfb6591_2ae3_11ed_83dd_d4bed961474drow1_col1" class="data row1 col1" >climate protection conditioner</td>
#                         <td id="T_0dfb6591_2ae3_11ed_83dd_d4bed961474drow1_col2" class="data row1 col2" >color protect conditioner</td>
#             </tr>
#             <tr>
#                         <th id="T_0dfb6591_2ae3_11ed_83dd_d4bed961474dlevel0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_0dfb6591_2ae3_11ed_83dd_d4bed961474drow2_col0" class="data row2 col0" >aqua halo rejuvenating conditioner</td>
#                         <td id="T_0dfb6591_2ae3_11ed_83dd_d4bed961474drow2_col1" class="data row2 col1" >aqua halo rejuvenating conditioner</td>
#                         <td id="T_0dfb6591_2ae3_11ed_83dd_d4bed961474drow2_col2" class="data row2 col2" >advanced hair fall control conditioner</td>
#             </tr>
#             <tr>
#                         <th id="T_0dfb6591_2ae3_11ed_83dd_d4bed961474dlevel0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_0dfb6591_2ae3_11ed_83dd_d4bed961474drow3_col0" class="data row3 col0" >hair fall defense conditioner</td>
#                         <td id="T_0dfb6591_2ae3_11ed_83dd_d4bed961474drow3_col1" class="data row3 col1" >hair fall defense conditioner</td>
#                         <td id="T_0dfb6591_2ae3_11ed_83dd_d4bed961474drow3_col2" class="data row3 col2" >herbal orange lemongrass hair conditioner</td>
#             </tr>
#             <tr>
#                         <th id="T_0dfb6591_2ae3_11ed_83dd_d4bed961474dlevel0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_0dfb6591_2ae3_11ed_83dd_d4bed961474drow4_col0" class="data row4 col0" >oil nourish conditioner</td>
#                         <td id="T_0dfb6591_2ae3_11ed_83dd_d4bed961474drow4_col1" class="data row4 col1" >oil nourish conditioner</td>
#                         <td id="T_0dfb6591_2ae3_11ed_83dd_d4bed961474drow4_col2" class="data row4 col2" >silky smooth care shampoo conditioner</td>
#             </tr>
#             <tr>
#                         <th id="T_0dfb6591_2ae3_11ed_83dd_d4bed961474dlevel0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_0dfb6591_2ae3_11ed_83dd_d4bed961474drow5_col0" class="data row5 col0" >color protect conditioner</td>
#                         <td id="T_0dfb6591_2ae3_11ed_83dd_d4bed961474drow5_col1" class="data row5 col1" >color protect conditioner</td>
#                         <td id="T_0dfb6591_2ae3_11ed_83dd_d4bed961474drow5_col2" class="data row5 col2" >aloe hair conditioner</td>
#             </tr>
#             <tr>
#                         <th id="T_0dfb6591_2ae3_11ed_83dd_d4bed961474dlevel0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_0dfb6591_2ae3_11ed_83dd_d4bed961474drow6_col0" class="data row6 col0" >aloe hair conditioner</td>
#                         <td id="T_0dfb6591_2ae3_11ed_83dd_d4bed961474drow6_col1" class="data row6 col1" >herbal orange lemongrass hair conditioner</td>
#                         <td id="T_0dfb6591_2ae3_11ed_83dd_d4bed961474drow6_col2" class="data row6 col2" >keratin smooth conditioner</td>
#             </tr>
#             <tr>
#                         <th id="T_0dfb6591_2ae3_11ed_83dd_d4bed961474dlevel0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_0dfb6591_2ae3_11ed_83dd_d4bed961474drow7_col0" class="data row7 col0" >conditioner hair repair</td>
#                         <td id="T_0dfb6591_2ae3_11ed_83dd_d4bed961474drow7_col1" class="data row7 col1" >aloe hair conditioner</td>
#                         <td id="T_0dfb6591_2ae3_11ed_83dd_d4bed961474drow7_col2" class="data row7 col2" >conditioner lusciously thick long nourishing</td>
#             </tr>
#             <tr>
#                         <th id="T_0dfb6591_2ae3_11ed_83dd_d4bed961474dlevel0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_0dfb6591_2ae3_11ed_83dd_d4bed961474drow8_col0" class="data row8 col0" >satreetha shampoo</td>
#                         <td id="T_0dfb6591_2ae3_11ed_83dd_d4bed961474drow8_col1" class="data row8 col1" >conditioner hair repair</td>
#                         <td id="T_0dfb6591_2ae3_11ed_83dd_d4bed961474drow8_col2" class="data row8 col2" >hair conditioner green tea with aloevera</td>
#             </tr>
#             <tr>
#                         <th id="T_0dfb6591_2ae3_11ed_83dd_d4bed961474dlevel0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_0dfb6591_2ae3_11ed_83dd_d4bed961474drow9_col0" class="data row9 col0" >conditioning shampoo</td>
#                         <td id="T_0dfb6591_2ae3_11ed_83dd_d4bed961474drow9_col1" class="data row9 col1" >fructis long strong strengthening conditioner</td>
#                         <td id="T_0dfb6591_2ae3_11ed_83dd_d4bed961474drow9_col2" class="data row9 col2" >fructis long strong strengthening conditioner</td>
#             </tr>
#     </tbody></table>

# %%
# checking for prod_index 789 , top 10 similar items
bow_789=bag_of_words_product_with_discount(789,11)
tfidf_789=tfidf_product(789,11)
tfidf_w2v_789=tfidf_w2v_product(789,11)
# Out:
# The searched\Queried product is:
#  789 : tomato salsa dip enjoy with nacho chips
#
# Top 10 Similar products for "tomato salsa dip enjoy with nacho chips" are:
# ======================================================================
#
# 11994 : yummy dip out
# Cosine Similarity with queried product is : 0.999797
# Discount %:  20.0
# --------------------------------------------------
#
# 22526 : pizza foundue dip cheese
# Cosine Similarity with queried product is : 0.999779
# Discount %:  20.0
# --------------------------------------------------
#
# 5431 : yogurt dip cilantro jalapeno
# Cosine Similarity with queried product is : 0.999778
# Discount %:  20.0
# --------------------------------------------------
#
# 4439 : dip hot cheese
# Cosine Similarity with queried product is : 0.999764
# Discount %:  20.0
# --------------------------------------------------
#
# 3005 : very creamy salsa spicy chipotle
# Cosine Similarity with queried product is : 0.999761
# Discount %:  20.0
# --------------------------------------------------
#
# 5516 : ranch mint herb
# Cosine Similarity with queried product is : 0.999758
# Discount %:  20.0
# --------------------------------------------------
#
# 347 : chunky salsa mild
# Cosine Similarity with queried product is : 0.999765
# Discount %:  15.0
# --------------------------------------------------
#
# 19954 : chunky salsa hot
# Cosine Similarity with queried product is : 0.999765
# Discount %:  15.0
# --------------------------------------------------
#
# 22781 : soy with chilli
# Cosine Similarity with queried product is : 0.999763
# Discount %:  0.0
# --------------------------------------------------
#
# 7745 : sriracha dip sauce
# Cosine Similarity with queried product is : 0.999761
# Discount %:  0.0
# --------------------------------------------------
#
# The searched\Queried product is:
#  789 :
#  product                    tomato salsa dip enjoy with nacho chips
# category                                         gourmet_worldfood
# sub_category                                   sauces_spreads_dips
# brand                                                     habanero
# type                                        hummus_cheese_salsadip
# description      traditional mexican style family gathering hav...
# sale_price                                                   157.5
# discount_%                                                      10
# negative                                                         0
# neutral                                                      0.857
# positive                                                     0.143
# compound                                                    0.7184
# cluster_label                                                    7
# Name: 789, dtype: object
#
# Top 10 Similar products for "tomato salsa dip enjoy with nacho chips" are:
# ======================================================================
#
# 15737 : all natural salsa peri peri salsa
# Cosine Similarity with queried product is : 0.999932
# Discount %:  20.0
# --------------------------------------------------
#
# 12246 : very cheesy salsa salsa con queso
# Cosine Similarity with queried product is : 0.999929
# Discount %:  20.0
# --------------------------------------------------
#
# 3005 : very creamy salsa spicy chipotle
# Cosine Similarity with queried product is : 0.999928
# Discount %:  20.0
# --------------------------------------------------
#
# 22526 : pizza foundue dip cheese
# Cosine Similarity with queried product is : 0.999925
# Discount %:  20.0
# --------------------------------------------------
#
# 11994 : yummy dip out
# Cosine Similarity with queried product is : 0.999925
# Discount %:  20.0
# --------------------------------------------------
#
# 5431 : yogurt dip cilantro jalapeno
# Cosine Similarity with queried product is : 0.999925
# Discount %:  20.0
# --------------------------------------------------
#
# 8799 : all natural hummus spicy sriracha
# Cosine Similarity with queried product is : 0.99992
# Discount %:  20.0
# --------------------------------------------------
#
# 16573 : all natural hummus fresh hummus
# Cosine Similarity with queried product is : 0.999919
# Discount %:  20.0
# --------------------------------------------------
#
# 5516 : ranch mint herb
# Cosine Similarity with queried product is : 0.999918
# Discount %:  20.0
# --------------------------------------------------
#
# 3854 : all natural hummus roasted garlic
# Cosine Similarity with queried product is : 0.999917
# Discount %:  20.0
# --------------------------------------------------
#
# The searched/Queried product is:
#  789 : tomato salsa dip enjoy with nacho chips
#
# Top 10 Similar products for "tomato salsa dip enjoy with nacho chips" are:
# ======================================================================
#
# 26463 : very cheesy dip pepper jack
# Cosine Similarity with queried product is : 0.999784
# Discount %:  20.0
# --------------------------------------------------
#
# 3005 : very creamy salsa spicy chipotle
# Cosine Similarity with queried product is : 0.999781
# Discount %:  20.0
# --------------------------------------------------
#
# 12246 : very cheesy salsa salsa con queso
# Cosine Similarity with queried product is : 0.999761
# Discount %:  20.0
# --------------------------------------------------
#
# 8799 : all natural hummus spicy sriracha
# Cosine Similarity with queried product is : 0.999754
# Discount %:  20.0
# --------------------------------------------------
#
# 22526 : pizza foundue dip cheese
# Cosine Similarity with queried product is : 0.999751
# Discount %:  20.0
# --------------------------------------------------
#
# 11994 : yummy dip out
# Cosine Similarity with queried product is : 0.99975
# Discount %:  20.0
# --------------------------------------------------
#
# 3854 : all natural hummus roasted garlic
# Cosine Similarity with queried product is : 0.999726
# Discount %:  20.0
# --------------------------------------------------
#
# 15737 : all natural salsa peri peri salsa
# Cosine Similarity with queried product is : 0.999701
# Discount %:  20.0
# --------------------------------------------------
#
# 4439 : dip hot cheese
# Cosine Similarity with queried product is : 0.999694
# Discount %:  20.0
# --------------------------------------------------
#
# 4848 : potato crisp chips hot spicy
# Cosine Similarity with queried product is : 0.999692
# Discount %:  0.0
# --------------------------------------------------

# %%
#Summarizing the results of all 3 methods
prod_index=789
d=pd.DataFrame({'BOW':bow_789['product'].values[1:],'TF-IDF':tfidf_789['product'].values[1:], \
                'TF-IDF_W2V':tfidf_w2v_789['product'].values[1:]})
# setting caption(title) to dataframe
d.style.set_caption('Similar products for : '+'" '+data['product'].loc[prod_index]+'"').set_table_styles([{'selector':'caption',
                                                                                         'props':[('color','black'),
                                                                                                  ('font-weight', 'bold'),
                                                                                                  ('text-align','left'),
                                                                                                 ('font-size', '16px')]}])
# Out:
# <style  type="text/css" >
#     #T_4fdc745a_2ae3_11ed_9e75_d4bed961474d caption {
#           color: black;
#           font-weight: bold;
#           text-align: left;
#           font-size: 16px;
#     }</style><table id="T_4fdc745a_2ae3_11ed_9e75_d4bed961474d" ><caption>Similar products for : " tomato salsa dip enjoy with nacho chips"</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >BOW</th>        <th class="col_heading level0 col1" >TF-IDF</th>        <th class="col_heading level0 col2" >TF-IDF_W2V</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_4fdc745a_2ae3_11ed_9e75_d4bed961474dlevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_4fdc745a_2ae3_11ed_9e75_d4bed961474drow0_col0" class="data row0 col0" >yummy dip out</td>
#                         <td id="T_4fdc745a_2ae3_11ed_9e75_d4bed961474drow0_col1" class="data row0 col1" >all natural salsa peri peri salsa</td>
#                         <td id="T_4fdc745a_2ae3_11ed_9e75_d4bed961474drow0_col2" class="data row0 col2" >very cheesy dip pepper jack</td>
#             </tr>
#             <tr>
#                         <th id="T_4fdc745a_2ae3_11ed_9e75_d4bed961474dlevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_4fdc745a_2ae3_11ed_9e75_d4bed961474drow1_col0" class="data row1 col0" >pizza foundue dip cheese</td>
#                         <td id="T_4fdc745a_2ae3_11ed_9e75_d4bed961474drow1_col1" class="data row1 col1" >very cheesy salsa salsa con queso</td>
#                         <td id="T_4fdc745a_2ae3_11ed_9e75_d4bed961474drow1_col2" class="data row1 col2" >very creamy salsa spicy chipotle</td>
#             </tr>
#             <tr>
#                         <th id="T_4fdc745a_2ae3_11ed_9e75_d4bed961474dlevel0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_4fdc745a_2ae3_11ed_9e75_d4bed961474drow2_col0" class="data row2 col0" >yogurt dip cilantro jalapeno</td>
#                         <td id="T_4fdc745a_2ae3_11ed_9e75_d4bed961474drow2_col1" class="data row2 col1" >very creamy salsa spicy chipotle</td>
#                         <td id="T_4fdc745a_2ae3_11ed_9e75_d4bed961474drow2_col2" class="data row2 col2" >very cheesy salsa salsa con queso</td>
#             </tr>
#             <tr>
#                         <th id="T_4fdc745a_2ae3_11ed_9e75_d4bed961474dlevel0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_4fdc745a_2ae3_11ed_9e75_d4bed961474drow3_col0" class="data row3 col0" >dip hot cheese</td>
#                         <td id="T_4fdc745a_2ae3_11ed_9e75_d4bed961474drow3_col1" class="data row3 col1" >pizza foundue dip cheese</td>
#                         <td id="T_4fdc745a_2ae3_11ed_9e75_d4bed961474drow3_col2" class="data row3 col2" >all natural hummus spicy sriracha</td>
#             </tr>
#             <tr>
#                         <th id="T_4fdc745a_2ae3_11ed_9e75_d4bed961474dlevel0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_4fdc745a_2ae3_11ed_9e75_d4bed961474drow4_col0" class="data row4 col0" >very creamy salsa spicy chipotle</td>
#                         <td id="T_4fdc745a_2ae3_11ed_9e75_d4bed961474drow4_col1" class="data row4 col1" >yummy dip out</td>
#                         <td id="T_4fdc745a_2ae3_11ed_9e75_d4bed961474drow4_col2" class="data row4 col2" >pizza foundue dip cheese</td>
#             </tr>
#             <tr>
#                         <th id="T_4fdc745a_2ae3_11ed_9e75_d4bed961474dlevel0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_4fdc745a_2ae3_11ed_9e75_d4bed961474drow5_col0" class="data row5 col0" >ranch mint herb</td>
#                         <td id="T_4fdc745a_2ae3_11ed_9e75_d4bed961474drow5_col1" class="data row5 col1" >yogurt dip cilantro jalapeno</td>
#                         <td id="T_4fdc745a_2ae3_11ed_9e75_d4bed961474drow5_col2" class="data row5 col2" >yummy dip out</td>
#             </tr>
#             <tr>
#                         <th id="T_4fdc745a_2ae3_11ed_9e75_d4bed961474dlevel0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_4fdc745a_2ae3_11ed_9e75_d4bed961474drow6_col0" class="data row6 col0" >chunky salsa mild</td>
#                         <td id="T_4fdc745a_2ae3_11ed_9e75_d4bed961474drow6_col1" class="data row6 col1" >all natural hummus spicy sriracha</td>
#                         <td id="T_4fdc745a_2ae3_11ed_9e75_d4bed961474drow6_col2" class="data row6 col2" >all natural hummus roasted garlic</td>
#             </tr>
#             <tr>
#                         <th id="T_4fdc745a_2ae3_11ed_9e75_d4bed961474dlevel0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_4fdc745a_2ae3_11ed_9e75_d4bed961474drow7_col0" class="data row7 col0" >chunky salsa hot</td>
#                         <td id="T_4fdc745a_2ae3_11ed_9e75_d4bed961474drow7_col1" class="data row7 col1" >all natural hummus fresh hummus</td>
#                         <td id="T_4fdc745a_2ae3_11ed_9e75_d4bed961474drow7_col2" class="data row7 col2" >all natural salsa peri peri salsa</td>
#             </tr>
#             <tr>
#                         <th id="T_4fdc745a_2ae3_11ed_9e75_d4bed961474dlevel0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_4fdc745a_2ae3_11ed_9e75_d4bed961474drow8_col0" class="data row8 col0" >soy with chilli</td>
#                         <td id="T_4fdc745a_2ae3_11ed_9e75_d4bed961474drow8_col1" class="data row8 col1" >ranch mint herb</td>
#                         <td id="T_4fdc745a_2ae3_11ed_9e75_d4bed961474drow8_col2" class="data row8 col2" >dip hot cheese</td>
#             </tr>
#             <tr>
#                         <th id="T_4fdc745a_2ae3_11ed_9e75_d4bed961474dlevel0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_4fdc745a_2ae3_11ed_9e75_d4bed961474drow9_col0" class="data row9 col0" >sriracha dip sauce</td>
#                         <td id="T_4fdc745a_2ae3_11ed_9e75_d4bed961474drow9_col1" class="data row9 col1" >all natural hummus roasted garlic</td>
#                         <td id="T_4fdc745a_2ae3_11ed_9e75_d4bed961474drow9_col2" class="data row9 col2" >potato crisp chips hot spicy</td>
#             </tr>
#     </tbody></table>

# %%
# checking for prod_index 6786 , top 10 similar items
bow_6786=bag_of_words_product_with_discount(6786,11)
tfidf_6786=tfidf_product(6786,11)
tfidf_w2v_6786=tfidf_w2v_product(6786,11)
# Out:
# The searched\Queried product is:
#  6786 : dressing thousand island
#
# Top 10 Similar products for "dressing thousand island" are:
# ======================================================================
#
# 14832 : thousand island dressing lite
# Cosine Similarity with queried product is : 0.999992
# Discount %:  0.0
# --------------------------------------------------
#
# 8328 : french dressing
# Cosine Similarity with queried product is : 0.999977
# Discount %:  0.0
# --------------------------------------------------
#
# 488 : dressing creamy caesar
# Cosine Similarity with queried product is : 0.999972
# Discount %:  0.0
# --------------------------------------------------
#
# 4733 : italian dressing less fat
# Cosine Similarity with queried product is : 0.999965
# Discount %:  0.0
# --------------------------------------------------
#
# 3757 : mayonnaise
# Cosine Similarity with queried product is : 0.999955
# Discount %:  0.0
# --------------------------------------------------
#
# 9203 : tulsi honey
# Cosine Similarity with queried product is : 0.999954
# Discount %:  0.0
# --------------------------------------------------
#
# 1427 : nutella ready
# Cosine Similarity with queried product is : 0.999953
# Discount %:  0.0
# --------------------------------------------------
#
# 22517 : red pepper sauce
# Cosine Similarity with queried product is : 0.999953
# Discount %:  0.0
# --------------------------------------------------
#
# 18661 : syrup pancake
# Cosine Similarity with queried product is : 0.999952
# Discount %:  0.0
# --------------------------------------------------
#
# 16290 : mayonnaise mayolite
# Cosine Similarity with queried product is : 0.99995
# Discount %:  0.0
# --------------------------------------------------
#
# The searched\Queried product is:
#  6786 :
#  product                                   dressing thousand island
# category                                         gourmet_worldfood
# sub_category                                   sauces_spreads_dips
# brand                                               americangarden
# type                                                saladdressings
# description      american garden thousand island takes you cook...
# sale_price                                                     270
# discount_%                                                       0
# negative                                                         0
# neutral                                                      0.893
# positive                                                     0.107
# compound                                                      0.34
# cluster_label                                                    6
# Name: 6786, dtype: object
#
# Top 10 Similar products for "dressing thousand island" are:
# ======================================================================
#
# 6304 : original recipe italian herb mayo
# Cosine Similarity with queried product is : 0.999971
# Discount %:  30.0
# --------------------------------------------------
#
# 14832 : thousand island dressing lite
# Cosine Similarity with queried product is : 0.999997
# Discount %:  0.0
# --------------------------------------------------
#
# 488 : dressing creamy caesar
# Cosine Similarity with queried product is : 0.99999
# Discount %:  0.0
# --------------------------------------------------
#
# 4733 : italian dressing less fat
# Cosine Similarity with queried product is : 0.999989
# Discount %:  0.0
# --------------------------------------------------
#
# 8328 : french dressing
# Cosine Similarity with queried product is : 0.999989
# Discount %:  0.0
# --------------------------------------------------
#
# 772 : peanut butter chunky
# Cosine Similarity with queried product is : 0.999972
# Discount %:  0.0
# --------------------------------------------------
#
# 20889 : barbeque sauce original
# Cosine Similarity with queried product is : 0.999971
# Discount %:  0.0
# --------------------------------------------------
#
# 18661 : syrup pancake
# Cosine Similarity with queried product is : 0.999971
# Discount %:  0.0
# --------------------------------------------------
#
# 22517 : red pepper sauce
# Cosine Similarity with queried product is : 0.999969
# Discount %:  0.0
# --------------------------------------------------
#
# 9203 : tulsi honey
# Cosine Similarity with queried product is : 0.999969
# Discount %:  0.0
# --------------------------------------------------
#
# The searched/Queried product is:
#  6786 : dressing thousand island
#
# Top 10 Similar products for "dressing thousand island" are:
# ======================================================================
#
# 7531 : olive oil extra virgin
# Cosine Similarity with queried product is : 0.99986
# Discount %:  58.6429
# --------------------------------------------------
#
# 25645 : san remo pasta disano olive oil american garden pasta sauce
# Cosine Similarity with queried product is : 0.999861
# Discount %:  32.3486
# --------------------------------------------------
#
# 3957 : spanish extra virgin olive oil
# Cosine Similarity with queried product is : 0.999863
# Discount %:  30.0
# --------------------------------------------------
#
# 11204 : cashew nuts whole natural premium king size
# Cosine Similarity with queried product is : 0.999861
# Discount %:  24.726
# --------------------------------------------------
#
# 10647 : chinese five spice powder shaker
# Cosine Similarity with queried product is : 0.999863
# Discount %:  10.0
# --------------------------------------------------
#
# 14832 : thousand island dressing lite
# Cosine Similarity with queried product is : 0.999979
# Discount %:  0.0
# --------------------------------------------------
#
# 4733 : italian dressing less fat
# Cosine Similarity with queried product is : 0.999888
# Discount %:  0.0
# --------------------------------------------------
#
# 22173 : phantom hot tomato ketchup sauce made with world hottest ghost pepper
# Cosine Similarity with queried product is : 0.999865
# Discount %:  0.0
# --------------------------------------------------
#
# 7620 : olive oil tomato and porcini mushroom pasta sauce with extra virgin
# Cosine Similarity with queried product is : 0.999862
# Discount %:  0.0
# --------------------------------------------------
#
# 27007 : american garden peanut butter chunky jar
# Cosine Similarity with queried product is : 0.999861
# Discount %:  0.0
# --------------------------------------------------

# %%
#Summarizing the results of all 3 methods
prod_index=6786
d=pd.DataFrame({'BOW':bow_6786['product'].values[1:],'TF-IDF':tfidf_6786['product'].values[1:], \
                'TF-IDF_W2V':tfidf_w2v_6786['product'].values[1:]})
# setting caption(title) to dataframe
d.style.set_caption('Similar products for : '+'" '+data['product'].loc[prod_index]+'"').set_table_styles([{'selector':'caption',
                                                                                         'props':[('color','black'),
                                                                                                  ('font-weight', 'bold'),
                                                                                                  ('text-align','left'),
                                                                                                 ('font-size', '16px')]}])
# Out:
# <style  type="text/css" >
#     #T_8b775d7a_2ae3_11ed_a47b_d4bed961474d caption {
#           color: black;
#           font-weight: bold;
#           text-align: left;
#           font-size: 16px;
#     }</style><table id="T_8b775d7a_2ae3_11ed_a47b_d4bed961474d" ><caption>Similar products for : " dressing thousand island"</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >BOW</th>        <th class="col_heading level0 col1" >TF-IDF</th>        <th class="col_heading level0 col2" >TF-IDF_W2V</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_8b775d7a_2ae3_11ed_a47b_d4bed961474dlevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_8b775d7a_2ae3_11ed_a47b_d4bed961474drow0_col0" class="data row0 col0" >thousand island dressing lite</td>
#                         <td id="T_8b775d7a_2ae3_11ed_a47b_d4bed961474drow0_col1" class="data row0 col1" >original recipe italian herb mayo</td>
#                         <td id="T_8b775d7a_2ae3_11ed_a47b_d4bed961474drow0_col2" class="data row0 col2" >olive oil extra virgin</td>
#             </tr>
#             <tr>
#                         <th id="T_8b775d7a_2ae3_11ed_a47b_d4bed961474dlevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_8b775d7a_2ae3_11ed_a47b_d4bed961474drow1_col0" class="data row1 col0" >french dressing</td>
#                         <td id="T_8b775d7a_2ae3_11ed_a47b_d4bed961474drow1_col1" class="data row1 col1" >thousand island dressing lite</td>
#                         <td id="T_8b775d7a_2ae3_11ed_a47b_d4bed961474drow1_col2" class="data row1 col2" >san remo pasta disano olive oil american garden pasta sauce</td>
#             </tr>
#             <tr>
#                         <th id="T_8b775d7a_2ae3_11ed_a47b_d4bed961474dlevel0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_8b775d7a_2ae3_11ed_a47b_d4bed961474drow2_col0" class="data row2 col0" >dressing creamy caesar</td>
#                         <td id="T_8b775d7a_2ae3_11ed_a47b_d4bed961474drow2_col1" class="data row2 col1" >dressing creamy caesar</td>
#                         <td id="T_8b775d7a_2ae3_11ed_a47b_d4bed961474drow2_col2" class="data row2 col2" >spanish extra virgin olive oil</td>
#             </tr>
#             <tr>
#                         <th id="T_8b775d7a_2ae3_11ed_a47b_d4bed961474dlevel0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_8b775d7a_2ae3_11ed_a47b_d4bed961474drow3_col0" class="data row3 col0" >italian dressing less fat</td>
#                         <td id="T_8b775d7a_2ae3_11ed_a47b_d4bed961474drow3_col1" class="data row3 col1" >italian dressing less fat</td>
#                         <td id="T_8b775d7a_2ae3_11ed_a47b_d4bed961474drow3_col2" class="data row3 col2" >cashew nuts whole natural premium king size</td>
#             </tr>
#             <tr>
#                         <th id="T_8b775d7a_2ae3_11ed_a47b_d4bed961474dlevel0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_8b775d7a_2ae3_11ed_a47b_d4bed961474drow4_col0" class="data row4 col0" >mayonnaise</td>
#                         <td id="T_8b775d7a_2ae3_11ed_a47b_d4bed961474drow4_col1" class="data row4 col1" >french dressing</td>
#                         <td id="T_8b775d7a_2ae3_11ed_a47b_d4bed961474drow4_col2" class="data row4 col2" >chinese five spice powder shaker</td>
#             </tr>
#             <tr>
#                         <th id="T_8b775d7a_2ae3_11ed_a47b_d4bed961474dlevel0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_8b775d7a_2ae3_11ed_a47b_d4bed961474drow5_col0" class="data row5 col0" >tulsi honey</td>
#                         <td id="T_8b775d7a_2ae3_11ed_a47b_d4bed961474drow5_col1" class="data row5 col1" >peanut butter chunky</td>
#                         <td id="T_8b775d7a_2ae3_11ed_a47b_d4bed961474drow5_col2" class="data row5 col2" >thousand island dressing lite</td>
#             </tr>
#             <tr>
#                         <th id="T_8b775d7a_2ae3_11ed_a47b_d4bed961474dlevel0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_8b775d7a_2ae3_11ed_a47b_d4bed961474drow6_col0" class="data row6 col0" >nutella ready</td>
#                         <td id="T_8b775d7a_2ae3_11ed_a47b_d4bed961474drow6_col1" class="data row6 col1" >barbeque sauce original</td>
#                         <td id="T_8b775d7a_2ae3_11ed_a47b_d4bed961474drow6_col2" class="data row6 col2" >italian dressing less fat</td>
#             </tr>
#             <tr>
#                         <th id="T_8b775d7a_2ae3_11ed_a47b_d4bed961474dlevel0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_8b775d7a_2ae3_11ed_a47b_d4bed961474drow7_col0" class="data row7 col0" >red pepper sauce</td>
#                         <td id="T_8b775d7a_2ae3_11ed_a47b_d4bed961474drow7_col1" class="data row7 col1" >syrup pancake</td>
#                         <td id="T_8b775d7a_2ae3_11ed_a47b_d4bed961474drow7_col2" class="data row7 col2" >phantom hot tomato ketchup sauce made with world hottest ghost pepper</td>
#             </tr>
#             <tr>
#                         <th id="T_8b775d7a_2ae3_11ed_a47b_d4bed961474dlevel0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_8b775d7a_2ae3_11ed_a47b_d4bed961474drow8_col0" class="data row8 col0" >syrup pancake</td>
#                         <td id="T_8b775d7a_2ae3_11ed_a47b_d4bed961474drow8_col1" class="data row8 col1" >red pepper sauce</td>
#                         <td id="T_8b775d7a_2ae3_11ed_a47b_d4bed961474drow8_col2" class="data row8 col2" >olive oil tomato and porcini mushroom pasta sauce with extra virgin</td>
#             </tr>
#             <tr>
#                         <th id="T_8b775d7a_2ae3_11ed_a47b_d4bed961474dlevel0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_8b775d7a_2ae3_11ed_a47b_d4bed961474drow9_col0" class="data row9 col0" >mayonnaise mayolite</td>
#                         <td id="T_8b775d7a_2ae3_11ed_a47b_d4bed961474drow9_col1" class="data row9 col1" >tulsi honey</td>
#                         <td id="T_8b775d7a_2ae3_11ed_a47b_d4bed961474drow9_col2" class="data row9 col2" >american garden peanut butter chunky jar</td>
#             </tr>
#     </tbody></table>

# %%
# checking for prod_index 2607 , top 10 similar items
bow_2607=bag_of_words_product_with_discount(2607,11)
tfidf_2607=tfidf_product(2607,11)
tfidf_w2v_2607=tfidf_w2v_product(2607,11)
# Out:
# The searched\Queried product is:
#  2607 : organic rava idli mix
#
# Top 10 Similar products for "organic rava idli mix" are:
# ======================================================================
#
# 11541 : instant mix rava idli
# Cosine Similarity with queried product is : 0.999615
# Discount %:  10.0
# --------------------------------------------------
#
# 3597 : organic masala rava idli ready mix
# Cosine Similarity with queried product is : 0.999746
# Discount %:  0.0
# --------------------------------------------------
#
# 9853 : organic rice idli ready
# Cosine Similarity with queried product is : 0.999591
# Discount %:  0.0
# --------------------------------------------------
#
# 23692 : ragi dosa mix
# Cosine Similarity with queried product is : 0.999561
# Discount %:  0.0
# --------------------------------------------------
#
# 24212 : breakfast mix upma
# Cosine Similarity with queried product is : 0.999561
# Discount %:  0.0
# --------------------------------------------------
#
# 20410 : mix millet pongal
# Cosine Similarity with queried product is : 0.999556
# Discount %:  0.0
# --------------------------------------------------
#
# 17737 : multigrain thalipeeth mix
# Cosine Similarity with queried product is : 0.999531
# Discount %:  0.0
# --------------------------------------------------
#
# 12169 : organic ragi dosa ready mix
# Cosine Similarity with queried product is : 0.999526
# Discount %:  0.0
# --------------------------------------------------
#
# 7218 : organic rice dosa ready mix
# Cosine Similarity with queried product is : 0.999525
# Discount %:  0.0
# --------------------------------------------------
#
# 16997 : ready mix sambar
# Cosine Similarity with queried product is : 0.999525
# Discount %:  0.0
# --------------------------------------------------
#
# The searched\Queried product is:
#  2607 :
#  product                                      organic rava idli mix
# category                                       snacks_brandedfoods
# sub_category                                       readytocook_eat
# brand                                             phaladapure_sure
# type                                          breakfast_snackmixes
# description      rava idli variation the popular south indian b...
# sale_price                                                      88
# discount_%                                                       0
# negative                                                      0.01
# neutral                                                      0.826
# positive                                                     0.164
# compound                                                    0.9744
# cluster_label                                                   14
# Name: 2607, dtype: object
#
# Top 10 Similar products for "organic rava idli mix" are:
# ======================================================================
#
# 7582 : breakfast mix oats pongal
# Cosine Similarity with queried product is : 0.999768
# Discount %:  28.8
# --------------------------------------------------
#
# 26671 : breakfast mix little millet upma
# Cosine Similarity with queried product is : 0.999763
# Discount %:  28.8
# --------------------------------------------------
#
# 2994 : breakfast mix little millet pongal
# Cosine Similarity with queried product is : 0.999762
# Discount %:  28.8
# --------------------------------------------------
#
# 8288 : specialty idli dosa batter
# Cosine Similarity with queried product is : 0.999765
# Discount %:  18.0952
# --------------------------------------------------
#
# 3597 : organic masala rava idli ready mix
# Cosine Similarity with queried product is : 0.999847
# Discount %:  0.0
# --------------------------------------------------
#
# 9853 : organic rice idli ready
# Cosine Similarity with queried product is : 0.999784
# Discount %:  0.0
# --------------------------------------------------
#
# 23692 : ragi dosa mix
# Cosine Similarity with queried product is : 0.99977
# Discount %:  0.0
# --------------------------------------------------
#
# 24212 : breakfast mix upma
# Cosine Similarity with queried product is : 0.999768
# Discount %:  0.0
# --------------------------------------------------
#
# 20410 : mix millet pongal
# Cosine Similarity with queried product is : 0.999764
# Discount %:  0.0
# --------------------------------------------------
#
# 7218 : organic rice dosa ready mix
# Cosine Similarity with queried product is : 0.999759
# Discount %:  0.0
# --------------------------------------------------
#
# The searched/Queried product is:
#  2607 : organic rava idli mix
#
# Top 10 Similar products for "organic rava idli mix" are:
# ======================================================================
#
# 168 : organic dosa mix jowar
# Cosine Similarity with queried product is : 0.999716
# Discount %:  0.0
# --------------------------------------------------
#
# 3597 : organic masala rava idli ready mix
# Cosine Similarity with queried product is : 0.999403
# Discount %:  0.0
# --------------------------------------------------
#
# 12169 : organic ragi dosa ready mix
# Cosine Similarity with queried product is : 0.999401
# Discount %:  0.0
# --------------------------------------------------
#
# 10347 : organic mix dal
# Cosine Similarity with queried product is : 0.999389
# Discount %:  0.0
# --------------------------------------------------
#
# 16854 : organic rice mix flaxseed
# Cosine Similarity with queried product is : 0.999361
# Discount %:  0.0
# --------------------------------------------------
#
# 20190 : organic dosa mix mixed millet
# Cosine Similarity with queried product is : 0.999343
# Discount %:  0.0
# --------------------------------------------------
#
# 7218 : organic rice dosa ready mix
# Cosine Similarity with queried product is : 0.99928
# Discount %:  0.0
# --------------------------------------------------
#
# 467 : organic rasam ready mix long pepper
# Cosine Similarity with queried product is : 0.999071
# Discount %:  0.0
# --------------------------------------------------
#
# 4598 : organic dosa mix little millet
# Cosine Similarity with queried product is : 0.999024
# Discount %:  0.0
# --------------------------------------------------
#
# 20562 : organic pongal mix foxtail millet
# Cosine Similarity with queried product is : 0.999016
# Discount %:  0.0
# --------------------------------------------------

# %%
#Summarizing the results of all 3 methods
prod_index=2607
d=pd.DataFrame({'BOW':bow_2607['product'].values[1:],'TF-IDF':tfidf_2607['product'].values[1:], \
                'TF-IDF_W2V':tfidf_w2v_2607['product'].values[1:]})
# setting caption(title) to dataframe
d.style.set_caption('Similar products for : '+'" '+data['product'].loc[prod_index]+'"').set_table_styles([{'selector':'caption',
                                                                                         'props':[('color','black'),
                                                                                                  ('font-weight', 'bold'),
                                                                                                  ('text-align','left'),
                                                                                                 ('font-size', '16px')]}])
# Out:
# <style  type="text/css" >
#     #T_fca80a5f_2ae3_11ed_8564_d4bed961474d caption {
#           color: black;
#           font-weight: bold;
#           text-align: left;
#           font-size: 16px;
#     }</style><table id="T_fca80a5f_2ae3_11ed_8564_d4bed961474d" ><caption>Similar products for : " organic rava idli mix"</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >BOW</th>        <th class="col_heading level0 col1" >TF-IDF</th>        <th class="col_heading level0 col2" >TF-IDF_W2V</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_fca80a5f_2ae3_11ed_8564_d4bed961474dlevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_fca80a5f_2ae3_11ed_8564_d4bed961474drow0_col0" class="data row0 col0" >instant mix rava idli</td>
#                         <td id="T_fca80a5f_2ae3_11ed_8564_d4bed961474drow0_col1" class="data row0 col1" >breakfast mix oats pongal</td>
#                         <td id="T_fca80a5f_2ae3_11ed_8564_d4bed961474drow0_col2" class="data row0 col2" >organic dosa mix jowar</td>
#             </tr>
#             <tr>
#                         <th id="T_fca80a5f_2ae3_11ed_8564_d4bed961474dlevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_fca80a5f_2ae3_11ed_8564_d4bed961474drow1_col0" class="data row1 col0" >organic masala rava idli ready mix</td>
#                         <td id="T_fca80a5f_2ae3_11ed_8564_d4bed961474drow1_col1" class="data row1 col1" >breakfast mix little millet upma</td>
#                         <td id="T_fca80a5f_2ae3_11ed_8564_d4bed961474drow1_col2" class="data row1 col2" >organic masala rava idli ready mix</td>
#             </tr>
#             <tr>
#                         <th id="T_fca80a5f_2ae3_11ed_8564_d4bed961474dlevel0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_fca80a5f_2ae3_11ed_8564_d4bed961474drow2_col0" class="data row2 col0" >organic rice idli ready</td>
#                         <td id="T_fca80a5f_2ae3_11ed_8564_d4bed961474drow2_col1" class="data row2 col1" >breakfast mix little millet pongal</td>
#                         <td id="T_fca80a5f_2ae3_11ed_8564_d4bed961474drow2_col2" class="data row2 col2" >organic ragi dosa ready mix</td>
#             </tr>
#             <tr>
#                         <th id="T_fca80a5f_2ae3_11ed_8564_d4bed961474dlevel0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_fca80a5f_2ae3_11ed_8564_d4bed961474drow3_col0" class="data row3 col0" >ragi dosa mix</td>
#                         <td id="T_fca80a5f_2ae3_11ed_8564_d4bed961474drow3_col1" class="data row3 col1" >specialty idli dosa batter</td>
#                         <td id="T_fca80a5f_2ae3_11ed_8564_d4bed961474drow3_col2" class="data row3 col2" >organic mix dal</td>
#             </tr>
#             <tr>
#                         <th id="T_fca80a5f_2ae3_11ed_8564_d4bed961474dlevel0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_fca80a5f_2ae3_11ed_8564_d4bed961474drow4_col0" class="data row4 col0" >breakfast mix upma</td>
#                         <td id="T_fca80a5f_2ae3_11ed_8564_d4bed961474drow4_col1" class="data row4 col1" >organic masala rava idli ready mix</td>
#                         <td id="T_fca80a5f_2ae3_11ed_8564_d4bed961474drow4_col2" class="data row4 col2" >organic rice mix flaxseed</td>
#             </tr>
#             <tr>
#                         <th id="T_fca80a5f_2ae3_11ed_8564_d4bed961474dlevel0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_fca80a5f_2ae3_11ed_8564_d4bed961474drow5_col0" class="data row5 col0" >mix millet pongal</td>
#                         <td id="T_fca80a5f_2ae3_11ed_8564_d4bed961474drow5_col1" class="data row5 col1" >organic rice idli ready</td>
#                         <td id="T_fca80a5f_2ae3_11ed_8564_d4bed961474drow5_col2" class="data row5 col2" >organic dosa mix mixed millet</td>
#             </tr>
#             <tr>
#                         <th id="T_fca80a5f_2ae3_11ed_8564_d4bed961474dlevel0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_fca80a5f_2ae3_11ed_8564_d4bed961474drow6_col0" class="data row6 col0" >multigrain thalipeeth mix</td>
#                         <td id="T_fca80a5f_2ae3_11ed_8564_d4bed961474drow6_col1" class="data row6 col1" >ragi dosa mix</td>
#                         <td id="T_fca80a5f_2ae3_11ed_8564_d4bed961474drow6_col2" class="data row6 col2" >organic rice dosa ready mix</td>
#             </tr>
#             <tr>
#                         <th id="T_fca80a5f_2ae3_11ed_8564_d4bed961474dlevel0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_fca80a5f_2ae3_11ed_8564_d4bed961474drow7_col0" class="data row7 col0" >organic ragi dosa ready mix</td>
#                         <td id="T_fca80a5f_2ae3_11ed_8564_d4bed961474drow7_col1" class="data row7 col1" >breakfast mix upma</td>
#                         <td id="T_fca80a5f_2ae3_11ed_8564_d4bed961474drow7_col2" class="data row7 col2" >organic rasam ready mix long pepper</td>
#             </tr>
#             <tr>
#                         <th id="T_fca80a5f_2ae3_11ed_8564_d4bed961474dlevel0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_fca80a5f_2ae3_11ed_8564_d4bed961474drow8_col0" class="data row8 col0" >organic rice dosa ready mix</td>
#                         <td id="T_fca80a5f_2ae3_11ed_8564_d4bed961474drow8_col1" class="data row8 col1" >mix millet pongal</td>
#                         <td id="T_fca80a5f_2ae3_11ed_8564_d4bed961474drow8_col2" class="data row8 col2" >organic dosa mix little millet</td>
#             </tr>
#             <tr>
#                         <th id="T_fca80a5f_2ae3_11ed_8564_d4bed961474dlevel0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_fca80a5f_2ae3_11ed_8564_d4bed961474drow9_col0" class="data row9 col0" >ready mix sambar</td>
#                         <td id="T_fca80a5f_2ae3_11ed_8564_d4bed961474drow9_col1" class="data row9 col1" >organic rice dosa ready mix</td>
#                         <td id="T_fca80a5f_2ae3_11ed_8564_d4bed961474drow9_col2" class="data row9 col2" >organic pongal mix foxtail millet</td>
#             </tr>
#     </tbody></table>

# %%
# checking for prod_index 19098 , top 10 similar items
bow_19098=bag_of_words_product_with_discount(19098,11)
tfidf_19098=tfidf_product(19098,11)
tfidf_w2v_19098=tfidf_w2v_product(19098,11)
# Out:
# The searched\Queried product is:
#  19098 : millet muesli crunchy nutty delight
#
# Top 10 Similar products for "millet muesli crunchy nutty delight" are:
# ======================================================================
#
# 16084 : millet diet muesli
# Cosine Similarity with queried product is : 0.999921
# Discount %:  30.0
# --------------------------------------------------
#
# 14627 : oat crispies classic
# Cosine Similarity with queried product is : 0.999793
# Discount %:  30.0
# --------------------------------------------------
#
# 13794 : hazelnut
# Cosine Similarity with queried product is : 0.99979
# Discount %:  23.0
# --------------------------------------------------
#
# 25836 : instant oats
# Cosine Similarity with queried product is : 0.999794
# Discount %:  19.598
# --------------------------------------------------
#
# 24266 : cashew
# Cosine Similarity with queried product is : 0.999792
# Discount %:  7.6923
# --------------------------------------------------
#
# 21534 : rolled oats
# Cosine Similarity with queried product is : 0.99981
# Discount %:  5.0
# --------------------------------------------------
#
# 18419 : oats flour
# Cosine Similarity with queried product is : 0.999805
# Discount %:  0.0
# --------------------------------------------------
#
# 13380 : peanut butter crunchy
# Cosine Similarity with queried product is : 0.999793
# Discount %:  0.0
# --------------------------------------------------
#
# 27060 : healthy snacks nutty apricot fibre
# Cosine Similarity with queried product is : 0.999791
# Discount %:  0.0
# --------------------------------------------------
#
# 21005 : moments
# Cosine Similarity with queried product is : 0.999791
# Discount %:  0.0
# --------------------------------------------------
#
# The searched\Queried product is:
#  19098 :
#  product                        millet muesli crunchy nutty delight
# category                                         gourmet_worldfood
# sub_category                                     cereals_breakfast
# brand                                                 milletmantra
# type                                              muesli_ricecakes
# description      crunchy nutty delight muesli millet based mues...
# sale_price                                                     168
# discount_%                                                      30
# negative                                                     0.158
# neutral                                                      0.645
# positive                                                     0.197
# compound                                                     0.743
# cluster_label                                                    7
# Name: 19098, dtype: object
#
# Top 10 Similar products for "millet muesli crunchy nutty delight" are:
# ======================================================================
#
# 16084 : millet diet muesli
# Cosine Similarity with queried product is : 0.999973
# Discount %:  30.0
# --------------------------------------------------
#
# 14627 : oat crispies classic
# Cosine Similarity with queried product is : 0.999872
# Discount %:  30.0
# --------------------------------------------------
#
# 8201 : super oats rolled oats
# Cosine Similarity with queried product is : 0.999877
# Discount %:  22.0
# --------------------------------------------------
#
# 2474 : teff grain vegan non gmo improves gut health
# Cosine Similarity with queried product is : 0.999895
# Discount %:  20.0
# --------------------------------------------------
#
# 25836 : instant oats
# Cosine Similarity with queried product is : 0.999885
# Discount %:  19.598
# --------------------------------------------------
#
# 10975 : whole instant oats gluten free
# Cosine Similarity with queried product is : 0.999895
# Discount %:  10.2564
# --------------------------------------------------
#
# 21534 : rolled oats
# Cosine Similarity with queried product is : 0.999897
# Discount %:  5.0
# --------------------------------------------------
#
# 27060 : healthy snacks nutty apricot fibre
# Cosine Similarity with queried product is : 0.999898
# Discount %:  0.0
# --------------------------------------------------
#
# 18419 : oats flour
# Cosine Similarity with queried product is : 0.999893
# Discount %:  0.0
# --------------------------------------------------
#
# 13380 : peanut butter crunchy
# Cosine Similarity with queried product is : 0.999872
# Discount %:  0.0
# --------------------------------------------------
#
# The searched/Queried product is:
#  19098 : millet muesli crunchy nutty delight
#
# Top 10 Similar products for "millet muesli crunchy nutty delight" are:
# ======================================================================
#
# 23236 : assorted crispy treats
# Cosine Similarity with queried product is : 0.999682
# Discount %:  30.0601
# --------------------------------------------------
#
# 15249 : popcorn nutty tuxedo chocolate
# Cosine Similarity with queried product is : 0.999718
# Discount %:  15.0
# --------------------------------------------------
#
# 4221 : flavoured cashew godambis creamy chocolate
# Cosine Similarity with queried product is : 0.999683
# Discount %:  15.0
# --------------------------------------------------
#
# 5467 : unsweetened crunchy peanut butter
# Cosine Similarity with queried product is : 0.999712
# Discount %:  10.0
# --------------------------------------------------
#
# 27040 : chocolate peanut butter crunchy
# Cosine Similarity with queried product is : 0.999686
# Discount %:  9.7506
# --------------------------------------------------
#
# 19187 : organic peanut butter creamy sweet salty
# Cosine Similarity with queried product is : 0.999711
# Discount %:  7.5
# --------------------------------------------------
#
# 9526 : crunchy organic peanut butter
# Cosine Similarity with queried product is : 0.999691
# Discount %:  5.1282
# --------------------------------------------------
#
# 27060 : healthy snacks nutty apricot fibre
# Cosine Similarity with queried product is : 0.999759
# Discount %:  0.0
# --------------------------------------------------
#
# 14608 : healthy snacks nutty apricot fibre
# Cosine Similarity with queried product is : 0.999726
# Discount %:  0.0
# --------------------------------------------------
#
# 25120 : breakfast cereal crunchy granola with nutty honey
# Cosine Similarity with queried product is : 0.99972
# Discount %:  0.0
# --------------------------------------------------

# %%
#Summarizing the results of all 3 methods
prod_index=19098
d=pd.DataFrame({'BOW':bow_19098['product'].values[1:],'TF-IDF':tfidf_19098['product'].values[1:], \
                'TF-IDF_W2V':tfidf_w2v_19098['product'].values[1:]})
# setting caption(title) to dataframe
d.style.set_caption('Similar products for : '+'" '+data['product'].loc[prod_index]+'"').set_table_styles([{'selector':'caption',
                                                                                         'props':[('color','black'),
                                                                                                  ('font-weight', 'bold'),
                                                                                                  ('text-align','left'),
                                                                                                 ('font-size', '16px')]}])
# Out:
# <style  type="text/css" >
#     #T_4972cbd3_2ae4_11ed_a006_d4bed961474d caption {
#           color: black;
#           font-weight: bold;
#           text-align: left;
#           font-size: 16px;
#     }</style><table id="T_4972cbd3_2ae4_11ed_a006_d4bed961474d" ><caption>Similar products for : " millet muesli crunchy nutty delight"</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >BOW</th>        <th class="col_heading level0 col1" >TF-IDF</th>        <th class="col_heading level0 col2" >TF-IDF_W2V</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_4972cbd3_2ae4_11ed_a006_d4bed961474dlevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_4972cbd3_2ae4_11ed_a006_d4bed961474drow0_col0" class="data row0 col0" >millet diet muesli</td>
#                         <td id="T_4972cbd3_2ae4_11ed_a006_d4bed961474drow0_col1" class="data row0 col1" >millet diet muesli</td>
#                         <td id="T_4972cbd3_2ae4_11ed_a006_d4bed961474drow0_col2" class="data row0 col2" >assorted crispy treats</td>
#             </tr>
#             <tr>
#                         <th id="T_4972cbd3_2ae4_11ed_a006_d4bed961474dlevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_4972cbd3_2ae4_11ed_a006_d4bed961474drow1_col0" class="data row1 col0" >oat crispies classic</td>
#                         <td id="T_4972cbd3_2ae4_11ed_a006_d4bed961474drow1_col1" class="data row1 col1" >oat crispies classic</td>
#                         <td id="T_4972cbd3_2ae4_11ed_a006_d4bed961474drow1_col2" class="data row1 col2" >popcorn nutty tuxedo chocolate</td>
#             </tr>
#             <tr>
#                         <th id="T_4972cbd3_2ae4_11ed_a006_d4bed961474dlevel0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_4972cbd3_2ae4_11ed_a006_d4bed961474drow2_col0" class="data row2 col0" >hazelnut</td>
#                         <td id="T_4972cbd3_2ae4_11ed_a006_d4bed961474drow2_col1" class="data row2 col1" >super oats rolled oats</td>
#                         <td id="T_4972cbd3_2ae4_11ed_a006_d4bed961474drow2_col2" class="data row2 col2" >flavoured cashew godambis creamy chocolate</td>
#             </tr>
#             <tr>
#                         <th id="T_4972cbd3_2ae4_11ed_a006_d4bed961474dlevel0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_4972cbd3_2ae4_11ed_a006_d4bed961474drow3_col0" class="data row3 col0" >instant oats</td>
#                         <td id="T_4972cbd3_2ae4_11ed_a006_d4bed961474drow3_col1" class="data row3 col1" >teff grain vegan non gmo improves gut health</td>
#                         <td id="T_4972cbd3_2ae4_11ed_a006_d4bed961474drow3_col2" class="data row3 col2" >unsweetened crunchy peanut butter</td>
#             </tr>
#             <tr>
#                         <th id="T_4972cbd3_2ae4_11ed_a006_d4bed961474dlevel0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_4972cbd3_2ae4_11ed_a006_d4bed961474drow4_col0" class="data row4 col0" >cashew</td>
#                         <td id="T_4972cbd3_2ae4_11ed_a006_d4bed961474drow4_col1" class="data row4 col1" >instant oats</td>
#                         <td id="T_4972cbd3_2ae4_11ed_a006_d4bed961474drow4_col2" class="data row4 col2" >chocolate peanut butter crunchy</td>
#             </tr>
#             <tr>
#                         <th id="T_4972cbd3_2ae4_11ed_a006_d4bed961474dlevel0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_4972cbd3_2ae4_11ed_a006_d4bed961474drow5_col0" class="data row5 col0" >rolled oats</td>
#                         <td id="T_4972cbd3_2ae4_11ed_a006_d4bed961474drow5_col1" class="data row5 col1" >whole instant oats gluten free</td>
#                         <td id="T_4972cbd3_2ae4_11ed_a006_d4bed961474drow5_col2" class="data row5 col2" >organic peanut butter creamy sweet salty</td>
#             </tr>
#             <tr>
#                         <th id="T_4972cbd3_2ae4_11ed_a006_d4bed961474dlevel0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_4972cbd3_2ae4_11ed_a006_d4bed961474drow6_col0" class="data row6 col0" >oats flour</td>
#                         <td id="T_4972cbd3_2ae4_11ed_a006_d4bed961474drow6_col1" class="data row6 col1" >rolled oats</td>
#                         <td id="T_4972cbd3_2ae4_11ed_a006_d4bed961474drow6_col2" class="data row6 col2" >crunchy organic peanut butter</td>
#             </tr>
#             <tr>
#                         <th id="T_4972cbd3_2ae4_11ed_a006_d4bed961474dlevel0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_4972cbd3_2ae4_11ed_a006_d4bed961474drow7_col0" class="data row7 col0" >peanut butter crunchy</td>
#                         <td id="T_4972cbd3_2ae4_11ed_a006_d4bed961474drow7_col1" class="data row7 col1" >healthy snacks nutty apricot fibre</td>
#                         <td id="T_4972cbd3_2ae4_11ed_a006_d4bed961474drow7_col2" class="data row7 col2" >healthy snacks nutty apricot fibre</td>
#             </tr>
#             <tr>
#                         <th id="T_4972cbd3_2ae4_11ed_a006_d4bed961474dlevel0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_4972cbd3_2ae4_11ed_a006_d4bed961474drow8_col0" class="data row8 col0" >healthy snacks nutty apricot fibre</td>
#                         <td id="T_4972cbd3_2ae4_11ed_a006_d4bed961474drow8_col1" class="data row8 col1" >oats flour</td>
#                         <td id="T_4972cbd3_2ae4_11ed_a006_d4bed961474drow8_col2" class="data row8 col2" >healthy snacks nutty apricot fibre</td>
#             </tr>
#             <tr>
#                         <th id="T_4972cbd3_2ae4_11ed_a006_d4bed961474dlevel0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_4972cbd3_2ae4_11ed_a006_d4bed961474drow9_col0" class="data row9 col0" >moments</td>
#                         <td id="T_4972cbd3_2ae4_11ed_a006_d4bed961474drow9_col1" class="data row9 col1" >peanut butter crunchy</td>
#                         <td id="T_4972cbd3_2ae4_11ed_a006_d4bed961474drow9_col2" class="data row9 col2" >breakfast cereal crunchy granola with nutty honey</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ### </u>Observations<u>
#
# - From the above result summary TF-IDF weighted W2V results are better compare to other two methods
