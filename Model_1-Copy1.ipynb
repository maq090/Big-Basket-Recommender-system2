# %% [markdown]
# # <span style="color:green"> <U/> Model & Feature Engineering</span>

# %%
#import all the necessary packages.
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings("ignore")
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import nltk
import seaborn as sns
from collections import Counter
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity  
from sklearn.metrics import pairwise_distances
from scipy.sparse import hstack
import re
import pickle
from sklearn.preprocessing import MinMaxScaler
import sys

# %%
# we use the list of stop words that are downloaded from nltk lib.
import nltk # to download only once
nltk.download('stopwords')
stop_words = set(stopwords.words('english'))
print ('list of stop words:', stop_words)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Muheebpashasnr\AppData\Roaming\nltk_data...
# list of stop words: {'herself', 'before', 'other', 'don', 'is', "should've", 'does', 'up', 'isn', 'their', 'because', "you're", 'y', 'she', 'hadn', 'whom', 'only', 're', 'myself', 'by', 'theirs', 'ma', "couldn't", 'to', "needn't", 'at', "didn't", 'doesn', 'her', 'off', 'between', 'here', 'needn', 'ain', 'that', 'themselves', 'being', 'me', "you'd", 'each', "mustn't", 'after', 'further', 'into', 'for', 'below', 'same', 'then', "aren't", 'his', 'an', 'under', "shouldn't", 'than', 'haven', 'weren', 'very', 'can', 'wasn', 'few', 't', 'or', "doesn't", 'are', 'ours', 'itself', 'been', "you'll", 'have', 'he', 'nor', 's', 'such', 'not', 'll', 'over', 'hasn', 'my', 'the', "haven't", 'during', "weren't", 'having', 'what', "hasn't", "isn't", 'has', 'mightn', 'through', 'we', 'shan', 'was', "you've", 'them', 'of', 'a', 'wouldn', 'if', 'ourselves', 'now', "shan't", 'couldn', 'didn', 'did', 'out', 'am', 'both', 'some', 'd', 'won', 'own', 'with', 'where', 'how', 'from', "it's", "don't", 'himself', 'yours', 'about', 'him', 'too', 'again', 'your', "wasn't", 'why', 'aren', 'its', 'down', 'had', 'which', 'while', 'so', 'just', 'above', 'i', 'there', 've', 'were', 'this', 'once', 'those', 'on', "wouldn't", 'shouldn', "she's", 'doing', 'but', 'hers', 'and', 'these', 'when', "hadn't", 'will', 'until', 'yourself', 'do', 'o', 'should', 'any', 'mustn', 'against', 'they', 'more', 'no', 'it', 'in', 'who', 'you', "mightn't", 'our', 'all', 'most', 'm', "won't", 'as', "that'll", 'be', 'yourselves'}
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# computing sentiment score for description feature
import nltk
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\Muheebpashasnr\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# True

# %%
# load preprocessed train data
df=pd.read_csv('train_preprocessed_with_clusterlabels.csv')
df.head()
# Out:
#                product               category          sub_category  \
# 0         Flour - Corn  foodgrains_oil_masala        organicstaples
# 1    Veg. Burger Patty    snacks_brandedfoods  frozenveggies_snacks
# 2       Dosa Rice/Akki  foodgrains_oil_masala     rice_riceproducts
# 3  Skimmed Milk Powder      gourmet_worldfood   cooking_bakingneeds
# 4           Kiwi Drink      gourmet_worldfood      drinks_beverages
#
#            brand                    type  \
# 0  organictattva           organicflours
# 1        yummiez         frozenvegsnacks
# 2     supersaver                 rawrice
# 3       puramate  baking_cakedecorations
# 4       alafresh    gourmetjuices_drinks
#
#                                          description  sale_price  \
# 0                                   per calories fat        57.0
# 1  real good veg burger patty choice eating beefy...       125.0
# 2  rice dosa easy make premium dosa mix used make...       199.0
# 3  puramate skimmed milk powder makes wholesome m...        58.5
# 4  ala fresh kiwi fruit drink refreshing fruit dr...        10.0
#
#    market_price  discount_%  negative  neutral  positive  compound  \
# 0          60.0    0.050000       0.0    1.000     0.000    0.0000
# 1         125.0    0.000000       0.0    0.611     0.389    0.9484
# 2         225.0    0.115556       0.0    0.811     0.189    0.8126
# 3          65.0    0.100000       0.0    0.780     0.220    0.9723
# 4          10.0    0.000000       0.0    0.667     0.333    0.8402
#
#    sale_price_scaled  cluster_label
# 0           0.027308              1
# 1           0.061350              2
# 2           0.098396              3
# 3           0.028059              2
# 4           0.003780              2

# %%
df.columns
# Out:
# Index(['product', 'category', 'sub_category', 'brand', 'type', 'description',
#        'sale_price', 'market_price', 'discount_%', 'negative', 'neutral',
#        'positive', 'compound', 'sale_price_scaled', 'cluster_label'],
#       dtype='object')

# %%
df.shape
# Out:
# (21648, 15)

# %% [markdown]
# - will vectorize preprocessed description text with tfidf weighted W2V

# %%
# loading glove vectors for w2v dimensions
with open(r'F:\Applied AI\Assignments\Self_Case_Study_1\glove_vectors','rb') as f:
    model=pickle.load(f)
    glove_words=set(model.keys()) # creating set of words in glove file

# %%
# tfidf vectorizer
tfidf=TfidfVectorizer()
tfidf_description=tfidf.fit_transform(df['description'])

# %%
# we are converting a dictionary with word as a key, and the idf as a value
dictionary = dict(zip(tfidf.get_feature_names(), list(tfidf.idf_)))
tfidf_words = set(tfidf.get_feature_names())

# %% [markdown]
# ### tfidf_W2V vectorization of preprocessed description feature

# %%
#vectorizing train  data using tfidf-W2v
# average Word2Vec
# compute tfidf word2vec for each description.
from tqdm import tqdm
description_tfidf_w2v_vectors = []; # the avg-w2v for each description is stored in this list
for description in tqdm(df['description']): # for each description
    vector = np.zeros(300) # as word vectors are of zero length
    tf_idf_weight =0; # num of words with a valid vector in the description
    for word in description.split(): # for each word in description
        if (word in glove_words) and (word in tfidf_words):
            vec = model[word] # getting the vector for each word
            # here we are multiplying idf value(dictionary[word]) and the tf value((description.count(word)/len(product.split())))
            tf_idf = dictionary[word]*(description.count(word)/len(description.split())) # getting the tfidf value for each word
            vector += (vec * tf_idf) # calculating tfidf weighted w2v
            tf_idf_weight += tf_idf
    if tf_idf_weight != 0:
        vector /= tf_idf_weight
    description_tfidf_w2v_vectors.append(vector)
# Out:
# 100%|██████████████████████████████████| 21648/21648 [00:16<00:00, 1286.60it/s]

# %%
len(description_tfidf_w2v_vectors)
# Out:
# 21648

# %% [markdown]
# ### Label encoding categorical features `'category', 'sub_category', 'brand', 'type'`

# %%
#https://stephenallwright.com/label-encode-unseen-values/
from sklearn.preprocessing import LabelEncoder

def label_encode_columns(df, columns, encoders=None):
    if encoders is None:
        encoders = {}
    
        for col in columns:
            unique_values = list(df[col].unique())
            unique_values.append('Unseen')
            le = LabelEncoder().fit(unique_values)
            df[col] = le.transform(df[[col]])
            encoders[col] = le
    
    else:
        for col in columns:
            le = encoders.get(col)
            df[col] = [x if x in le.classes_ else 'Unseen' for x in df[col]]
            df[col] = le.transform(df[[col]])

    return df, encoders

# %%
columns=['category', 'sub_category', 'brand', 'type']
df, encoders=label_encode_columns(df, columns, encoders=None)

# %%
le_for_test=encoders # saving encoders for test data

# %%
le_for_test
# Out:
# {'category': LabelEncoder(),
#  'sub_category': LabelEncoder(),
#  'brand': LabelEncoder(),
#  'type': LabelEncoder()}

# %%
df.head()
# Out:
#                product  category  sub_category  brand  type  \
# 0         Flour - Corn         7            69   1445   302
# 1    Veg. Burger Patty        11            46   2138   176
# 2       Dosa Rice/Akki         7            77   1876   349
# 3  Skimmed Milk Powder         9            21   1570    30
# 4           Kiwi Drink         9            31     56   193
#
#                                          description  sale_price  \
# 0                                   per calories fat        57.0
# 1  real good veg burger patty choice eating beefy...       125.0
# 2  rice dosa easy make premium dosa mix used make...       199.0
# 3  puramate skimmed milk powder makes wholesome m...        58.5
# 4  ala fresh kiwi fruit drink refreshing fruit dr...        10.0
#
#    market_price  discount_%  negative  neutral  positive  compound  \
# 0          60.0    0.050000       0.0    1.000     0.000    0.0000
# 1         125.0    0.000000       0.0    0.611     0.389    0.9484
# 2         225.0    0.115556       0.0    0.811     0.189    0.8126
# 3          65.0    0.100000       0.0    0.780     0.220    0.9723
# 4          10.0    0.000000       0.0    0.667     0.333    0.8402
#
#    sale_price_scaled  cluster_label
# 0           0.027308              1
# 1           0.061350              2
# 2           0.098396              3
# 3           0.028059              2
# 4           0.003780              2

# %% [markdown]
# ### will build a matrix from train data to compute cosine similarity

# %%
# stacking all encoded categorical features, vectorized description text and scaled sael price,discount% and sentiment scores
X_train=np.hstack((description_tfidf_w2v_vectors,df['category'].values.reshape(-1,1),df['sub_category'].values.reshape(-1,1),df['brand'].values.reshape(-1,1), \
                  df['type'].values.reshape(-1,1),df['sale_price_scaled'].values.reshape(-1,1),df['discount_%'].values.reshape(-1,1), \
                  df['negative'].values.reshape(-1,1),df['neutral'].values.reshape(-1,1),df['positive'].values.reshape(-1,1), \
                  df['compound'].values.reshape(-1,1),df['cluster_label'].values.reshape(-1,1)))

# %%
X_train.shape
# Out:
# (21648, 311)

# %%
#saving to pkl file
pickle.dump(X_train,open('X_train.pkl','wb'))

# %% [markdown]
# ## Model Building

# %% [markdown]
# - will give attributes of query product
# - query product should have `category,sub_category,brand,type,description,sale_price,market_price`
# - using the above features will do encoding,vectorizing ,scale sale price to train data,compute discount_%, calculate sentiment scores, and assign to nearest cluster

# %%
# function to check all features are given for query product
def missing_features(data):
    """to check any missing or blank or nan values in qury product """
    data.replace('None',np.nan,inplace=True) # replace None with Nan
    data.replace(r'^\s*$',np.nan,regex=True,inplace=True) # replace empty string with NaN
    
   # first to check whether the data has the 8 listed columns[category,sub_category,brand,type,description,sale_price,market_price]
   # to check for any missing values
    if(data.shape[1]<7) or data.isna().any().any():
        print('Please check datapoint\n')
        print('The data has missing values in'+ str(list(data.columns[data.isna().any()]))+ 'columns')
        
        return False
    else:
        return True

# %%
testcase=pd.read_csv('missing_column.csv')
testcase
# Out:
#    index                product              category  \
# 0   9766  Food Package - Medium  Cleaning & Household
#
#                sub_category  brand  sale_price  market_price  \
# 0  Disposables, Garbage Bag    NaN        50.0          50.0
#
#                         type  rating  description
# 0  Aluminium Foil, Clingwrap     NaN          NaN

# %%
#test case of missing_features func
a=missing_features(testcase) #with msiing column
a
# Out:
# Please check datapoint
#
# The data has missing values in['brand', 'rating', 'description']columns
# False

# %%
#removing sale price
testcase['sale_price']=''
testcase
# Out:
#    index                product              category  \
# 0   9766  Food Package - Medium  Cleaning & Household
#
#                sub_category  brand sale_price  market_price  \
# 0  Disposables, Garbage Bag    NaN                     50.0
#
#                         type  rating  description
# 0  Aluminium Foil, Clingwrap     NaN          NaN

# %%
a=missing_features(testcase) #with missing column
a
# Out:
# Please check datapoint
#
# The data has missing values in['brand', 'sale_price', 'rating', 'description']columns
# False

# %%
print(type(df.loc[[1],:]))
df.loc[[1],:]
# Out:
# <class 'pandas.core.frame.DataFrame'>
#              product  category  sub_category  brand  type  \
# 1  Veg. Burger Patty        11            46   2138   176
#
#                                          description  sale_price  \
# 1  real good veg burger patty choice eating beefy...       125.0
#
#    market_price  discount_%  negative  neutral  positive  compound  \
# 1         125.0         0.0       0.0    0.611     0.389    0.9484
#
#    sale_price_scaled  cluster_label
# 1            0.06135              2

# %%
b=missing_features(df.loc[[1],:])
b
# Out:
# True

# %%
# function to check for sale price range 
sale_price_minima=df['sale_price'].min()-(df['sale_price'].min()*0.15) # 15 less than min 
sale_price_maxima=df['sale_price'].max()+(df['sale_price'].max()*0.15)
print(sale_price_minima,'\t',sale_price_maxima)
# Out:
# 2.0825 	 2300.0

# %%
def salepricecheck(data,train_data):
    '''function to check data has sale price relavant to other produts in same brand or whole train data'''
    if data['sale_price'].values.size!=0: #https://stackoverflow.com/questions/11295609/how-can-i-check-whether-a-numpy-array-is-empty-or-not
        if data['brand'].notna().all():
            g=train_data.groupby(['brand'])['sale_price'] # grouping train data based on brand to get group of query product brand
            minimum=g.get_group((data['brand'].values[0])).min() # getting minimum sale price of query product brand in train data
            minimum = minimum-(minimum*0.15) # 15% tolerance
            
            maximum=g.get_group((data['brand'].values[0])).max()
            maximum = maximum + (maximum*0.15)
            
            if minimum <= float(data['sale_price'].values[0]) <= maximum:
                return True
            else:
                print('The sale_price of query product is not in range of other products in same brand,Check sale_price')
                return False
        else:
            if sale_price_minima <= float(data['sale_price'].values[0]) <= sale_price_maxima: # if brand is not available then will see in whole train data
                return True
            else:
                print('The sale_price of query product is not in range of train data products,please check sale_price')
                return False
    else:
        print('No sale_price for query product given')    
        return False

# %%
#test cases for salepricecheck
a=df.loc[[1],:]
a
# Out:
#              product  category  sub_category  brand  type  \
# 1  Veg. Burger Patty        11            46   2138   176
#
#                                          description  sale_price  \
# 1  real good veg burger patty choice eating beefy...       125.0
#
#    market_price  discount_%  negative  neutral  positive  compound  \
# 1         125.0         0.0       0.0    0.611     0.389    0.9484
#
#    sale_price_scaled  cluster_label
# 1            0.06135              2

# %%
out=salepricecheck(a,df)
out
# Out:
# True

# %%
# modifying a
a['brand']=np.nan
a
# Out:
#              product  category  sub_category  brand  type  \
# 1  Veg. Burger Patty        11            46    NaN   176
#
#                                          description  sale_price  \
# 1  real good veg burger patty choice eating beefy...       125.0
#
#    market_price  discount_%  negative  neutral  positive  compound  \
# 1         125.0         0.0       0.0    0.611     0.389    0.9484
#
#    sale_price_scaled  cluster_label
# 1            0.06135              2

# %%
out=salepricecheck(a,df)
out
# Out:
# True

# %%
a['sale_price']=2301 # chamged sale price above maximum
a
# Out:
#              product  category  sub_category  brand  type  \
# 1  Veg. Burger Patty        11            46    NaN   176
#
#                                          description  sale_price  \
# 1  real good veg burger patty choice eating beefy...        2301
#
#    market_price  discount_%  negative  neutral  positive  compound  \
# 1         125.0         0.0       0.0    0.611     0.389    0.9484
#
#    sale_price_scaled  cluster_label
# 1            0.06135              2

# %%
out=salepricecheck(a,df)
out
# Out:
# The sale_price of query product is not in range of train data products,please check sale_price
# False

# %%
# changing brand to Nivea and replacing sale price lower than the brand group minima with 15% tolerance
a['brand']=2138
g=df.groupby(['brand'])['sale_price']
minima=g.get_group((2138)).min()
print(minima)
a['sale_price']=(minima)-(minima*.30)
a
# Out:
# 95.0
#              product  category  sub_category  brand  type  \
# 1  Veg. Burger Patty        11            46   2138   176
#
#                                          description  sale_price  \
# 1  real good veg burger patty choice eating beefy...        66.5
#
#    market_price  discount_%  negative  neutral  positive  compound  \
# 1         125.0         0.0       0.0    0.611     0.389    0.9484
#
#    sale_price_scaled  cluster_label
# 1            0.06135              2

# %%
out=salepricecheck(a,df)
out
# Out:
# The sale_price of query product is not in range of other products in same brand,Check sale_price
# False

# %%
# function to get sentiment scores 
from nltk.sentiment.vader import SentimentIntensityAnalyzer

def get_scores(data):
    """retuens sentiment analysis scores for description feature"""
    sia=SentimentIntensityAnalyzer()
    
    negative=[]
    neu=[]
    pos=[]
    compound=[]
    if 'description' in data.columns:
        for value in (data['description']):
            i=sia.polarity_scores(value)['neg']
            j=sia.polarity_scores(value)['neu']
            k=sia.polarity_scores(value)['pos']
            l=sia.polarity_scores(value)['compound']
            
            negative.append(i)
            neu.append(j)
            pos.append(k)
            compound.append(l)
            
    data['negative']=negative
    data['neutral']=neu
    data['positive']=pos
    data['compound']=compound
    
    return data

# %%
# function to get tfidf weighted word2vec

def get_tfidf_w2v(data):
    """retuens tfidf weighted w2v for description feature"""
    
    description_tfidf_w2v_vectors = []; # the avg-w2v for each description is stored in this list
    if 'description' in data.columns:
        for description in (data['description']):
            vector = np.zeros(300) # as word vectors are of zero length
            tf_idf_weight =0; # num of words with a valid vector in the description
            for word in description.split(): # for each word in description
                if (word in glove_words) and (word in tfidf_words):
                    vec = model[word] # getting the vector for each word
                    # here we are multiplying idf value(dictionary[word]) and the tf value((description.count(word)/len(product.split())))
                    tf_idf = dictionary[word]*(description.count(word)/len(description.split())) # getting the tfidf value for each word
                    vector += (vec * tf_idf) # calculating tfidf weighted w2v
                    tf_idf_weight += tf_idf
            if tf_idf_weight != 0:
                vector /= tf_idf_weight
            description_tfidf_w2v_vectors.append(vector)
    
    return description_tfidf_w2v_vectors

# %%
# function to preprocess categorical text features category,sub_category,brand,type

def categorical_preprocess(text):
    """to preprocess categorical features,use .apply for applying function"""
    text=text.str.replace('&','_') # replacing & with _
    text=text.str.replace(',','_') # replacing , with _
    text=text.str.replace("'",'') #replacing '' with ''(no space)
    text=text.str.replace(" ",'') # removing white spaces
    text=text.str.lower() # to lower case
    text=text.str.strip() # removing trailing and leading white space
    
    return text

# %%
# function to preprocess description text feature

def preprocess_description(text):
    """ Function which does preprocesiing on prodcut title feature,
        removes stopwords, replaces special character with space, converts to lower case,
    """
    preprocessed_description=[]
    for description in text:
        
        #Delete all the data which are present in the brackets
        description = re.sub(r'\([^()]*\)',' ',description)
        
        #removing urls
        description = re.sub(r'http\S+',' ',description)
        description = re.sub('[^A-Za-z]+', ' ', description) # remove all characters except a-z and A-Z and replace with white space
        # https://gist.github.com/sebleier/554280
        description = ' '.join(word for word in description.split() if word.lower() not in stop_words) # removing stop words
        description = ' '.join(word for word in description.split() if len(word)>2) # removing single letter and two letter words
        description = description.lower().strip()
        preprocessed_description.append(description)
        
    return preprocessed_description

# %% [markdown]
# ### Function to get similar products of query product(given as dataframe)

# %%
#www.geeksforgeeks.org/k-means
# loading cluster centres(means) on train data
with open ('cluster_centers.pkl','rb') as f:
    cluster_centers=pickle.load(f)
    
def get_clusterlabel(X,means=cluster_centers):
    """ to get cluster label"""
    minimum=sys.maxsize # initializing minimum as maximum integer so that the distances will be less than that
    index=-1
    for i in range(len(means)):
        dis=np.linalg.norm(X - means[i]) #https://www.geeksforgeeks.org/calculate-the-euclidean-distance-using-numpy/
        
        if (dis<minimum):
            minmum=dis
            index=i
            
    return index

# %%
from sklearn.preprocessing import MinMaxScaler
import sys

def get_similar_products(query,train_data,X_train=X_train,num_results=11):
    """function to give similar products from train_data for query product """
    
    # query: query product
    # train_data: preprocessed train data with all features
    #X_train: matrix to compute cosine similarity
    # num_results: number of similar products to show
    
    if missing_features(query):
        
        # preprocessing categorical columns
        query[['category','sub_category','brand','type']]=query[['category','sub_category','brand','type']].apply(categorical_preprocess)
        
        # encoding categorical features category,sub_category,brand,type
        columns=['category', 'sub_category', 'brand', 'type']
        query, encoders=label_encode_columns(query, columns, le_for_test) # using encoders =encoders got by fitting on
        
        if salepricecheck(query,train_data):
            # preprocessing description
            query['description']=preprocess_description(query['description'].values)
        
            #calculating discount_%
            if 'discount_%' not in query.columns:
                query['discount_%']=(query['market_price']-query['sale_price'])/query['market_price']
        
            query=get_scores(query) # to get sentiment scores
        
            # scaling sale price
            scaler = MinMaxScaler()
            scaler.fit(train_data['sale_price'].values.reshape(-1,1))
            query['sale_price_scaled']=scaler.transform(query['sale_price'].values.reshape(-1,1))
        
            # to get cluster label
            X_q=np.hstack((query['sale_price_scaled'].values.reshape(-1,1),query['discount_%'].values.reshape(-1,1), \
                           query['negative'].values.reshape(-1,1),query['neutral'].values.reshape(-1,1), \
                           query['positive'].values.reshape(-1,1),query['compound'].values.reshape(-1,1)))
        
            query['cluster_label']=get_clusterlabel(X_q) # function to classify item to nearest means(cluster_centres)
        
            tfidf_w2v_vector=get_tfidf_w2v(query) # function to vectorize description text after preprocessing
        
            
            # stacking all values
            #https://numpy.org/doc/stable/reference/generated/numpy.concatenate.html#numpy.concatenate
            X=np.hstack((tfidf_w2v_vector,query['category'].values.reshape(-1,1),query['sub_category'].values.reshape(-1,1), \
                         query['brand'].values.reshape(-1,1),query['type'].values.reshape(-1,1), \
                         query['sale_price_scaled'].values.reshape(-1,1),query['discount_%'].values.reshape(-1,1), \
                         query['negative'].values.reshape(-1,1),query['neutral'].values.reshape(-1,1), \
                         query['positive'].values.reshape(-1,1),query['compound'].values.reshape(-1,1), \
                         query['cluster_label'].values.reshape(-1,1)))
        
            # till now we have preprocessed and vectorized query product
            # now will compute cosine similarities and suggest similar products based on cosine similarity
            cosine_sim=cosine_similarity(X_train,X)
            # np.argsort will return indices of the nearest products 
            indices = np.argsort(cosine_sim.flatten())[-num_results:-1]
            # -1 given to exclude the searched product itself from showing in recommendations as cosinine similarity will be 1 for same product
            # flipping the indices so that the product with more similarity is shown first
            # argsort will do sorting of indices from smallest to largest value
            indices=np.flip(indices)
            #psimilarity will store the similarity 
            psimilarity  = np.sort(cosine_sim.flatten())[-num_results:-1]
            psimilarity = np.flip(psimilarity)
        
            print('The searched/Queried product is:\n',query['product'].values[0])
            print('\nTop '+str(num_results-1)+' Similar products for "'+'\033[1m'+query['product'].values[0]+'\033[0m' +'" are:')
            print("="*70,'\n')
        
            data=train_data[['product','discount_%']].loc[indices]
            data['similarity']=psimilarity.tolist() # adding similarity scores as a new column to data
           
            lst=[] # list to store indices after sorting
            for ind in data.index:
                lst.append(ind)
                print(ind,":",data['product'][ind])
                print('Cosine Similarity with queried product is :',np.round(data['similarity'][ind],6))
                print('Discount %: ',np.round(data['discount_%'][ind])) # restoring discount to original scale 
                print('-'*50,'\n')
            
            return train_data.loc[lst]
    else:
        print('Please check query point for any missing or incomplete information')

# %%
# loading test data to check model performance
test=pd.read_csv('test_raw.csv')
test.drop(['discount_%'],axis=1,inplace=True)
test.head(2)
# Out:
#                                              product                category  \
# 0  Vittora Plastic Shoe Rack/Shoe Stand - 2 Steps...  Kitchen, Garden & Pets
# 1  Power Plus Disinfectant Toilet Cleaner 1 L + C...    Cleaning & Household
#
#             sub_category   brand             type  \
# 0  Storage & Accessories  Aristo  Racks & Holders
# 1   All Purpose Cleaners  Harpic  Toilet Cleaners
#
#                                          description  sale_price  market_price
# 0  Virgin plastic made strong and elegant 2 step ...       699.0         923.0
# 1  Harpic Disinfectant Toilet Cleaner Liquid - Ro...       274.0         324.0

# %%
test.shape
# Out:
# (5488, 8)

# %% [markdown]
# ### checking for some random query products

# %%
query=test.loc[[3],:]
query
# Out:
#                    product              category           sub_category brand  \
# 3  Kantan Watermelon Slice  Gourmet & World Food  Chocolates & Biscuits  Fini
#
#                         type  \
# 3  Marshmallow, Candy, Jelly
#
#                                          description  sale_price  market_price
# 3  Fini Fizzy Watermelon Slices containing fizzy ...       110.0         110.0

# %%
query.to_csv('query3.csv',index=False)

# %%
le_for_test['category'].classes_
# Out:
# array(['Unseen', 'babycare', 'bakery_cakes_dairy', 'beauty_hygiene',
#        'beverages', 'cleaning_household', 'eggs_meat_fish',
#        'foodgrains_oil_masala', 'fruits_vegetables', 'gourmet_worldfood',
#        'kitchen_garden_pets', 'snacks_brandedfoods'], dtype='<U21')

# %%
query
# Out:
#                    product              category           sub_category brand  \
# 3  Kantan Watermelon Slice  Gourmet & World Food  Chocolates & Biscuits  Fini
#
#                         type  \
# 3  Marshmallow, Candy, Jelly
#
#                                          description  sale_price  market_price
# 3  Fini Fizzy Watermelon Slices containing fizzy ...       110.0         110.0

# %%
query['category']
# Out:
# 3    Gourmet & World Food
# Name: category, dtype: object

# %%
# get similar products
similar_products_3=get_similar_products(query,df,X_train=X_train,num_results=11)
similar_products_3
# Out:
# The searched/Queried product is:
#  Kantan Watermelon Slice
#
# Top 10 Similar products for "Kantan Watermelon Slice" are:
# ======================================================================
#
# 8558 : Kantan Cola Bottles Gum
# Cosine Similarity with queried product is : 0.999986
# Discount %:  0.0
# --------------------------------------------------
#
# 13075 : Kantan Bubble Gum Balls
# Cosine Similarity with queried product is : 0.999985
# Discount %:  0.0
# --------------------------------------------------
#
# 16625 : Kantan Bubble Gum Balls
# Cosine Similarity with queried product is : 0.999985
# Discount %:  0.0
# --------------------------------------------------
#
# 5895 : Pucks Crunchy Jellies
# Cosine Similarity with queried product is : 0.999985
# Discount %:  0.0
# --------------------------------------------------
#
# 5774 : Tennis Balls Gum
# Cosine Similarity with queried product is : 0.999985
# Discount %:  0.0
# --------------------------------------------------
#
# 21486 : Kantan Tennis Balls
# Cosine Similarity with queried product is : 0.999983
# Discount %:  0.0
# --------------------------------------------------
#
# 18589 : Cola Bottles - Sugar
# Cosine Similarity with queried product is : 0.99998
# Discount %:  0.0
# --------------------------------------------------
#
# 20781 : Crazy Roller
# Cosine Similarity with queried product is : 0.99998
# Discount %:  0.0
# --------------------------------------------------
#
# 970 : Moments
# Cosine Similarity with queried product is : 0.999978
# Discount %:  0.0
# --------------------------------------------------
#
# 10965 : Moments
# Cosine Similarity with queried product is : 0.999978
# Discount %:  0.0
# --------------------------------------------------
#                        product  category  sub_category  brand  type  \
# 8558   Kantan Cola Bottles Gum         9            17    660   263
# 13075  Kantan Bubble Gum Balls         9            17    660   263
# 16625  Kantan Bubble Gum Balls         9            17    660   263
# 5895     Pucks Crunchy Jellies         9            17    660   263
# 5774          Tennis Balls Gum         9            17    660   263
# 21486      Kantan Tennis Balls         9            17    660   263
# 18589     Cola Bottles - Sugar         9            17    660   263
# 20781             Crazy Roller         9            17    660   263
# 970                    Moments         9            17    652   257
# 10965                  Moments         9            17    652   257
#
#                                              description  sale_price  \
# 8558   fini bubblegum cola bottles supplied fini come...       110.0
# 13075  kantan bubble gum balls gluten free percent yu...       110.0
# 16625  kantan bubble gum balls gluten free percent yu...        40.0
# 5895   pucks crunchy jellies gluten free percent fat ...       125.0
# 5774   tennis balls gum gluten free percent yummy per...       125.0
# 21486  sporty kids ones well love throw ball around c...        40.0
# 18589  sin gluten free percent grasa fat percent yumm...       225.0
# 20781  crazy roller gluten free percent yummy percent...       110.0
# 970    introducing ferrero rocher moments special pra...       175.0
# 10965  introducing ferrero rocher moments special pra...       349.0
#
#        market_price  discount_%  negative  neutral  positive  compound  \
# 8558          110.0         0.0     0.000    0.572     0.428    0.9136
# 13075         110.0         0.0     0.000    0.427     0.573    0.9442
# 16625          40.0         0.0     0.000    0.427     0.573    0.9442
# 5895          125.0         0.0     0.000    0.326     0.674    0.9709
# 5774          125.0         0.0     0.000    0.447     0.553    0.9442
# 21486          40.0         0.0     0.000    0.472     0.528    0.9584
# 18589         225.0         0.0     0.187    0.466     0.347    0.4767
# 20781         110.0         0.0     0.091    0.302     0.608    0.9287
# 970           175.0         0.0     0.000    0.574     0.426    0.9854
# 10965         349.0         0.0     0.000    0.574     0.426    0.9854
#
#        sale_price_scaled  cluster_label
# 8558            0.053841              2
# 13075           0.053841              2
# 16625           0.018798              2
# 5895            0.061350              2
# 5774            0.061350              2
# 21486           0.018798              2
# 18589           0.111411              3
# 20781           0.053841              2
# 970             0.086381              2
# 10965           0.173488              2

# %%
#Summary of results
#https://pandas.pydata.org/docs/user_guide/style.html
#https://stackoverflow.com/questions/59535426/can-you-change-the-caption-font-size-using-pandas-styling
#https://datascientyst.com/set-caption-customize-font-size-color-in-pandas-dataframe/
query=test.loc[[3],:]
d=pd.DataFrame({'Similar products':similar_products_3['product'].values})
d.style.set_caption('Similar products for: '+'"'+query['product'].values+'"').set_table_styles([{'selector':'caption',
                                                                                         'props':[('color','black'),
                                                                                                  ('font-weight', 'bold'),
                                                                                                  ('text-align','left'),
                                                                                                  ('background-color','skyblue'),
                                                                                                 ('font-size', '12px')]}])
# Out:
# <style  type="text/css" >
#     #T_7fbf1879_3460_11ed_a212_d4bed961474d caption {
#           color: black;
#           font-weight: bold;
#           text-align: left;
#           background-color: skyblue;
#           font-size: 12px;
#     }</style><table id="T_7fbf1879_3460_11ed_a212_d4bed961474d" ><caption>['Similar products for: "Kantan Watermelon Slice"']</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Similar products</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_7fbf1879_3460_11ed_a212_d4bed961474dlevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_7fbf1879_3460_11ed_a212_d4bed961474drow0_col0" class="data row0 col0" >Kantan Cola Bottles Gum</td>
#             </tr>
#             <tr>
#                         <th id="T_7fbf1879_3460_11ed_a212_d4bed961474dlevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_7fbf1879_3460_11ed_a212_d4bed961474drow1_col0" class="data row1 col0" >Kantan Bubble Gum Balls</td>
#             </tr>
#             <tr>
#                         <th id="T_7fbf1879_3460_11ed_a212_d4bed961474dlevel0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_7fbf1879_3460_11ed_a212_d4bed961474drow2_col0" class="data row2 col0" >Kantan Bubble Gum Balls</td>
#             </tr>
#             <tr>
#                         <th id="T_7fbf1879_3460_11ed_a212_d4bed961474dlevel0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_7fbf1879_3460_11ed_a212_d4bed961474drow3_col0" class="data row3 col0" >Pucks Crunchy Jellies</td>
#             </tr>
#             <tr>
#                         <th id="T_7fbf1879_3460_11ed_a212_d4bed961474dlevel0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_7fbf1879_3460_11ed_a212_d4bed961474drow4_col0" class="data row4 col0" >Tennis Balls Gum</td>
#             </tr>
#             <tr>
#                         <th id="T_7fbf1879_3460_11ed_a212_d4bed961474dlevel0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_7fbf1879_3460_11ed_a212_d4bed961474drow5_col0" class="data row5 col0" >Kantan Tennis Balls</td>
#             </tr>
#             <tr>
#                         <th id="T_7fbf1879_3460_11ed_a212_d4bed961474dlevel0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_7fbf1879_3460_11ed_a212_d4bed961474drow6_col0" class="data row6 col0" >Cola Bottles - Sugar</td>
#             </tr>
#             <tr>
#                         <th id="T_7fbf1879_3460_11ed_a212_d4bed961474dlevel0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_7fbf1879_3460_11ed_a212_d4bed961474drow7_col0" class="data row7 col0" >Crazy Roller</td>
#             </tr>
#             <tr>
#                         <th id="T_7fbf1879_3460_11ed_a212_d4bed961474dlevel0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_7fbf1879_3460_11ed_a212_d4bed961474drow8_col0" class="data row8 col0" >Moments</td>
#             </tr>
#             <tr>
#                         <th id="T_7fbf1879_3460_11ed_a212_d4bed961474dlevel0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_7fbf1879_3460_11ed_a212_d4bed961474drow9_col0" class="data row9 col0" >Moments</td>
#             </tr>
#     </tbody></table>

# %%
query=test.loc[[10],:]
query
# Out:
#                                           product                category  \
# 10  Stainless Steel Water Bottle - Green BB 498 2  Kitchen, Garden & Pets
#
#              sub_category brand                    type  \
# 10  Storage & Accessories    DP  Water & Fridge Bottles
#
#                                           description  sale_price  \
# 10  This green coloured water bottle, made of stai...       249.0
#
#     market_price
# 10         460.0

# %%
query.to_csv('query10.csv',index=False)

# %%
query['sale_price']=2700
query.to_csv('query_salepreiceerror.csv',index=False)

# %%
# changing sale price to check for saleprice check
query['sale_price']=2700
similar_products=get_similar_products(query,df,X_train=X_train,num_results=11)
similar_products
# Out:
# The sale_price of query product is not in range of other products in same brand,Check sale_price

# %%
query['brand']=' '
query.to_csv('missingbrand.csv',index=False)

# %%
query['sale_price']=249
query['brand']=' ' #keepingspace in brand
similar_products=get_similar_products(query,df,X_train=X_train,num_results=11)
similar_products
# Out:
# Please check datapoint
#
# The data has missing values in['brand']columns
# Please check query point for any missing or incomplete information

# %%
query=test.loc[[765],:]
query.to_csv('query765.csv',index=False)

# %%
query=test.loc[[765],:]
similar_products=get_similar_products(query,df,X_train=X_train,num_results=11)
similar_products
# Out:
# The searched/Queried product is:
#  Brahmi Bhringaraj Taila - Anti Graying
#
# Top 10 Similar products for "Brahmi Bhringaraj Taila - Anti Graying" are:
# ======================================================================
#
# 16751 : Moroccan Argan Hair Serum  - Nourishing, Conditioning
# Cosine Similarity with queried product is : 0.999999
# Discount %:  0.0
# --------------------------------------------------
#
# 19261 : Evening Primrose Oil - Vegetarian Capsule (500 mg)
# Cosine Similarity with queried product is : 0.999998
# Discount %:  0.0
# --------------------------------------------------
#
# 5783 : Pro Keratin & Argan Oil Hair Nourishing Smooth Therapy Spray
# Cosine Similarity with queried product is : 0.999998
# Discount %:  0.0
# --------------------------------------------------
#
# 15588 : Cold Pressed Rosemary Lavender Healthy Hair Oil For Thick & Strong Hair
# Cosine Similarity with queried product is : 0.999998
# Discount %:  0.0
# --------------------------------------------------
#
# 3353 : 10-In-1 Bioactive Hair Oil - 10 Pure Oils in 1
# Cosine Similarity with queried product is : 0.999998
# Discount %:  0.0
# --------------------------------------------------
#
# 6240 : Flaxseed Oil - Omega-3, Omega-6, Omega-9 Vegetarian Capsule
# Cosine Similarity with queried product is : 0.999998
# Discount %:  0.0
# --------------------------------------------------
#
# 16132 : Garlic Oil - Vegetarian Capsule 500 mg
# Cosine Similarity with queried product is : 0.999998
# Discount %:  0.0
# --------------------------------------------------
#
# 18939 : Garlic Oil - Vegetarian Capsule 500 mg
# Cosine Similarity with queried product is : 0.999998
# Discount %:  0.0
# --------------------------------------------------
#
# 20312 : Ultralights Highlighting Kit - Coffee Collection, Mocha Brown
# Cosine Similarity with queried product is : 0.999997
# Discount %:  0.0
# --------------------------------------------------
#
# 7970 : Ultralights Highlighting Kit - Coffee Collection, Hazel Brown
# Cosine Similarity with queried product is : 0.999997
# Discount %:  0.0
# --------------------------------------------------
#                                                  product  category  \
# 16751  Moroccan Argan Hair Serum  - Nourishing, Condi...         3
# 19261  Evening Primrose Oil - Vegetarian Capsule (500...         3
# 5783   Pro Keratin & Argan Oil Hair Nourishing Smooth...         3
# 15588  Cold Pressed Rosemary Lavender Healthy Hair Oi...         3
# 3353      10-In-1 Bioactive Hair Oil - 10 Pure Oils in 1         3
# 6240   Flaxseed Oil - Omega-3, Omega-6, Omega-9 Veget...         3
# 16132             Garlic Oil - Vegetarian Capsule 500 mg         3
# 18939             Garlic Oil - Vegetarian Capsule 500 mg         3
# 20312  Ultralights Highlighting Kit - Coffee Collecti...         3
# 7970   Ultralights Highlighting Kit - Coffee Collecti...         3
#
#        sub_category  brand  type  \
# 16751            50   1849   203
# 19261            50   1835   203
# 5783             50   1849   205
# 15588            50   1809   203
# 3353             50   1849   203
# 6240             50   1835   203
# 16132            50   1835   203
# 18939            50   1835   203
# 20312            50   1856   202
# 7970             50   1856   202
#
#                                              description  sale_price  \
# 16751  get soft glossy hair seconds light non greasy ...       675.0
# 19261  product contains evening primrose oil known he...       295.0
# 5783   botanica pro keratin argan oil smooth therapy ...       499.0
# 15588  bring home soulflower rosemary lavender health...       300.0
# 3353   botanica years research brought breakthrough h...       799.0
# 6240   flaxseed oil useful strengthening reduces vata...       235.0
# 16132  product contains garlic oil known help proper ...       220.0
# 18939  product contains garlic oil known help proper ...       220.0
# 20312  ready give hair gorgeous vibrant highlights or...       160.0
# 7970   ready give hair gorgeous vibrant highlights or...       160.0
#
#        market_price  discount_%  negative  neutral  positive  compound  \
# 16751         675.0    0.000000     0.060    0.605     0.335    0.9929
# 19261         295.0    0.000000     0.121    0.671     0.208    0.5719
# 5783          499.0    0.000000     0.074    0.608     0.318    0.9970
# 15588         400.0    0.250000     0.065    0.507     0.428    0.9423
# 3353          899.0    0.111235     0.085    0.812     0.102    0.0310
# 6240          235.0    0.000000     0.072    0.335     0.593    0.8979
# 16132         220.0    0.000000     0.054    0.614     0.332    0.8271
# 18939         220.0    0.000000     0.054    0.614     0.332    0.8271
# 20312         160.0    0.000000     0.000    0.590     0.410    0.9843
# 7970          160.0    0.000000     0.000    0.590     0.410    0.9843
#
#        sale_price_scaled  cluster_label
# 16751           0.336687              2
# 19261           0.146454              3
# 5783            0.248580              2
# 15588           0.148957              4
# 3353            0.398763              1
# 6240            0.116418              2
# 16132           0.108908              2
# 18939           0.108908              2
# 20312           0.078872              2
# 7970            0.078872              2

# %%
d=pd.DataFrame({'Similar products':similar_products['product'].values})
d.style.set_caption('Similar products for: '+'"'+query['product'].values+'"').set_table_styles([{'selector':'caption',
                                                                                         'props':[('color','black'),
                                                                                                  ('font-weight', 'bold'),
                                                                                                  ('text-align','left'),
                                                                                                  ('background-color','skyblue'),
                                                                                                 ('font-size', '12px')]}])
# Out:
# <style  type="text/css" >
#     #T_873dc261_3460_11ed_ad8c_d4bed961474d caption {
#           color: black;
#           font-weight: bold;
#           text-align: left;
#           background-color: skyblue;
#           font-size: 12px;
#     }</style><table id="T_873dc261_3460_11ed_ad8c_d4bed961474d" ><caption>['Similar products for: "Brahmi Bhringaraj Taila - Anti Graying"']</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Similar products</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_873dc261_3460_11ed_ad8c_d4bed961474dlevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_873dc261_3460_11ed_ad8c_d4bed961474drow0_col0" class="data row0 col0" >Moroccan Argan Hair Serum  - Nourishing, Conditioning</td>
#             </tr>
#             <tr>
#                         <th id="T_873dc261_3460_11ed_ad8c_d4bed961474dlevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_873dc261_3460_11ed_ad8c_d4bed961474drow1_col0" class="data row1 col0" >Evening Primrose Oil - Vegetarian Capsule (500 mg)</td>
#             </tr>
#             <tr>
#                         <th id="T_873dc261_3460_11ed_ad8c_d4bed961474dlevel0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_873dc261_3460_11ed_ad8c_d4bed961474drow2_col0" class="data row2 col0" >Pro Keratin & Argan Oil Hair Nourishing Smooth Therapy Spray</td>
#             </tr>
#             <tr>
#                         <th id="T_873dc261_3460_11ed_ad8c_d4bed961474dlevel0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_873dc261_3460_11ed_ad8c_d4bed961474drow3_col0" class="data row3 col0" >Cold Pressed Rosemary Lavender Healthy Hair Oil For Thick & Strong Hair</td>
#             </tr>
#             <tr>
#                         <th id="T_873dc261_3460_11ed_ad8c_d4bed961474dlevel0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_873dc261_3460_11ed_ad8c_d4bed961474drow4_col0" class="data row4 col0" >10-In-1 Bioactive Hair Oil - 10 Pure Oils in 1</td>
#             </tr>
#             <tr>
#                         <th id="T_873dc261_3460_11ed_ad8c_d4bed961474dlevel0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_873dc261_3460_11ed_ad8c_d4bed961474drow5_col0" class="data row5 col0" >Flaxseed Oil - Omega-3, Omega-6, Omega-9 Vegetarian Capsule</td>
#             </tr>
#             <tr>
#                         <th id="T_873dc261_3460_11ed_ad8c_d4bed961474dlevel0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_873dc261_3460_11ed_ad8c_d4bed961474drow6_col0" class="data row6 col0" >Garlic Oil - Vegetarian Capsule 500 mg</td>
#             </tr>
#             <tr>
#                         <th id="T_873dc261_3460_11ed_ad8c_d4bed961474dlevel0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_873dc261_3460_11ed_ad8c_d4bed961474drow7_col0" class="data row7 col0" >Garlic Oil - Vegetarian Capsule 500 mg</td>
#             </tr>
#             <tr>
#                         <th id="T_873dc261_3460_11ed_ad8c_d4bed961474dlevel0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_873dc261_3460_11ed_ad8c_d4bed961474drow8_col0" class="data row8 col0" >Ultralights Highlighting Kit - Coffee Collection, Mocha Brown</td>
#             </tr>
#             <tr>
#                         <th id="T_873dc261_3460_11ed_ad8c_d4bed961474dlevel0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_873dc261_3460_11ed_ad8c_d4bed961474drow9_col0" class="data row9 col0" >Ultralights Highlighting Kit - Coffee Collection, Hazel Brown</td>
#             </tr>
#     </tbody></table>

# %%
query=test.loc[[5232],:]
query.to_csv('query5232.csv',index=False)

# %%
query=test.loc[[5232],:]
similar_products=get_similar_products(query,df,X_train=X_train,num_results=11)
similar_products
# Out:
# The searched/Queried product is:
#  Sauce - Chilli, Hot
#
# Top 10 Similar products for "Sauce - Chilli, Hot" are:
# ======================================================================
#
# 12205 : Sauce - Sweet Thai chilli Sauce
# Cosine Similarity with queried product is : 0.999997
# Discount %:  0.0
# --------------------------------------------------
#
# 104 : Sauce - Black Bean Sauce
# Cosine Similarity with queried product is : 0.999997
# Discount %:  0.0
# --------------------------------------------------
#
# 8755 : Sauce - Dark Soy
# Cosine Similarity with queried product is : 0.999997
# Discount %:  0.0
# --------------------------------------------------
#
# 1340 : Sauce - Black Pepper
# Cosine Similarity with queried product is : 0.999996
# Discount %:  0.0
# --------------------------------------------------
#
# 5396 : Sauce - Teriyaki
# Cosine Similarity with queried product is : 0.999995
# Discount %:  0.0
# --------------------------------------------------
#
# 12480 : Ongs Marinade - Honey Soy 255 gm Bottle
# Cosine Similarity with queried product is : 0.999995
# Discount %:  0.0
# --------------------------------------------------
#
# 3603 : Sauce - Stir Fry
# Cosine Similarity with queried product is : 0.999995
# Discount %:  0.0
# --------------------------------------------------
#
# 15822 : Sambal - Oelek
# Cosine Similarity with queried product is : 0.999995
# Discount %:  0.0
# --------------------------------------------------
#
# 14382 : Sauce - Light Soy
# Cosine Similarity with queried product is : 0.999994
# Discount %:  0.0
# --------------------------------------------------
#
# 15101 : Schezwan Dip
# Cosine Similarity with queried product is : 0.999993
# Discount %:  0.0
# --------------------------------------------------
#                                        product  category  sub_category  brand  \
# 12205          Sauce - Sweet Thai chilli Sauce         9            79   1430
# 104                   Sauce - Black Bean Sauce         9            79   1430
# 8755                          Sauce - Dark Soy         9            79   1430
# 1340                      Sauce - Black Pepper         9            79   1430
# 5396                          Sauce - Teriyaki         9            79   1430
# 12480  Ongs Marinade - Honey Soy 255 gm Bottle         9            79   1430
# 3603                          Sauce - Stir Fry         9            79   1430
# 15822                           Sambal - Oelek         9            79   1430
# 14382                        Sauce - Light Soy         9            79   1430
# 15101                             Schezwan Dip         9            79   1443
#
#        type                                        description  sale_price  \
# 12205   395  add black bean sauce oriental recipes give aut...       240.0
# 104     395  ongs brand aims bring flavours asia easy use s...       240.0
# 8755    395  full bodied dark reddish brown sauce rich arom...       240.0
# 1340    395  mild spice sauce packed right amount black pep...       240.0
# 5396    395  truly convenient oriental sauce sweet savoury ...       290.0
# 12480   395  ongs honey soy marinade directions add tablesp...       210.0
# 3603    395  oriental one sauce perfectly blended authentic...       240.0
# 15822   395  sambal hot paste famous south east asia made m...       240.0
# 14382   395                                 boost taste snacks       240.0
# 15101   395  organic nation chutneys blended right spices i...        89.0
#
#        market_price  discount_%  negative  neutral  positive  compound  \
# 12205         240.0         0.0       0.0    0.816     0.184    0.8591
# 104           240.0         0.0       0.0    0.723     0.277    0.9442
# 8755          240.0         0.0       0.0    0.749     0.251    0.8271
# 1340          240.0         0.0       0.0    0.748     0.252    0.9022
# 5396          290.0         0.0       0.0    0.638     0.362    0.9517
# 12480         210.0         0.0       0.0    1.000     0.000    0.0000
# 3603          240.0         0.0       0.0    0.667     0.333    0.9432
# 15822         240.0         0.0       0.0    1.000     0.000    0.0000
# 14382         240.0         0.0       0.0    0.426     0.574    0.4019
# 15101          89.0         0.0       0.0    0.640     0.360    0.9590
#
#        sale_price_scaled  cluster_label
# 12205           0.118921              2
# 104             0.118921              2
# 8755            0.118921              2
# 1340            0.118921              2
# 5396            0.143951              2
# 12480           0.103902              1
# 3603            0.118921              2
# 15822           0.118921              1
# 14382           0.118921              3
# 15101           0.043328              2

# %%
d=pd.DataFrame({'Similar products':similar_products['product'].values})
d.style.set_caption('Similar products for: '+'"'+query['product'].values+'"').set_table_styles([{'selector':'caption',
                                                                                         'props':[('color','black'),
                                                                                                  ('font-weight', 'bold'),
                                                                                                  ('text-align','left'),
                                                                                                  ('background-color','skyblue'),
                                                                                                 ('font-size', '12px')]}])
# Out:
# <style  type="text/css" >
#     #T_889a9225_3460_11ed_99b1_d4bed961474d caption {
#           color: black;
#           font-weight: bold;
#           text-align: left;
#           background-color: skyblue;
#           font-size: 12px;
#     }</style><table id="T_889a9225_3460_11ed_99b1_d4bed961474d" ><caption>['Similar products for: "Sauce - Chilli, Hot"']</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Similar products</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_889a9225_3460_11ed_99b1_d4bed961474dlevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_889a9225_3460_11ed_99b1_d4bed961474drow0_col0" class="data row0 col0" >Sauce - Sweet Thai chilli Sauce</td>
#             </tr>
#             <tr>
#                         <th id="T_889a9225_3460_11ed_99b1_d4bed961474dlevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_889a9225_3460_11ed_99b1_d4bed961474drow1_col0" class="data row1 col0" >Sauce - Black Bean Sauce</td>
#             </tr>
#             <tr>
#                         <th id="T_889a9225_3460_11ed_99b1_d4bed961474dlevel0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_889a9225_3460_11ed_99b1_d4bed961474drow2_col0" class="data row2 col0" >Sauce - Dark Soy</td>
#             </tr>
#             <tr>
#                         <th id="T_889a9225_3460_11ed_99b1_d4bed961474dlevel0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_889a9225_3460_11ed_99b1_d4bed961474drow3_col0" class="data row3 col0" >Sauce - Black Pepper</td>
#             </tr>
#             <tr>
#                         <th id="T_889a9225_3460_11ed_99b1_d4bed961474dlevel0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_889a9225_3460_11ed_99b1_d4bed961474drow4_col0" class="data row4 col0" >Sauce - Teriyaki</td>
#             </tr>
#             <tr>
#                         <th id="T_889a9225_3460_11ed_99b1_d4bed961474dlevel0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_889a9225_3460_11ed_99b1_d4bed961474drow5_col0" class="data row5 col0" >Ongs Marinade - Honey Soy 255 gm Bottle</td>
#             </tr>
#             <tr>
#                         <th id="T_889a9225_3460_11ed_99b1_d4bed961474dlevel0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_889a9225_3460_11ed_99b1_d4bed961474drow6_col0" class="data row6 col0" >Sauce - Stir Fry</td>
#             </tr>
#             <tr>
#                         <th id="T_889a9225_3460_11ed_99b1_d4bed961474dlevel0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_889a9225_3460_11ed_99b1_d4bed961474drow7_col0" class="data row7 col0" >Sambal - Oelek</td>
#             </tr>
#             <tr>
#                         <th id="T_889a9225_3460_11ed_99b1_d4bed961474dlevel0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_889a9225_3460_11ed_99b1_d4bed961474drow8_col0" class="data row8 col0" >Sauce - Light Soy</td>
#             </tr>
#             <tr>
#                         <th id="T_889a9225_3460_11ed_99b1_d4bed961474dlevel0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_889a9225_3460_11ed_99b1_d4bed961474drow9_col0" class="data row9 col0" >Schezwan Dip</td>
#             </tr>
#     </tbody></table>

# %%
query=test.loc[[2607],:]
query
# Out:
#                            product                category  \
# 2607  Instant Pasta - Tomato Salsa  Snacks & Branded Foods
#
#                    sub_category      brand           type  \
# 2607  Noodle, Pasta, Vermicelli  Weikfield  Instant Pasta
#
#                          description  sale_price  market_price
# 2607  Instant Pasta with Sauce Maker        22.0          25.0

# %%
query=test.loc[[2607],:]
query.to_csv('query2607.csv')

# %%
query=test.loc[[2607],:]
similar_products=get_similar_products(query,df,X_train=X_train,num_results=11)
similar_products
# Out:
# The searched/Queried product is:
#  Instant Pasta - Tomato Salsa
#
# Top 10 Similar products for "Instant Pasta - Tomato Salsa" are:
# ======================================================================
#
# 6692 : 1-2-3 Noodles - Chicken Flavour
# Cosine Similarity with queried product is : 0.999998
# Discount %:  0.0
# --------------------------------------------------
#
# 2013 : X-press Instant Noodles - Masala Delight, Super Saver Pack
# Cosine Similarity with queried product is : 0.999997
# Discount %:  0.0
# --------------------------------------------------
#
# 17915 : 1-2-3 Noodles - Pure Vegetarian
# Cosine Similarity with queried product is : 0.999996
# Discount %:  0.0
# --------------------------------------------------
#
# 9277 : Organic Black Pepper/Kari Menasu
# Cosine Similarity with queried product is : 0.999995
# Discount %:  0.0
# --------------------------------------------------
#
# 10133 : Mortadella - Chicken, Olive
# Cosine Similarity with queried product is : 0.999994
# Discount %:  0.0
# --------------------------------------------------
#
# 5029 : A Flavouring Agent - Grape
# Cosine Similarity with queried product is : 0.999993
# Discount %:  0.0
# --------------------------------------------------
#
# 15566 : Momos - Vegetable
# Cosine Similarity with queried product is : 0.999991
# Discount %:  0.0
# --------------------------------------------------
#
# 17536 : Hair Growth Serum With Vitamin C - Oil Free Formula
# Cosine Similarity with queried product is : 0.999987
# Discount %:  0.0
# --------------------------------------------------
#
# 8695 : Smoked Chicken Frankfurter - 7"
# Cosine Similarity with queried product is : 0.999986
# Discount %:  0.0
# --------------------------------------------------
#
# 20867 : Udupi Kashaya Milk Mix
# Cosine Similarity with queried product is : 0.999985
# Discount %:  0.0
# --------------------------------------------------
#                                                  product  category  \
# 6692                     1-2-3 Noodles - Chicken Flavour        11
# 2013   X-press Instant Noodles - Masala Delight, Supe...        11
# 17915                    1-2-3 Noodles - Pure Vegetarian        11
# 9277                    Organic Black Pepper/Kari Menasu         7
# 10133                        Mortadella - Chicken, Olive        11
# 5029                          A Flavouring Agent - Grape         7
# 15566                                  Momos - Vegetable        11
# 17536  Hair Growth Serum With Vitamin C - Oil Free Fo...         3
# 8695                     Smoked Chicken Frankfurter - 7"        11
# 20867                             Udupi Kashaya Milk Mix         7
#
#        sub_category  brand  type  \
# 6692             65   2086   230
# 2013             65   2086   230
# 17915            65   2086   230
# 9277             59   1945   213
# 10133            46   1588   174
# 5029             59   1968   213
# 15566            46   1549   176
# 17536            60   1832   201
# 8695             46   1629   174
# 20867            59   2011   213
#
#                                              description  sale_price  \
# 6692   wai wai instant way mouthwatering noodles pref...        12.0
# 2013   wai wai press white noodle available vegetable...        60.0
# 17915  wai wai instant way mouthwatering noodles pref...        28.0
# 9277   rich flavour large sized peppercorns stems fac...       175.0
# 10133  quickee presents deliciously mouth watering ra...       195.0
# 5029   avail wide range liquid food colours extensive...        35.0
# 15566  made premium ingredients preservatives prasuma...       150.0
# 17536  vitamin beard hair growth serum men unique oil...       549.0
# 8695   republic chicken presents authentic range chic...       540.0
# 20867  udupi ruchi udupi kashaya traditional sought b...       142.5
#
#        market_price  discount_%  negative  neutral  positive  compound  \
# 6692           12.0        0.00     0.000    0.741     0.259    0.8442
# 2013           60.0        0.00     0.000    0.561     0.439    0.9686
# 17915          35.0        0.20     0.000    1.000     0.000    0.0000
# 9277          175.0        0.00     0.000    0.734     0.266    0.7845
# 10133         195.0        0.00     0.036    0.808     0.156    0.6124
# 5029           35.0        0.00     0.000    0.787     0.213    0.7964
# 15566         150.0        0.00     0.000    0.804     0.196    0.7430
# 17536         549.0        0.00     0.011    0.494     0.495    0.9987
# 8695          600.0        0.10     0.048    0.481     0.471    0.9485
# 20867         150.0        0.05     0.106    0.646     0.247    0.5719
#
#        sale_price_scaled  cluster_label
# 6692            0.004781              2
# 2013            0.028810              2
# 17915           0.012791              1
# 9277            0.086381              2
# 10133           0.096393              3
# 5029            0.016295              3
# 15566           0.073865              3
# 17536           0.273610              2
# 8695            0.269105              2
# 20867           0.070111              3

# %%
d=pd.DataFrame({'Similar products':similar_products['product'].values})
d.style.set_caption('Similar products for: '+'"'+query['product'].values+'"').set_table_styles([{'selector':'caption',
                                                                                         'props':[('color','black'),
                                                                                                  ('font-weight', 'bold'),
                                                                                                  ('text-align','left'),
                                                                                                  ('background-color','skyblue'),
                                                                                                 ('font-size', '12px')]}])
# Out:
# <style  type="text/css" >
#     #T_8a3f0bdb_3460_11ed_b1b3_d4bed961474d caption {
#           color: black;
#           font-weight: bold;
#           text-align: left;
#           background-color: skyblue;
#           font-size: 12px;
#     }</style><table id="T_8a3f0bdb_3460_11ed_b1b3_d4bed961474d" ><caption>['Similar products for: "Instant Pasta - Tomato Salsa"']</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Similar products</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_8a3f0bdb_3460_11ed_b1b3_d4bed961474dlevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_8a3f0bdb_3460_11ed_b1b3_d4bed961474drow0_col0" class="data row0 col0" >1-2-3 Noodles - Chicken Flavour</td>
#             </tr>
#             <tr>
#                         <th id="T_8a3f0bdb_3460_11ed_b1b3_d4bed961474dlevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_8a3f0bdb_3460_11ed_b1b3_d4bed961474drow1_col0" class="data row1 col0" >X-press Instant Noodles - Masala Delight, Super Saver Pack</td>
#             </tr>
#             <tr>
#                         <th id="T_8a3f0bdb_3460_11ed_b1b3_d4bed961474dlevel0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_8a3f0bdb_3460_11ed_b1b3_d4bed961474drow2_col0" class="data row2 col0" >1-2-3 Noodles - Pure Vegetarian</td>
#             </tr>
#             <tr>
#                         <th id="T_8a3f0bdb_3460_11ed_b1b3_d4bed961474dlevel0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_8a3f0bdb_3460_11ed_b1b3_d4bed961474drow3_col0" class="data row3 col0" >Organic Black Pepper/Kari Menasu</td>
#             </tr>
#             <tr>
#                         <th id="T_8a3f0bdb_3460_11ed_b1b3_d4bed961474dlevel0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_8a3f0bdb_3460_11ed_b1b3_d4bed961474drow4_col0" class="data row4 col0" >Mortadella - Chicken, Olive</td>
#             </tr>
#             <tr>
#                         <th id="T_8a3f0bdb_3460_11ed_b1b3_d4bed961474dlevel0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_8a3f0bdb_3460_11ed_b1b3_d4bed961474drow5_col0" class="data row5 col0" >A Flavouring Agent - Grape</td>
#             </tr>
#             <tr>
#                         <th id="T_8a3f0bdb_3460_11ed_b1b3_d4bed961474dlevel0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_8a3f0bdb_3460_11ed_b1b3_d4bed961474drow6_col0" class="data row6 col0" >Momos - Vegetable</td>
#             </tr>
#             <tr>
#                         <th id="T_8a3f0bdb_3460_11ed_b1b3_d4bed961474dlevel0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_8a3f0bdb_3460_11ed_b1b3_d4bed961474drow7_col0" class="data row7 col0" >Hair Growth Serum With Vitamin C - Oil Free Formula</td>
#             </tr>
#             <tr>
#                         <th id="T_8a3f0bdb_3460_11ed_b1b3_d4bed961474dlevel0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_8a3f0bdb_3460_11ed_b1b3_d4bed961474drow8_col0" class="data row8 col0" >Smoked Chicken Frankfurter - 7"</td>
#             </tr>
#             <tr>
#                         <th id="T_8a3f0bdb_3460_11ed_b1b3_d4bed961474dlevel0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_8a3f0bdb_3460_11ed_b1b3_d4bed961474drow9_col0" class="data row9 col0" >Udupi Kashaya Milk Mix</td>
#             </tr>
#     </tbody></table>

# %%
query=test.loc[[1909],:]
query.to_csv('query1909.csv')

# %%
query=test.loc[[1909],:]
similar_products=get_similar_products(query,df,X_train=X_train,num_results=11)
similar_products
# Out:
# The searched/Queried product is:
#  Solid Rim Power Active - Lemon
#
# Top 10 Similar products for "Solid Rim Power Active - Lemon" are:
# ======================================================================
#
# 12357 : Toilet Rimblock Dou Burst - Lemon
# Cosine Similarity with queried product is : 0.999982
# Discount %:  0.0
# --------------------------------------------------
#
# 18041 : Solid Rim Blue Active - Fresh Flower
# Cosine Similarity with queried product is : 0.999982
# Discount %:  0.0
# --------------------------------------------------
#
# 16013 : Solid Rim Colour Active Purple Water - Lavender
# Cosine Similarity with queried product is : 0.999982
# Discount %:  0.0
# --------------------------------------------------
#
# 5973 : Acticlean In Cistern Toilet Block - Purple
# Cosine Similarity with queried product is : 0.999982
# Discount %:  0.0
# --------------------------------------------------
#
# 18609 : Solid Rim Blue Active - Fresh Flower, Twin Pack
# Cosine Similarity with queried product is : 0.999982
# Discount %:  0.0
# --------------------------------------------------
#
# 8381 : Solid Rim Power Active Flower
# Cosine Similarity with queried product is : 0.999982
# Discount %:  0.0
# --------------------------------------------------
#
# 1233 : Solid Rim Colour Active Blue Water - Fresh Flower
# Cosine Similarity with queried product is : 0.999982
# Discount %:  0.0
# --------------------------------------------------
#
# 10810 : Solid Rim Power Active Lemon Trio Pack
# Cosine Similarity with queried product is : 0.999982
# Discount %:  0.0
# --------------------------------------------------
#
# 15000 : Toilet Gel Cleaner - Hygiene & Shine, Flower Burst
# Cosine Similarity with queried product is : 0.999968
# Discount %:  0.0
# --------------------------------------------------
#
# 3593 : Toilet & Bathroom Wipes - Sweet Tulip
# Cosine Similarity with queried product is : 0.999967
# Discount %:  0.0
# --------------------------------------------------
#                                                  product  category  \
# 12357                  Toilet Rimblock Dou Burst - Lemon         5
# 18041               Solid Rim Blue Active - Fresh Flower         5
# 16013    Solid Rim Colour Active Purple Water - Lavender         5
# 5973          Acticlean In Cistern Toilet Block - Purple         5
# 18609    Solid Rim Blue Active - Fresh Flower, Twin Pack         5
# 8381                       Solid Rim Power Active Flower         5
# 1233   Solid Rim Colour Active Blue Water - Fresh Flower         5
# 10810             Solid Rim Power Active Lemon Trio Pack         5
# 15000  Toilet Gel Cleaner - Hygiene & Shine, Flower B...         5
# 3593               Toilet & Bathroom Wipes - Sweet Tulip         5
#
#        sub_category  brand  type  \
# 12357             1    247   222
# 18041             1    247   222
# 16013             1    247   222
# 5973              1    247   222
# 18609             1    247   222
# 8381              1    247   222
# 1233              1    247   222
# 10810             1    247   222
# 15000             1    247   222
# 3593              1    247   222
#
#                                              description  sale_price  \
# 12357  function formula cleaning foam cleans toilet e...       169.0
# 18041  function formula cleaning foam cleans toilet e...       169.0
# 16013  function formula cleaning foam cleans toilet e...       169.0
# 5973   function formula cleaning foam cleans toilet e...       249.0
# 18609  function formula cleaning foam cleans toilet e...       299.0
# 8381   function formula cleaning foam cleans toilet e...       399.0
# 1233   function formula cleaning foam cleans toilet e...       399.0
# 10810  function formula cleaning foam cleans toilet e...       399.0
# 15000  bloo total hygiene shine toilet gel removes li...       259.0
# 3593   fragrance lock easy open close pack keeps wipe...       159.0
#
#        market_price  discount_%  negative  neutral  positive  compound  \
# 12357         169.0         0.0     0.108    0.570     0.322    0.9001
# 18041         169.0         0.0     0.108    0.570     0.322    0.9001
# 16013         169.0         0.0     0.108    0.570     0.322    0.9001
# 5973          249.0         0.0     0.108    0.570     0.322    0.9001
# 18609         299.0         0.0     0.108    0.570     0.322    0.9001
# 8381          399.0         0.0     0.108    0.570     0.322    0.9001
# 1233          399.0         0.0     0.108    0.570     0.322    0.9001
# 10810         399.0         0.0     0.108    0.570     0.322    0.9001
# 15000         259.0         0.0     0.117    0.572     0.311    0.8316
# 3593          159.0         0.0     0.066    0.543     0.391    0.9371
#
#        sale_price_scaled  cluster_label
# 12357           0.083377              2
# 18041           0.083377              2
# 16013           0.083377              2
# 5973            0.123426              2
# 18609           0.148457              2
# 8381            0.198518              2
# 1233            0.198518              2
# 10810           0.198518              2
# 15000           0.128432              2
# 3593            0.078371              2

# %%
d=pd.DataFrame({'Similar products':similar_products['product'].values})
d.style.set_caption('Similar products for: '+'"'+query['product'].values+'"').set_table_styles([{'selector':'caption',
                                                                                         'props':[('color','black'),
                                                                                                  ('font-weight', 'bold'),
                                                                                                  ('text-align','left'),
                                                                                                  ('background-color','skyblue'),
                                                                                                 ('font-size', '12px')]}])
# Out:
# <style  type="text/css" >
#     #T_8be01d41_3460_11ed_9604_d4bed961474d caption {
#           color: black;
#           font-weight: bold;
#           text-align: left;
#           background-color: skyblue;
#           font-size: 12px;
#     }</style><table id="T_8be01d41_3460_11ed_9604_d4bed961474d" ><caption>['Similar products for: "Solid Rim Power Active - Lemon"']</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Similar products</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_8be01d41_3460_11ed_9604_d4bed961474dlevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_8be01d41_3460_11ed_9604_d4bed961474drow0_col0" class="data row0 col0" >Toilet Rimblock Dou Burst - Lemon</td>
#             </tr>
#             <tr>
#                         <th id="T_8be01d41_3460_11ed_9604_d4bed961474dlevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_8be01d41_3460_11ed_9604_d4bed961474drow1_col0" class="data row1 col0" >Solid Rim Blue Active - Fresh Flower</td>
#             </tr>
#             <tr>
#                         <th id="T_8be01d41_3460_11ed_9604_d4bed961474dlevel0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_8be01d41_3460_11ed_9604_d4bed961474drow2_col0" class="data row2 col0" >Solid Rim Colour Active Purple Water - Lavender</td>
#             </tr>
#             <tr>
#                         <th id="T_8be01d41_3460_11ed_9604_d4bed961474dlevel0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_8be01d41_3460_11ed_9604_d4bed961474drow3_col0" class="data row3 col0" >Acticlean In Cistern Toilet Block - Purple</td>
#             </tr>
#             <tr>
#                         <th id="T_8be01d41_3460_11ed_9604_d4bed961474dlevel0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_8be01d41_3460_11ed_9604_d4bed961474drow4_col0" class="data row4 col0" >Solid Rim Blue Active - Fresh Flower, Twin Pack</td>
#             </tr>
#             <tr>
#                         <th id="T_8be01d41_3460_11ed_9604_d4bed961474dlevel0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_8be01d41_3460_11ed_9604_d4bed961474drow5_col0" class="data row5 col0" >Solid Rim Power Active Flower</td>
#             </tr>
#             <tr>
#                         <th id="T_8be01d41_3460_11ed_9604_d4bed961474dlevel0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_8be01d41_3460_11ed_9604_d4bed961474drow6_col0" class="data row6 col0" >Solid Rim Colour Active Blue Water - Fresh Flower</td>
#             </tr>
#             <tr>
#                         <th id="T_8be01d41_3460_11ed_9604_d4bed961474dlevel0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_8be01d41_3460_11ed_9604_d4bed961474drow7_col0" class="data row7 col0" >Solid Rim Power Active Lemon Trio Pack</td>
#             </tr>
#             <tr>
#                         <th id="T_8be01d41_3460_11ed_9604_d4bed961474dlevel0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_8be01d41_3460_11ed_9604_d4bed961474drow8_col0" class="data row8 col0" >Toilet Gel Cleaner - Hygiene & Shine, Flower Burst</td>
#             </tr>
#             <tr>
#                         <th id="T_8be01d41_3460_11ed_9604_d4bed961474dlevel0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_8be01d41_3460_11ed_9604_d4bed961474drow9_col0" class="data row9 col0" >Toilet & Bathroom Wipes - Sweet Tulip</td>
#             </tr>
#     </tbody></table>

# %%
query=test.loc[[3103],:]
similar_products=get_similar_products(query,df,X_train=X_train,num_results=11)
similar_products
# Out:
# The searched/Queried product is:
#  Organic - Mustard Oil
#
# Top 10 Similar products for "Organic - Mustard Oil" are:
# ======================================================================
#
# 19843 : Organic - Urad Chilka
# Cosine Similarity with queried product is : 0.999999
# Discount %:  0.0
# --------------------------------------------------
#
# 4299 : Organic - Masoor Malka
# Cosine Similarity with queried product is : 0.999999
# Discount %:  0.0
# --------------------------------------------------
#
# 17800 : Organic - Almond
# Cosine Similarity with queried product is : 0.999999
# Discount %:  0.0
# --------------------------------------------------
#
# 9628 : Organic - Cashew/Godambi
# Cosine Similarity with queried product is : 0.999999
# Discount %:  0.0
# --------------------------------------------------
#
# 18572 : Organic - Wheat Dalia
# Cosine Similarity with queried product is : 0.999999
# Discount %:  0.0
# --------------------------------------------------
#
# 10222 : Organic - Sesame Oil
# Cosine Similarity with queried product is : 0.999999
# Discount %:  0.0
# --------------------------------------------------
#
# 10094 : Organic - Urad Dal/Uddina Bele
# Cosine Similarity with queried product is : 0.999999
# Discount %:  0.0
# --------------------------------------------------
#
# 5103 : Organic -Suji
# Cosine Similarity with queried product is : 0.999999
# Discount %:  0.0
# --------------------------------------------------
#
# 9891 : Organic - Urad Whole
# Cosine Similarity with queried product is : 0.999999
# Discount %:  0.0
# --------------------------------------------------
#
# 3405 : Rajma/Capparadavare Jammu
# Cosine Similarity with queried product is : 0.999999
# Discount %:  0.0
# --------------------------------------------------
#                               product  category  sub_category  brand  type  \
# 19843           Organic - Urad Chilka         7            69   2004   298
# 4299           Organic - Masoor Malka         7            69   2004   298
# 17800                Organic - Almond         7            69   2004   299
# 9628         Organic - Cashew/Godambi         7            69   2004   299
# 18572           Organic - Wheat Dalia         7            69   2004   302
# 10222            Organic - Sesame Oil         7            69   2004   300
# 10094  Organic - Urad Dal/Uddina Bele         7            69   2004   298
# 5103                    Organic -Suji         7            69   2004   302
# 9891             Organic - Urad Whole         7            69   2004   298
# 3405        Rajma/Capparadavare Jammu         7            69   2004   298
#
#                                              description  sale_price  \
# 19843  turn organic brought premium fresh healthy org...       87.75
# 4299   turn organic brought premium fresh healthy org...       67.50
# 17800  turn organic brought premium fresh healthy org...      105.00
# 9628   turn organic brought premium fresh healthy org...       82.50
# 18572  turn organic brought premium fresh healthy org...       52.00
# 10222  could used cooking place edible oils help redu...      202.50
# 10094  turn organic brought premium fresh healthy org...       90.00
# 5103   organic rava made grinding organic rice coarse...       52.00
# 9891   turn organic brought premium fresh healthy org...      115.00
# 3405   turn organic rajma beans mature dried beans ma...      108.00
#
#        market_price  discount_%  negative  neutral  positive  compound  \
# 19843         117.0        0.25     0.000    0.661     0.339    0.9468
# 4299           90.0        0.25     0.000    0.745     0.255    0.7351
# 17800         105.0        0.00     0.000    0.643     0.357    0.6124
# 9628          110.0        0.25     0.000    0.643     0.357    0.6124
# 18572          52.0        0.00     0.061    0.696     0.243    0.7430
# 10222         225.0        0.10     0.133    0.545     0.321    0.7351
# 10094         120.0        0.25     0.000    0.821     0.179    0.6124
# 5103           52.0        0.00     0.078    0.777     0.145    0.4404
# 9891          115.0        0.00     0.000    0.821     0.179    0.6124
# 3405          120.0        0.10     0.000    0.797     0.203    0.7269
#
#        sale_price_scaled  cluster_label
# 19843           0.042702              4
# 4299            0.032565              4
# 17800           0.051338              3
# 9628            0.040074              3
# 18572           0.024805              3
# 10222           0.100148              2
# 10094           0.043829              3
# 5103            0.024805              3
# 9891            0.056344              3
# 3405            0.052840              3

# %%
d=pd.DataFrame({'Similar products':similar_products['product'].values})
d.style.set_caption('Similar products for: '+'"'+query['product'].values+'"').set_table_styles([{'selector':'caption',
                                                                                         'props':[('color','black'),
                                                                                                  ('font-weight', 'bold'),
                                                                                                  ('text-align','left'),
                                                                                                  ('background-color','skyblue'),
                                                                                                 ('font-size', '12px')]}])
# Out:
# <style  type="text/css" >
#     #T_8d867e08_3460_11ed_ad08_d4bed961474d caption {
#           color: black;
#           font-weight: bold;
#           text-align: left;
#           background-color: skyblue;
#           font-size: 12px;
#     }</style><table id="T_8d867e08_3460_11ed_ad08_d4bed961474d" ><caption>['Similar products for: "Organic - Mustard Oil"']</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Similar products</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_8d867e08_3460_11ed_ad08_d4bed961474dlevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_8d867e08_3460_11ed_ad08_d4bed961474drow0_col0" class="data row0 col0" >Organic - Urad Chilka</td>
#             </tr>
#             <tr>
#                         <th id="T_8d867e08_3460_11ed_ad08_d4bed961474dlevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_8d867e08_3460_11ed_ad08_d4bed961474drow1_col0" class="data row1 col0" >Organic - Masoor Malka</td>
#             </tr>
#             <tr>
#                         <th id="T_8d867e08_3460_11ed_ad08_d4bed961474dlevel0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_8d867e08_3460_11ed_ad08_d4bed961474drow2_col0" class="data row2 col0" >Organic - Almond</td>
#             </tr>
#             <tr>
#                         <th id="T_8d867e08_3460_11ed_ad08_d4bed961474dlevel0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_8d867e08_3460_11ed_ad08_d4bed961474drow3_col0" class="data row3 col0" >Organic - Cashew/Godambi</td>
#             </tr>
#             <tr>
#                         <th id="T_8d867e08_3460_11ed_ad08_d4bed961474dlevel0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_8d867e08_3460_11ed_ad08_d4bed961474drow4_col0" class="data row4 col0" >Organic - Wheat Dalia</td>
#             </tr>
#             <tr>
#                         <th id="T_8d867e08_3460_11ed_ad08_d4bed961474dlevel0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_8d867e08_3460_11ed_ad08_d4bed961474drow5_col0" class="data row5 col0" >Organic - Sesame Oil</td>
#             </tr>
#             <tr>
#                         <th id="T_8d867e08_3460_11ed_ad08_d4bed961474dlevel0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_8d867e08_3460_11ed_ad08_d4bed961474drow6_col0" class="data row6 col0" >Organic - Urad Dal/Uddina Bele</td>
#             </tr>
#             <tr>
#                         <th id="T_8d867e08_3460_11ed_ad08_d4bed961474dlevel0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_8d867e08_3460_11ed_ad08_d4bed961474drow7_col0" class="data row7 col0" >Organic -Suji</td>
#             </tr>
#             <tr>
#                         <th id="T_8d867e08_3460_11ed_ad08_d4bed961474dlevel0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_8d867e08_3460_11ed_ad08_d4bed961474drow8_col0" class="data row8 col0" >Organic - Urad Whole</td>
#             </tr>
#             <tr>
#                         <th id="T_8d867e08_3460_11ed_ad08_d4bed961474dlevel0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_8d867e08_3460_11ed_ad08_d4bed961474drow9_col0" class="data row9 col0" >Rajma/Capparadavare Jammu</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ###  Model deployed in Streamlit.
# - Streamlit app is open to public, anyone can use it
#
# [deployment link](https://maq090-big-basket-recommender-system2-streamlit2-qxcgyh.streamlitapp.com/)

# %% [markdown]
# ### <u/> References:
#
# - https://www.geeksforgeeks.org/
# - https://seaborn.pydata.org/generated/seaborn
# - https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.hist.html
# - https://docs.python.org/3/library/re.html
# - https://www.towardsdatascience.com/
